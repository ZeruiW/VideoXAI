# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                outputs = self.model(**inputs)
                logits = outputs.logits
                probabilities = F.softmax(logits, dim=-1)
                pred_label = logits.argmax(-1).item()
                pred_score = probabilities[0, pred_label].item()
                segment_outputs.append((pred_label, pred_score, probabilities))
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        segment_outputs = video_processor.predict_video_and_segments(container, true_label)
        video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
        video_pred_label = video_probs.argmax().item()
        video_pred_score = video_probs[0, video_pred_label].item()
        video_true_score = video_probs[0, true_label].item()
        
        if use_exact:
            sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
            sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
        else:
            sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
            sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
        
        predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred))
    return predictions

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, true_labels[0]].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,
    "num_classes": 5,
    "num_samples_per_class": 2,
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": True  # 设置为True以使用精确Shapley Value计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

# 准备视频样本
sampled_files = []
true_labels = []
selected_classes = list(video_labels.keys())[:config["num_classes"]]
for cls in selected_classes:
    sampled_files.extend(video_labels[cls][:config["num_samples_per_class"]])
    true_labels.extend([cls] * config["num_samples_per_class"])

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=config["use_exact"])

# 打印并保存结果
save_results(video_data)

# 打印结果以便查看
for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_labels[0]}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_labels[0]].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/10 [00:00<?, ?video/s]
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/transformers/feature_extraction_utils.py:141: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   return torch.tensor(value)
# Video: jf7RDuUTrsQ.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.2028, True Label = 325, True Label Score = 0.0010
#   Segment 1: Predicted Label = 81, Prediction Score = 0.4557, Segment Video Label Score = 0.0373, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0453
#   Segment 2: Predicted Label = 171, Prediction Score = 0.6322, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0004, SV True Label = -0.0002, SV Predicted Label = -0.0549
#   Segment 3: Predicted Label = 1, Prediction Score = 0.5045, Segment Video Label Score = 0.5045, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.0871
#   Segment 4: Predicted Label = 289, Prediction Score = 0.4299, Segment Video Label Score = 0.1295, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0192
#   Segment 5: Predicted Label = 1, Prediction Score = 0.4968, Segment Video Label Score = 0.4968, Segment True Label Score = 0.0054, SV True Label = 0.0013, SV Predicted Label = 0.0849
#   Segment 6: Predicted Label = 127, Prediction Score = 0.4740, Segment Video Label Score = 0.4092, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.0601
#   Segment 7: Predicted Label = 57, Prediction Score = 0.3964, Segment Video Label Score = 0.0368, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0455
#   Segment 8: Predicted Label = 81, Prediction Score = 0.4700, Segment Video Label Score = 0.0048, Segment True Label Score = 0.0022, SV True Label = 0.0003, SV Predicted Label = -0.0545
# Video: EhRxb8-cNzQ.mp4, Overall Predicted Label = 149, Overall Prediction Score = 0.3158, True Label = 325, True Label Score = 0.0011
#   Segment 1: Predicted Label = 230, Prediction Score = 0.5502, Segment Video Label Score = 0.0019, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0865
#   Segment 2: Predicted Label = 230, Prediction Score = 0.6382, Segment Video Label Score = 0.0491, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0731
#   Segment 3: Predicted Label = 106, Prediction Score = 0.3546, Segment Video Label Score = 0.1676, Segment True Label Score = 0.0017, SV True Label = 0.0002, SV Predicted Label = -0.0395
#   Segment 4: Predicted Label = 122, Prediction Score = 0.1118, Segment Video Label Score = 0.0334, Segment True Label Score = 0.0066, SV True Label = 0.0016, SV Predicted Label = -0.0776
#   Segment 5: Predicted Label = 149, Prediction Score = 0.9921, Segment Video Label Score = 0.9921, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.1942
#   Segment 6: Predicted Label = 149, Prediction Score = 0.8774, Segment Video Label Score = 0.8774, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.1617
#   Segment 7: Predicted Label = 127, Prediction Score = 0.5743, Segment Video Label Score = 0.0236, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0804
#   Segment 8: Predicted Label = 149, Prediction Score = 0.3811, Segment Video Label Score = 0.3811, Segment True Label Score = 0.0001, SV True Label = -0.0003, SV Predicted Label = 0.0210
# Video: JTlatknwOrY.mp4, Overall Predicted Label = 243, Overall Prediction Score = 0.4549, True Label = 325, True Label Score = 0.0184
#   Segment 1: Predicted Label = 392, Prediction Score = 0.3439, Segment Video Label Score = 0.3148, Segment True Label Score = 0.0000, SV True Label = 0.0008, SV Predicted Label = -0.0362
#   Segment 2: Predicted Label = 392, Prediction Score = 0.8649, Segment Video Label Score = 0.0281, Segment True Label Score = 0.0000, SV True Label = -0.0041, SV Predicted Label = -0.1174
#   Segment 3: Predicted Label = 243, Prediction Score = 0.9382, Segment Video Label Score = 0.9382, Segment True Label Score = 0.0000, SV True Label = -0.0049, SV Predicted Label = 0.1406
#   Segment 4: Predicted Label = 243, Prediction Score = 0.7217, Segment Video Label Score = 0.7217, Segment True Label Score = 0.0000, SV True Label = -0.0048, SV Predicted Label = 0.0792
#   Segment 5: Predicted Label = 243, Prediction Score = 0.2478, Segment Video Label Score = 0.2478, Segment True Label Score = 0.0000, SV True Label = -0.0007, SV Predicted Label = -0.0551
#   Segment 6: Predicted Label = 243, Prediction Score = 0.8982, Segment Video Label Score = 0.8982, Segment True Label Score = 0.0000, SV True Label = -0.0050, SV Predicted Label = 0.1292
#   Segment 7: Predicted Label = 243, Prediction Score = 0.4809, Segment Video Label Score = 0.4809, Segment True Label Score = 0.0000, SV True Label = 0.0024, SV Predicted Label = 0.0109
#   Segment 8: Predicted Label = 249, Prediction Score = 0.1752, Segment Video Label Score = 0.0092, Segment True Label Score = 0.0000, SV True Label = 0.0176, SV Predicted Label = -0.1228
# Video: nK15J54IVCI.mp4, Overall Predicted Label = 233, Overall Prediction Score = 0.9575, True Label = 325, True Label Score = 0.9575
#   Segment 1: Predicted Label = 233, Prediction Score = 0.9665, Segment Video Label Score = 0.9665, Segment True Label Score = 0.0000, SV True Label = 0.0100, SV Predicted Label = 0.0100
#   Segment 2: Predicted Label = 233, Prediction Score = 0.9698, Segment Video Label Score = 0.9698, Segment True Label Score = 0.0000, SV True Label = 0.0110, SV Predicted Label = 0.0110
#   Segment 3: Predicted Label = 233, Prediction Score = 0.9527, Segment Video Label Score = 0.9527, Segment True Label Score = 0.0000, SV True Label = 0.0061, SV Predicted Label = 0.0061
#   Segment 4: Predicted Label = 233, Prediction Score = 0.9495, Segment Video Label Score = 0.9495, Segment True Label Score = 0.0000, SV True Label = 0.0052, SV Predicted Label = 0.0052
#   Segment 5: Predicted Label = 233, Prediction Score = 0.9577, Segment Video Label Score = 0.9577, Segment True Label Score = 0.0000, SV True Label = 0.0076, SV Predicted Label = 0.0076
#   Segment 6: Predicted Label = 233, Prediction Score = 0.9569, Segment Video Label Score = 0.9569, Segment True Label Score = 0.0000, SV True Label = 0.0073, SV Predicted Label = 0.0073
#   Segment 7: Predicted Label = 233, Prediction Score = 0.9396, Segment Video Label Score = 0.9396, Segment True Label Score = 0.0000, SV True Label = 0.0024, SV Predicted Label = 0.0024
#   Segment 8: Predicted Label = 233, Prediction Score = 0.9669, Segment Video Label Score = 0.9669, Segment True Label Score = 0.0000, SV True Label = 0.0101, SV Predicted Label = 0.0101
# Video: 8UxlDNur-Z0.mp4, Overall Predicted Label = 262, Overall Prediction Score = 0.4897, True Label = 325, True Label Score = 0.4897
#   Segment 1: Predicted Label = 267, Prediction Score = 0.3794, Segment Video Label Score = 0.2797, Segment True Label Score = 0.0000, SV True Label = -0.0557, SV Predicted Label = -0.0557
#   Segment 2: Predicted Label = 262, Prediction Score = 0.5964, Segment Video Label Score = 0.5964, Segment True Label Score = 0.0001, SV True Label = 0.0341, SV Predicted Label = 0.0341
#   Segment 3: Predicted Label = 267, Prediction Score = 0.3372, Segment Video Label Score = 0.1509, Segment True Label Score = 0.0001, SV True Label = -0.0922, SV Predicted Label = -0.0922
#   Segment 4: Predicted Label = 267, Prediction Score = 0.3588, Segment Video Label Score = 0.2149, Segment True Label Score = 0.0000, SV True Label = -0.0741, SV Predicted Label = -0.0741
#   Segment 5: Predicted Label = 45, Prediction Score = 0.5598, Segment Video Label Score = 0.1077, Segment True Label Score = 0.0003, SV True Label = -0.1045, SV Predicted Label = -0.1045
#   Segment 6: Predicted Label = 262, Prediction Score = 0.6989, Segment Video Label Score = 0.6989, Segment True Label Score = 0.0009, SV True Label = 0.0631, SV Predicted Label = 0.0631
#   Segment 7: Predicted Label = 262, Prediction Score = 0.9150, Segment Video Label Score = 0.9150, Segment True Label Score = 0.0000, SV True Label = 0.1244, SV Predicted Label = 0.1244
#   Segment 8: Predicted Label = 262, Prediction Score = 0.9540, Segment Video Label Score = 0.9540, Segment True Label Score = 0.0000, SV True Label = 0.1354, SV Predicted Label = 0.1354
# Video: sBwcUtMx2VM.mp4, Overall Predicted Label = 262, Overall Prediction Score = 0.5562, True Label = 325, True Label Score = 0.5562
#   Segment 1: Predicted Label = 262, Prediction Score = 0.8899, Segment Video Label Score = 0.8899, Segment True Label Score = 0.0000, SV True Label = 0.0990, SV Predicted Label = 0.0990
#   Segment 2: Predicted Label = 262, Prediction Score = 0.9884, Segment Video Label Score = 0.9884, Segment True Label Score = 0.0000, SV True Label = 0.1269, SV Predicted Label = 0.1269
#   Segment 3: Predicted Label = 262, Prediction Score = 0.9821, Segment Video Label Score = 0.9821, Segment True Label Score = 0.0000, SV True Label = 0.1251, SV Predicted Label = 0.1251
#   Segment 4: Predicted Label = 262, Prediction Score = 0.6151, Segment Video Label Score = 0.6151, Segment True Label Score = 0.0000, SV True Label = 0.0211, SV Predicted Label = 0.0211
#   Segment 5: Predicted Label = 127, Prediction Score = 0.8559, Segment Video Label Score = 0.0941, Segment True Label Score = 0.0000, SV True Label = -0.1266, SV Predicted Label = -0.1266
#   Segment 6: Predicted Label = 262, Prediction Score = 0.8785, Segment Video Label Score = 0.8785, Segment True Label Score = 0.0000, SV True Label = 0.0957, SV Predicted Label = 0.0957
#   Segment 7: Predicted Label = 127, Prediction Score = 0.6127, Segment Video Label Score = 0.0008, Segment True Label Score = 0.0000, SV True Label = -0.1531, SV Predicted Label = -0.1531
#   Segment 8: Predicted Label = 127, Prediction Score = 0.3598, Segment Video Label Score = 0.0003, Segment True Label Score = 0.0000, SV True Label = -0.1532, SV Predicted Label = -0.1532
# Video: y9r115bgfNk.mp4, Overall Predicted Label = 254, Overall Prediction Score = 0.4981, True Label = 325, True Label Score = 0.0001
#   Segment 1: Predicted Label = 254, Prediction Score = 0.9853, Segment Video Label Score = 0.9853, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.1420
#   Segment 2: Predicted Label = 254, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.1461
#   Segment 3: Predicted Label = 254, Prediction Score = 0.9998, Segment Video Label Score = 0.9998, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.1461
#   Segment 4: Predicted Label = 254, Prediction Score = 0.9998, Segment Video Label Score = 0.9998, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.1461
#   Segment 5: Predicted Label = 123, Prediction Score = 0.7675, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = 0.0001, SV Predicted Label = -0.1373
#   Segment 6: Predicted Label = 123, Prediction Score = 0.7122, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = 0.0000, SV Predicted Label = -0.1373
#   Segment 7: Predicted Label = 123, Prediction Score = 0.8637, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = -0.1373
#   Segment 8: Predicted Label = 212, Prediction Score = 0.5701, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0001, SV True Label = -0.0000, SV Predicted Label = -0.1373
# Video: 1hnDIZGrBGE.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.1153, True Label = 325, True Label Score = 0.0411
#   Segment 1: Predicted Label = 277, Prediction Score = 0.8576, Segment Video Label Score = 0.0356, Segment True Label Score = 0.0000, SV True Label = -0.0113, SV Predicted Label = -0.0217
#   Segment 2: Predicted Label = 147, Prediction Score = 0.1999, Segment Video Label Score = 0.0014, Segment True Label Score = 0.0146, SV True Label = -0.0113, SV Predicted Label = -0.0314
#   Segment 3: Predicted Label = 256, Prediction Score = 0.2095, Segment Video Label Score = 0.0157, Segment True Label Score = 0.0003, SV True Label = -0.0111, SV Predicted Label = -0.0273
#   Segment 4: Predicted Label = 20, Prediction Score = 0.2774, Segment Video Label Score = 0.0968, Segment True Label Score = 0.0034, SV True Label = -0.0111, SV Predicted Label = -0.0044
#   Segment 5: Predicted Label = 233, Prediction Score = 0.7129, Segment Video Label Score = 0.0009, Segment True Label Score = 0.0000, SV True Label = -0.0089, SV Predicted Label = -0.0315
#   Segment 6: Predicted Label = 1, Prediction Score = 0.7297, Segment Video Label Score = 0.7297, Segment True Label Score = 0.0000, SV True Label = -0.0112, SV Predicted Label = 0.1751
#   Segment 7: Predicted Label = 293, Prediction Score = 0.3917, Segment Video Label Score = 0.0357, Segment True Label Score = 0.0000, SV True Label = -0.0112, SV Predicted Label = -0.0217
#   Segment 8: Predicted Label = 320, Prediction Score = 0.3177, Segment Video Label Score = 0.0069, Segment True Label Score = 0.0001, SV True Label = 0.0787, SV Predicted Label = -0.0298
# Video: ZnIDviwA8CE.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.3576, True Label = 325, True Label Score = 0.3576
#   Segment 1: Predicted Label = 244, Prediction Score = 0.9689, Segment Video Label Score = 0.9689, Segment True Label Score = 0.0000, SV True Label = 0.1761, SV Predicted Label = 0.1761
#   Segment 2: Predicted Label = 244, Prediction Score = 0.8593, Segment Video Label Score = 0.8593, Segment True Label Score = 0.0000, SV True Label = 0.1450, SV Predicted Label = 0.1450
#   Segment 3: Predicted Label = 244, Prediction Score = 0.8552, Segment Video Label Score = 0.8552, Segment True Label Score = 0.0000, SV True Label = 0.1439, SV Predicted Label = 0.1439
#   Segment 4: Predicted Label = 233, Prediction Score = 0.3322, Segment Video Label Score = 0.0195, Segment True Label Score = 0.0000, SV True Label = -0.0930, SV Predicted Label = -0.0930
#   Segment 5: Predicted Label = 233, Prediction Score = 0.3794, Segment Video Label Score = 0.0654, Segment True Label Score = 0.0000, SV True Label = -0.0800, SV Predicted Label = -0.0800
#   Segment 6: Predicted Label = 346, Prediction Score = 0.3985, Segment Video Label Score = 0.0688, Segment True Label Score = 0.0000, SV True Label = -0.0791, SV Predicted Label = -0.0791
#   Segment 7: Predicted Label = 134, Prediction Score = 0.1925, Segment Video Label Score = 0.0212, Segment True Label Score = 0.0000, SV True Label = -0.0926, SV Predicted Label = -0.0926
#   Segment 8: Predicted Label = 247, Prediction Score = 0.7648, Segment Video Label Score = 0.0021, Segment True Label Score = 0.0000, SV True Label = -0.0980, SV Predicted Label = -0.0980
# Video: -zpKHNrNsn4.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.9967, True Label = 325, True Label Score = 0.9967
#   Segment 1: Predicted Label = 244, Prediction Score = 0.9954, Segment Video Label Score = 0.9954, Segment True Label Score = 0.0000, SV True Label = 0.0074, SV Predicted Label = 0.0074
#   Segment 2: Predicted Label = 244, Prediction Score = 0.9931, Segment Video Label Score = 0.9931, Segment True Label Score = 0.0000, SV True Label = 0.0068, SV Predicted Label = 0.0068
#   Segment 3: Predicted Label = 244, Prediction Score = 0.9967, Segment Video Label Score = 0.9967, Segment True Label Score = 0.0000, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 4: Predicted Label = 244, Prediction Score = 0.9970, Segment Video Label Score = 0.9970, Segment True Label Score = 0.0000, SV True Label = 0.0079, SV Predicted Label = 0.0079
#   Segment 5: Predicted Label = 244, Prediction Score = 0.9982, Segment Video Label Score = 0.9982, Segment True Label Score = 0.0000, SV True Label = 0.0082, SV Predicted Label = 0.0082
#   Segment 6: Predicted Label = 244, Prediction Score = 0.9972, Segment Video Label Score = 0.9972, Segment True Label Score = 0.0000, SV True Label = 0.0079, SV Predicted Label = 0.0079
#   Segment 7: Predicted Label = 244, Prediction Score = 0.9974, Segment Video Label Score = 0.9974, Segment True Label Score = 0.0000, SV True Label = 0.0080, SV Predicted Label = 0.0080
#   Segment 8: Predicted Label = 244, Prediction Score = 0.9989, Segment Video Label Score = 0.9989, Segment True Label Score = 0.0000, SV True Label = 0.0084, SV Predicted Label = 0.0084
