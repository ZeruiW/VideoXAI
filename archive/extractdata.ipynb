# %%
import os
import shutil
import random
from collections import defaultdict

# 定义路径
label_file = 'kinetics400_val_list_videos.txt'
source_dir = 'videos_val'
target_dir = 'videos_test'

# 每个标签选择的视频数量
n_videos_per_label = 1  # 您可以根据需要更改这个数字

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 读取标签文件并组织数据
label_dict = defaultdict(list)
with open(label_file, 'r') as f:
    for line in f:
        video_name, label = line.strip().split()
        label = int(label)
        label_dict[label].append(video_name)

# 为每个标签随机选择n个视频
selected_videos = {}
for label in range(400):  # 假设标签从0到399
    if label in label_dict:
        videos = label_dict[label]
        n_select = min(n_videos_per_label, len(videos))  # 确保不会选择超过可用的视频数量
        selected_videos[label] = random.sample(videos, n_select)

# 复制选中的视频到目标目录
copied_count = 0
for label, video_names in selected_videos.items():
    for video_name in video_names:
        source_path = os.path.join(source_dir, video_name)
        target_path = os.path.join(target_dir, video_name)
        
        if os.path.exists(source_path):
            shutil.copy2(source_path, target_path)
            print(f"Copied {video_name} (Label: {label}) to {target_dir}")
            copied_count += 1
        else:
            print(f"Warning: {video_name} not found in {source_dir}")

# 打印统计信息
print(f"Total videos copied: {copied_count}")
print(f"Number of labels represented: {len(selected_videos)}")
# Out:
# Copied _aQSjArgAqA.mp4 (Label: 0) to videos_test
# Copied InSYAA9cJOs.mp4 (Label: 1) to videos_test
# Copied dplRiYsjQUk.mp4 (Label: 2) to videos_test
# Copied ohCzKMVmdEE.mp4 (Label: 3) to videos_test
# Copied MMMabYYxsew.mp4 (Label: 4) to videos_test
# Copied -UJgyiWe500.mp4 (Label: 5) to videos_test
# Copied BdMiTo_OtnU.mp4 (Label: 6) to videos_test
# Copied caKc581J6Ek.mp4 (Label: 7) to videos_test
# Copied rWex6zIMd1w.mp4 (Label: 8) to videos_test
# Copied LExCUx4STW0.mp4 (Label: 9) to videos_test
# Copied tSvENDgYfKk.mp4 (Label: 10) to videos_test
# Copied eG0Pu2uM5q0.mp4 (Label: 11) to videos_test
# Copied 2loWBp9BRi0.mp4 (Label: 12) to videos_test
# Copied 8wHTcDaq63g.mp4 (Label: 13) to videos_test
# Copied Qs3OUwmUJNQ.mp4 (Label: 14) to videos_test
# Copied A1rYh-cr67c.mp4 (Label: 15) to videos_test
# Copied 9GI-CTGudp0.mp4 (Label: 16) to videos_test
# Copied MRL_QqebIHE.mp4 (Label: 17) to videos_test
# Copied S7SJdtU9vP4.mp4 (Label: 18) to videos_test
# Copied gtfY2jotzkY.mp4 (Label: 19) to videos_test
# Copied TCRDSwJWKFQ.mp4 (Label: 20) to videos_test
# Copied KfCbcsqQMqs.mp4 (Label: 21) to videos_test
# Copied EVHx8WuPjgY.mp4 (Label: 22) to videos_test
# Copied 6Z267m0nKuo.mp4 (Label: 23) to videos_test
# Copied 9mec-ejMBqQ.mp4 (Label: 24) to videos_test
# Copied HDqZ2xBL3Xs.mp4 (Label: 25) to videos_test
# Copied h-ekL4jR214.mp4 (Label: 26) to videos_test
# Copied LgHB-PEWODk.mp4 (Label: 27) to videos_test
# Copied biiOYwzuhG4.mp4 (Label: 28) to videos_test
# Copied BZ5bWl6t28Y.mp4 (Label: 29) to videos_test
# Copied km8D1oLIyKg.mp4 (Label: 30) to videos_test
# Copied ZlVNRxRSQx8.mp4 (Label: 31) to videos_test
# Copied 0uswr636GWs.mp4 (Label: 32) to videos_test
# Copied Qd5-tUc8L1g.mp4 (Label: 33) to videos_test
# Copied nEemNn9Urww.mp4 (Label: 34) to videos_test
# Copied nqr44CA24Wo.mp4 (Label: 35) to videos_test
# Copied a2WgvBUiNE0.mp4 (Label: 36) to videos_test
# Copied 8NStNQyjIXI.mp4 (Label: 37) to videos_test
# Copied --uGS0Y4D6k.mp4 (Label: 38) to videos_test
# Copied 88NSyUW9fe4.mp4 (Label: 39) to videos_test
# Copied wIKUIInA1ts.mp4 (Label: 40) to videos_test
# Copied 1Ob-133153o.mp4 (Label: 41) to videos_test
# Copied SJfxkFQjS8o.mp4 (Label: 42) to videos_test
# Copied Nz_HZ63FPAI.mp4 (Label: 43) to videos_test
# Copied 38Uv6dbQkWc.mp4 (Label: 44) to videos_test
# Copied douPrLPb8PU.mp4 (Label: 45) to videos_test
# Copied s-HwLkS5Sfo.mp4 (Label: 46) to videos_test
# Copied lymjAF8Yd_I.mp4 (Label: 47) to videos_test
# Copied qfTsYvAa5Gc.mp4 (Label: 48) to videos_test
# Copied 5w7-2_KAP2k.mp4 (Label: 49) to videos_test
# Copied m1dVuEggNe8.mp4 (Label: 50) to videos_test
# Copied 6fyP1T1vbo0.mp4 (Label: 51) to videos_test
# Copied SP5wqmfufQU.mp4 (Label: 52) to videos_test
# Copied cW-E5AVMkwo.mp4 (Label: 53) to videos_test
# Copied YLJaiKWGQys.mp4 (Label: 54) to videos_test
# Copied oGLY8G334yU.mp4 (Label: 55) to videos_test
# Copied aXO-sNzhiE0.mp4 (Label: 56) to videos_test
# Copied 4A_ohVkJGJM.mp4 (Label: 57) to videos_test
# Copied x5h_QLUU59Q.mp4 (Label: 58) to videos_test
# Copied NiYuBZei0aI.mp4 (Label: 59) to videos_test
# Copied 23fL50KlN7U.mp4 (Label: 60) to videos_test
# Copied RUyX7aYQFrA.mp4 (Label: 61) to videos_test
# Copied 4WtZJeAUjho.mp4 (Label: 62) to videos_test
# Copied 7oLqr-alrZc.mp4 (Label: 63) to videos_test
# Copied xV17oEOM64c.mp4 (Label: 64) to videos_test
# Copied Gf7WySUCFWY.mp4 (Label: 65) to videos_test
# Copied C8_aYXTrthw.mp4 (Label: 66) to videos_test
# Copied ZQ041ORm8Vw.mp4 (Label: 67) to videos_test
# Copied lFqM3raiISQ.mp4 (Label: 68) to videos_test
# Copied HluLHzrS7Sc.mp4 (Label: 69) to videos_test
# Copied kbjjQ37YOGw.mp4 (Label: 70) to videos_test
# Copied JXaT0Dced_Q.mp4 (Label: 71) to videos_test
# Copied A8TIWMvJVDU.mp4 (Label: 72) to videos_test
# Copied xOOs_lJ-E2w.mp4 (Label: 73) to videos_test
# Copied xmmrsrAj0tE.mp4 (Label: 74) to videos_test
# Copied fDcujV8hkS8.mp4 (Label: 75) to videos_test
# Copied xnC3nngvLCo.mp4 (Label: 76) to videos_test
# Copied _lFH0L9EsmY.mp4 (Label: 77) to videos_test
# Copied p_WUzfanwE0.mp4 (Label: 78) to videos_test
# Copied O4jKum4nNQY.mp4 (Label: 79) to videos_test
# Copied dVHwTbKxrN4.mp4 (Label: 80) to videos_test
# Copied 575qtLq2trc.mp4 (Label: 81) to videos_test
# Copied 5sXubRXt6Q0.mp4 (Label: 82) to videos_test
# Copied 0-NbSopwDlk.mp4 (Label: 83) to videos_test
# Copied FRsV4HLKJ_4.mp4 (Label: 84) to videos_test
# Copied NmeMnIa36_w.mp4 (Label: 85) to videos_test
# Copied CgRxzu3r7LQ.mp4 (Label: 86) to videos_test
# Copied 6Q7tpnuI6YI.mp4 (Label: 87) to videos_test
# Copied TZ0wC5-x1XQ.mp4 (Label: 88) to videos_test
# Copied i0KHMuugfV0.mp4 (Label: 89) to videos_test
# Copied B__pr_4s7vY.mp4 (Label: 90) to videos_test
# Copied RR18KL8GSe4.mp4 (Label: 91) to videos_test
# Copied bMCDoCW3GWY.mp4 (Label: 92) to videos_test
# Copied EKzhNFxJQ4Q.mp4 (Label: 93) to videos_test
# Copied 7AyNmGlivyE.mp4 (Label: 94) to videos_test
# Copied Kx8NGDnS46M.mp4 (Label: 95) to videos_test
# Copied 6IbdUPJMeF8.mp4 (Label: 96) to videos_test
# Copied -GUDZKovNL4.mp4 (Label: 97) to videos_test
# Copied GTs3ZLA32PU.mp4 (Label: 98) to videos_test
# Copied wCTJ9bKn_sI.mp4 (Label: 99) to videos_test
# Copied bBqTvmNOaeA.mp4 (Label: 100) to videos_test
# Copied xS3kBfbNQX8.mp4 (Label: 101) to videos_test
# Copied 2ib0zTt3JGc.mp4 (Label: 102) to videos_test
# Copied xcxcGeFv0i0.mp4 (Label: 103) to videos_test
# Copied 82iM2hFQMnA.mp4 (Label: 104) to videos_test
# Copied m0mo6zbBkGc.mp4 (Label: 105) to videos_test
# Copied PUOQlOkZVWg.mp4 (Label: 106) to videos_test
# Copied -5jFf2thMKg.mp4 (Label: 107) to videos_test
# Copied ir_8tuJNOwo.mp4 (Label: 108) to videos_test
# Copied G26_gmBHCx4.mp4 (Label: 109) to videos_test
# Copied d4IhT7ZcfJY.mp4 (Label: 110) to videos_test
# Copied bp3tvU5mw-s.mp4 (Label: 111) to videos_test
# Copied I5Y53-Q9KRo.mp4 (Label: 112) to videos_test
# Copied vF1bLkU-QfM.mp4 (Label: 113) to videos_test
# Copied Y_WxKHxPmTQ.mp4 (Label: 114) to videos_test
# Copied YH_2tWoQKH4.mp4 (Label: 115) to videos_test
# Copied 16PMCXn0VXg.mp4 (Label: 116) to videos_test
# Copied sP6BSwCx1hc.mp4 (Label: 117) to videos_test
# Copied 2wIcUAH9yaM.mp4 (Label: 118) to videos_test
# Copied R9J4hyxxqC0.mp4 (Label: 119) to videos_test
# Copied a0lb9J07s_o.mp4 (Label: 120) to videos_test
# Copied cSY-r9K29wI.mp4 (Label: 121) to videos_test
# Copied iVLuQ9fIW6s.mp4 (Label: 122) to videos_test
# Copied WP63Jg8CDdg.mp4 (Label: 123) to videos_test
# Copied UMSboAcK6PM.mp4 (Label: 124) to videos_test
# Copied ZzKo1iI4cow.mp4 (Label: 125) to videos_test
# Copied zotsqqdK9lg.mp4 (Label: 126) to videos_test
# Copied MxdiNWg3ADs.mp4 (Label: 127) to videos_test
# Copied 3pfkq-LmxGw.mp4 (Label: 128) to videos_test
# Copied 6ilMfOk26dA.mp4 (Label: 129) to videos_test
# Copied pK0BTaG7QOo.mp4 (Label: 130) to videos_test
# Copied xzlOBN5z4uw.mp4 (Label: 131) to videos_test
# Copied dFOZOugwfg4.mp4 (Label: 132) to videos_test
# Copied _dWpzz8ng9U.mp4 (Label: 133) to videos_test
# Copied B63YUwWcA_8.mp4 (Label: 134) to videos_test
# Copied 21QPeww0HuA.mp4 (Label: 135) to videos_test
# Copied fwFDPukVgJs.mp4 (Label: 136) to videos_test
# Copied lZTso1hS7Jw.mp4 (Label: 137) to videos_test
# Copied f4Fk9DrDmJA.mp4 (Label: 138) to videos_test
# Copied EpG7-6kJrM8.mp4 (Label: 139) to videos_test
# Copied 4mIPkSk3YK8.mp4 (Label: 140) to videos_test
# Copied k1-xurY-I3Y.mp4 (Label: 141) to videos_test
# Copied GO1d1Swou5Y.mp4 (Label: 142) to videos_test
# Copied mQlwfIqT0YQ.mp4 (Label: 143) to videos_test
# Copied G_Z4UsLFrN8.mp4 (Label: 144) to videos_test
# Copied odizEwdAkMA.mp4 (Label: 145) to videos_test
# Copied IneM43S8Ieo.mp4 (Label: 146) to videos_test
# Copied XNvvPdzAiNw.mp4 (Label: 147) to videos_test
# Copied eE25lph7alo.mp4 (Label: 148) to videos_test
# Copied mbUvCCPGc28.mp4 (Label: 149) to videos_test
# Copied uozo0l3Wtqg.mp4 (Label: 150) to videos_test
# Copied fvbyaTREDCY.mp4 (Label: 151) to videos_test
# Copied Jozpg64DEh0.mp4 (Label: 152) to videos_test
# Copied uoRO19PQEWA.mp4 (Label: 153) to videos_test
# Copied GJ7EGQEyZvc.mp4 (Label: 154) to videos_test
# Copied neHJsZ7hg3w.mp4 (Label: 155) to videos_test
# Copied rcfxlQIk6aY.mp4 (Label: 156) to videos_test
# Copied gQK2cs6v9OQ.mp4 (Label: 157) to videos_test
# Copied 2V3T7VwWt2c.mp4 (Label: 158) to videos_test
# Copied evd1BOpj4YE.mp4 (Label: 159) to videos_test
# Copied V7WWYi7kGwA.mp4 (Label: 160) to videos_test
# Copied ZwIOFrsj1rI.mp4 (Label: 161) to videos_test
# Copied 7wnOMqHkkXM.mp4 (Label: 162) to videos_test
# Copied ziRHCx9gvFk.mp4 (Label: 163) to videos_test
# Copied V1Q_OqnloNk.mp4 (Label: 164) to videos_test
# Copied sVqL0mHcYgY.mp4 (Label: 165) to videos_test
# Copied GKK32IWDlSE.mp4 (Label: 166) to videos_test
# Copied 65kTXl2I9g4.mp4 (Label: 167) to videos_test
# Copied gQjTIrPQhnY.mp4 (Label: 168) to videos_test
# Copied 1cIrRGn5mmQ.mp4 (Label: 169) to videos_test
# Copied ZautLHJlWHk.mp4 (Label: 170) to videos_test
# Copied XZivRFQTvuM.mp4 (Label: 171) to videos_test
# Copied 9SNs8AVadi8.mp4 (Label: 172) to videos_test
# Copied AIFOKQUDfK8.mp4 (Label: 173) to videos_test
# Copied _OrvyygUV-g.mp4 (Label: 174) to videos_test
# Copied xKTjmCBd9to.mp4 (Label: 175) to videos_test
# Copied jPqNILLZoTI.mp4 (Label: 176) to videos_test
# Copied j6VaRVmEwPU.mp4 (Label: 177) to videos_test
# Copied glcVei9aPXY.mp4 (Label: 178) to videos_test
# Copied GTr3wXCclpM.mp4 (Label: 179) to videos_test
# Copied zsnU7rt_Qq0.mp4 (Label: 180) to videos_test
# Copied Rvs6_1yLmzA.mp4 (Label: 181) to videos_test
# Copied lIF5SyZn-ZQ.mp4 (Label: 182) to videos_test
# Copied 7IhilQhiNaE.mp4 (Label: 183) to videos_test
# Copied QEUdjS3DTKc.mp4 (Label: 184) to videos_test
# Copied RbhxGol5G8I.mp4 (Label: 185) to videos_test
# Copied sGUIPnRiauQ.mp4 (Label: 186) to videos_test
# Copied wMWkwQ7HXik.mp4 (Label: 187) to videos_test
# Copied sQZbXuQCrpg.mp4 (Label: 188) to videos_test
# Copied fV0j7Izw_m8.mp4 (Label: 189) to videos_test
# Copied -xg5mnJy1mA.mp4 (Label: 190) to videos_test
# Copied 3CLScUQPBk0.mp4 (Label: 191) to videos_test
# Copied IgKFqseG-9c.mp4 (Label: 192) to videos_test
# Copied mEHxbKEMe28.mp4 (Label: 193) to videos_test
# Copied PcXRWmzyTM8.mp4 (Label: 194) to videos_test
# Copied p1Tf9rKotCU.mp4 (Label: 195) to videos_test
# Copied rqBivpdlaNA.mp4 (Label: 196) to videos_test
# Copied -0-s1eu4sF4.mp4 (Label: 197) to videos_test
# Copied tAHyrcBt8ZM.mp4 (Label: 198) to videos_test
# Copied -0L4fgr5GE0.mp4 (Label: 199) to videos_test
# Copied saGVOe4M7ho.mp4 (Label: 200) to videos_test
# Copied wG1wBA9lyJE.mp4 (Label: 201) to videos_test
# Copied 2JnyfNF8Kno.mp4 (Label: 202) to videos_test
# Copied cjv_8awzeyo.mp4 (Label: 203) to videos_test
# Copied 61PNTePbtwY.mp4 (Label: 204) to videos_test
# Copied 5C3Gyqp-iUA.mp4 (Label: 205) to videos_test
# Copied d4ZgqL4bf9Q.mp4 (Label: 206) to videos_test
# Copied EEHDOVEfXRk.mp4 (Label: 207) to videos_test
# Copied fWKNCJr_RxA.mp4 (Label: 208) to videos_test
# Copied wDV6b2lclRs.mp4 (Label: 209) to videos_test
# Copied 87DmVgUFSSM.mp4 (Label: 210) to videos_test
# Copied CGn5KMLiNYU.mp4 (Label: 211) to videos_test
# Copied QxQ1tua9D_8.mp4 (Label: 212) to videos_test
# Copied beczHkrGKTE.mp4 (Label: 213) to videos_test
# Copied 2TWoNKBLq3w.mp4 (Label: 214) to videos_test
# Copied RpB8mbXb4FY.mp4 (Label: 215) to videos_test
# Copied 6BRIJxpfWPs.mp4 (Label: 216) to videos_test
# Copied yX4IfOAat4s.mp4 (Label: 217) to videos_test
# Copied R2rFq0iwMjQ.mp4 (Label: 218) to videos_test
# Copied utoq4gnDkS8.mp4 (Label: 219) to videos_test
# Copied l3Bx9TtjNKE.mp4 (Label: 220) to videos_test
# Copied 5iCQL3IN47M.mp4 (Label: 221) to videos_test
# Copied kVAz43lk8p8.mp4 (Label: 222) to videos_test
# Copied gsNLRX0NjIw.mp4 (Label: 223) to videos_test
# Copied Xkh86mum2ws.mp4 (Label: 224) to videos_test
# Copied zNBieYzIbxk.mp4 (Label: 225) to videos_test
# Copied axi62jA7Ft8.mp4 (Label: 226) to videos_test
# Copied lgPslaxBQt0.mp4 (Label: 227) to videos_test
# Copied pYFSdWL7aIo.mp4 (Label: 228) to videos_test
# Copied GOyyglYYzSI.mp4 (Label: 229) to videos_test
# Copied kXhnTK9TVsU.mp4 (Label: 230) to videos_test
# Copied t1ni9cjLRl4.mp4 (Label: 231) to videos_test
# Copied meMLnQoTKB8.mp4 (Label: 232) to videos_test
# Copied 9IwHB4agZTs.mp4 (Label: 233) to videos_test
# Copied g-onpXcXseM.mp4 (Label: 234) to videos_test
# Copied B4XOE5mspq8.mp4 (Label: 235) to videos_test
# Copied 4Qj5PYB6gyY.mp4 (Label: 236) to videos_test
# Copied N2FU_lX6Vw0.mp4 (Label: 237) to videos_test
# Copied VueBDRwia2w.mp4 (Label: 238) to videos_test
# Copied vYOwI1Q-l60.mp4 (Label: 239) to videos_test
# Copied joJS5OOHssc.mp4 (Label: 240) to videos_test
# Copied -6wNVod8iag.mp4 (Label: 241) to videos_test
# Copied hdw4u7D5aIw.mp4 (Label: 242) to videos_test
# Copied 7yrZgpJ3WMk.mp4 (Label: 243) to videos_test
# Copied 6dUY8QB2j8g.mp4 (Label: 244) to videos_test
# Copied jzBR9ihZBbI.mp4 (Label: 245) to videos_test
# Copied 04qp3eQSmJc.mp4 (Label: 246) to videos_test
# Copied 5w3R0qPj0u0.mp4 (Label: 247) to videos_test
# Copied iz8en2Dt7vE.mp4 (Label: 248) to videos_test
# Copied yYP7gwEjaf8.mp4 (Label: 249) to videos_test
# Copied Y9_AJlP0iUY.mp4 (Label: 250) to videos_test
# Copied 8z-LarQ0vf4.mp4 (Label: 251) to videos_test
# Copied VvckL4ljuBY.mp4 (Label: 252) to videos_test
# Copied HaikY17MPVI.mp4 (Label: 253) to videos_test
# Copied vCDvnBv3qK0.mp4 (Label: 254) to videos_test
# Copied dtvtA7H_Y1M.mp4 (Label: 255) to videos_test
# Copied UGlJS-x2xlk.mp4 (Label: 256) to videos_test
# Copied mfBG9e8H3v4.mp4 (Label: 257) to videos_test
# Copied thfy8cT2Y7w.mp4 (Label: 258) to videos_test
# Copied BKKZwGtb0HQ.mp4 (Label: 259) to videos_test
# Copied -51he86iZCY.mp4 (Label: 260) to videos_test
# Copied bBZcjsU0yuE.mp4 (Label: 261) to videos_test
# Copied tTnSSf52RFM.mp4 (Label: 262) to videos_test
# Copied Ykfa-__4qx0.mp4 (Label: 263) to videos_test
# Copied bChJsbogxs4.mp4 (Label: 264) to videos_test
# Copied Dvomn3IAnmk.mp4 (Label: 265) to videos_test
# Copied KFuSpD9XUxg.mp4 (Label: 266) to videos_test
# Copied kNoAzs8ADFo.mp4 (Label: 267) to videos_test
# Copied z8rNn0lEm7o.mp4 (Label: 268) to videos_test
# Copied _kAIMDkIKdw.mp4 (Label: 269) to videos_test
# Copied 7bTTOF80LII.mp4 (Label: 270) to videos_test
# Copied 9SMKZVbMSwM.mp4 (Label: 271) to videos_test
# Copied uWW7jSZfrYs.mp4 (Label: 272) to videos_test
# Copied SZbwKrk-K_g.mp4 (Label: 273) to videos_test
# Copied jt7osTBdLaI.mp4 (Label: 274) to videos_test
# Copied DCMjjC63AD4.mp4 (Label: 275) to videos_test
# Copied UKu3-g_xH9s.mp4 (Label: 276) to videos_test
# Copied qFjPNVIYFgE.mp4 (Label: 277) to videos_test
# Copied wN4aMquYEKc.mp4 (Label: 278) to videos_test
# Copied vopRvtcVBkA.mp4 (Label: 279) to videos_test
# Copied UnV16iU9FzI.mp4 (Label: 280) to videos_test
# Copied mU_u3FI83Jc.mp4 (Label: 281) to videos_test
# Copied X5Nyzma9Gp0.mp4 (Label: 282) to videos_test
# Copied uMtGlIwGUgY.mp4 (Label: 283) to videos_test
# Copied Dd8clccI5_w.mp4 (Label: 284) to videos_test
# Copied -5RvkhL92b4.mp4 (Label: 285) to videos_test
# Copied lENHaFh5DOI.mp4 (Label: 286) to videos_test
# Copied bf_iv5ZBEcg.mp4 (Label: 287) to videos_test
# Copied b8vAhQSYN-g.mp4 (Label: 288) to videos_test
# Copied 1U7II3wMFnc.mp4 (Label: 289) to videos_test
# Copied xosZJ5uRCbs.mp4 (Label: 290) to videos_test
# Copied Xo_ULY5HZrw.mp4 (Label: 291) to videos_test
# Copied fahLfdkXuJ0.mp4 (Label: 292) to videos_test
# Copied hesqM3bnFQI.mp4 (Label: 293) to videos_test
# Copied Z5z7eM4ni8Y.mp4 (Label: 294) to videos_test
# Copied rSTXxDLYxTQ.mp4 (Label: 295) to videos_test
# Copied 61Z36GSHLx4.mp4 (Label: 296) to videos_test
# Copied zNiy_rf_m4Y.mp4 (Label: 297) to videos_test
# Copied Zwr2kd-d2ss.mp4 (Label: 298) to videos_test
# Copied DF9HG1w5nZA.mp4 (Label: 299) to videos_test
# Copied 66HbjBfN_o4.mp4 (Label: 300) to videos_test
# Copied SbfJ7oTh5qA.mp4 (Label: 301) to videos_test
# Copied Pjt1X924mro.mp4 (Label: 302) to videos_test
# Copied GTiGQtH8bdI.mp4 (Label: 303) to videos_test
# Copied eEX40rTNDKg.mp4 (Label: 304) to videos_test
# Copied D--Fa71ta14.mp4 (Label: 305) to videos_test
# Copied MMmejgavKLY.mp4 (Label: 306) to videos_test
# Copied XQUsRpJ1A_Y.mp4 (Label: 307) to videos_test
# Copied hUZNKV9XwOw.mp4 (Label: 308) to videos_test
# Copied TKyLZ-iODkM.mp4 (Label: 309) to videos_test
# Copied MMSVjiTi6YQ.mp4 (Label: 310) to videos_test
# Copied CMVFSoI5Dlw.mp4 (Label: 311) to videos_test
# Copied 8V9HEpWUvto.mp4 (Label: 312) to videos_test
# Copied iLj4i4fTzn0.mp4 (Label: 313) to videos_test
# Copied Nu3ya30pu5o.mp4 (Label: 314) to videos_test
# Copied Kr4iUI1mTZY.mp4 (Label: 315) to videos_test
# Copied EbRJ9qx31AM.mp4 (Label: 316) to videos_test
# Copied VupJjJi8YrU.mp4 (Label: 317) to videos_test
# Copied Mv0sYuwaFXU.mp4 (Label: 318) to videos_test
# Copied -ayNZ5bs7EQ.mp4 (Label: 319) to videos_test
# Copied _YFUVYwuHSg.mp4 (Label: 320) to videos_test
# Copied tYcL5hKUGh0.mp4 (Label: 321) to videos_test
# Copied s0YiB_LsJEk.mp4 (Label: 322) to videos_test
# Copied 98fjxe2PIeA.mp4 (Label: 323) to videos_test
# Copied f3DsbfHdL8w.mp4 (Label: 324) to videos_test
# Copied JypdFku71jo.mp4 (Label: 325) to videos_test
# Copied qAY_lryy0j4.mp4 (Label: 326) to videos_test
# Copied XOUMPB-p1Bw.mp4 (Label: 327) to videos_test
# Copied YYM0nLy1q2M.mp4 (Label: 328) to videos_test
# Copied inFPa4wxOwQ.mp4 (Label: 329) to videos_test
# Copied yKe59rvOqRI.mp4 (Label: 330) to videos_test
# Copied -daBSTzifXA.mp4 (Label: 331) to videos_test
# Copied 2I3GHwg0OOs.mp4 (Label: 332) to videos_test
# Copied hgJqQBBTDRs.mp4 (Label: 333) to videos_test
# Copied zJK2vmCejto.mp4 (Label: 334) to videos_test
# Copied Cg-exRi1Qec.mp4 (Label: 335) to videos_test
# Copied YUoSliVSEh0.mp4 (Label: 336) to videos_test
# Copied 38ibwbAsJec.mp4 (Label: 337) to videos_test
# Copied dgQo1UGs0HA.mp4 (Label: 338) to videos_test
# Copied yWgIdWZksAU.mp4 (Label: 339) to videos_test
# Copied BX-dyfoGFsE.mp4 (Label: 340) to videos_test
# Copied YkIHY4SuO5Y.mp4 (Label: 341) to videos_test
# Copied br8nzdlk5eM.mp4 (Label: 342) to videos_test
# Copied eRuf8ZxHyik.mp4 (Label: 343) to videos_test
# Copied jaB-Eey0now.mp4 (Label: 344) to videos_test
# Copied JpLrWNjyaQU.mp4 (Label: 345) to videos_test
# Copied 8fyMEDcWBgE.mp4 (Label: 346) to videos_test
# Copied H3LR-XTm2FA.mp4 (Label: 347) to videos_test
# Copied iiQrdMwNask.mp4 (Label: 348) to videos_test
# Copied n15ydcfmZCQ.mp4 (Label: 349) to videos_test
# Copied U6N13ypiGoc.mp4 (Label: 350) to videos_test
# Copied 1ITFUe7Bq1k.mp4 (Label: 351) to videos_test
# Copied v6iqztjFdZs.mp4 (Label: 352) to videos_test
# Copied pITuRPnrT-4.mp4 (Label: 353) to videos_test
# Copied Tk23j3MFTWc.mp4 (Label: 354) to videos_test
# Copied mR83rJP3COE.mp4 (Label: 355) to videos_test
# Copied 4z0GhHvdsEw.mp4 (Label: 356) to videos_test
# Copied GXO1eYu4kr8.mp4 (Label: 357) to videos_test
# Copied hseVr8WcD-k.mp4 (Label: 358) to videos_test
# Copied Zm3BQu7eJUI.mp4 (Label: 359) to videos_test
# Copied YfijDjlZt3o.mp4 (Label: 360) to videos_test
# Copied DccaaIQtcx4.mp4 (Label: 361) to videos_test
# Copied 0RnlrsxG1hY.mp4 (Label: 362) to videos_test
# Copied IPwow0Io2FA.mp4 (Label: 363) to videos_test
# Copied xbAmVPhTsoE.mp4 (Label: 364) to videos_test
# Copied puSEdy6iHQY.mp4 (Label: 365) to videos_test
# Copied EvA5ETD9BlY.mp4 (Label: 366) to videos_test
# Copied w4KU248Q-J8.mp4 (Label: 367) to videos_test
# Copied pqboxf6aJhU.mp4 (Label: 368) to videos_test
# Copied YwteBgI1yy4.mp4 (Label: 369) to videos_test
# Copied 7Mtprt8_bqM.mp4 (Label: 370) to videos_test
# Copied AaPaXxmsTgg.mp4 (Label: 371) to videos_test
# Copied 7E890_Y8ojQ.mp4 (Label: 372) to videos_test
# Copied aVqY4HTeBfE.mp4 (Label: 373) to videos_test
# Copied Bj7_KWKEXp8.mp4 (Label: 374) to videos_test
# Copied aVXC13LEJgU.mp4 (Label: 375) to videos_test
# Copied dSI1jGIDjbg.mp4 (Label: 376) to videos_test
# Copied X2ZnwSZAF2Y.mp4 (Label: 377) to videos_test
# Copied EjTUh7ki-jM.mp4 (Label: 378) to videos_test
# Copied XAnhwRZE1iQ.mp4 (Label: 379) to videos_test
# Copied TbK8WAaJPks.mp4 (Label: 380) to videos_test
# Copied OrJ-qtdCN4E.mp4 (Label: 381) to videos_test
# Copied 96ADEnJy4GU.mp4 (Label: 382) to videos_test
# Copied E12xk-88SvM.mp4 (Label: 383) to videos_test
# Copied euBH_EPfuns.mp4 (Label: 384) to videos_test
# Copied 9M282d6-CXY.mp4 (Label: 385) to videos_test
# Copied tuQLgJPfvfA.mp4 (Label: 386) to videos_test
# Copied zX8mLojq_BY.mp4 (Label: 387) to videos_test
# Copied ZbahL_7Qub8.mp4 (Label: 388) to videos_test
# Copied 8dCn0eGepTI.mp4 (Label: 389) to videos_test
# Copied WkQMmkPhDvc.mp4 (Label: 390) to videos_test
# Copied vpsm5IzjOt0.mp4 (Label: 391) to videos_test
# Copied KFOWZBfLHrA.mp4 (Label: 392) to videos_test
# Copied V9p05KSMrgg.mp4 (Label: 393) to videos_test
# Copied 9Vfv3ox2gM8.mp4 (Label: 394) to videos_test
# Copied CFLYr9t7oVs.mp4 (Label: 395) to videos_test
# Copied zR7QR6JxyRs.mp4 (Label: 396) to videos_test
# Copied kfJBMICX5qY.mp4 (Label: 397) to videos_test
# Copied 9-3aPLdF8CU.mp4 (Label: 398) to videos_test
# Copied QcXdaGEK9yU.mp4 (Label: 399) to videos_test
# Total videos copied: 400
# Number of labels represented: 400
