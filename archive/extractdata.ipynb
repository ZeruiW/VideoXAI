# %%
import os
import shutil
import random
from collections import defaultdict

# 定义路径
label_file = 'kinetics400_val_list_videos.txt'
source_dir = 'videos_val'
target_dir = 'videos_test'

# 每个标签选择的视频数量
n_videos_per_label = 1  # 您可以根据需要更改这个数字

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 读取标签文件并组织数据
label_dict = defaultdict(list)
with open(label_file, 'r') as f:
    for line in f:
        video_name, label = line.strip().split()
        label = int(label)
        label_dict[label].append(video_name)

# 为每个标签随机选择n个视频
selected_videos = {}
for label in range(400):  # 假设标签从0到399
    if label in label_dict:
        videos = label_dict[label]
        n_select = min(n_videos_per_label, len(videos))  # 确保不会选择超过可用的视频数量
        selected_videos[label] = random.sample(videos, n_select)

# 复制选中的视频到目标目录
copied_count = 0
for label, video_names in selected_videos.items():
    for video_name in video_names:
        source_path = os.path.join(source_dir, video_name)
        target_path = os.path.join(target_dir, video_name)
        
        if os.path.exists(source_path):
            shutil.copy2(source_path, target_path)
            print(f"Copied {video_name} (Label: {label}) to {target_dir}")
            copied_count += 1
        else:
            print(f"Warning: {video_name} not found in {source_dir}")

# 打印统计信息
print(f"Total videos copied: {copied_count}")
print(f"Number of labels represented: {len(selected_videos)}")
# Out:
# Copied YqTT34PsD5c.mp4 (Label: 0) to videos_test
# Copied f7Z6BmBkcq4.mp4 (Label: 1) to videos_test
# Copied c6n1_Br_Gi0.mp4 (Label: 2) to videos_test
# Copied -PgjjBi_gqM.mp4 (Label: 3) to videos_test
# Copied U3_S9Fs3hFQ.mp4 (Label: 4) to videos_test
# Copied 0S-P4lr_c7s.mp4 (Label: 5) to videos_test
# Copied hCZlftwQj-4.mp4 (Label: 6) to videos_test
# Copied jR-_X0LqwpY.mp4 (Label: 7) to videos_test
# Copied eczjBrvBzxo.mp4 (Label: 8) to videos_test
# Copied lGwuTaLti8Y.mp4 (Label: 9) to videos_test
# Copied n0807kumDTM.mp4 (Label: 10) to videos_test
# Copied _QB3Wxlvgug.mp4 (Label: 11) to videos_test
# Copied IoDjDQTv-q0.mp4 (Label: 12) to videos_test
# Copied _qTc6uZUzKU.mp4 (Label: 13) to videos_test
# Copied n5bKEGvBr5Y.mp4 (Label: 14) to videos_test
# Copied bXYwMTc9rHA.mp4 (Label: 15) to videos_test
# Copied zvWzFXOZwPE.mp4 (Label: 16) to videos_test
# Copied 6FqS59XxFNY.mp4 (Label: 17) to videos_test
# Copied lh7MkOo4jzI.mp4 (Label: 18) to videos_test
# Copied NcjNaEwL9hY.mp4 (Label: 19) to videos_test
# Copied Xys2glt0KaA.mp4 (Label: 20) to videos_test
# Copied Tt3EdH8xjTg.mp4 (Label: 21) to videos_test
# Copied 4CPpUCKy4OU.mp4 (Label: 22) to videos_test
# Copied ZVFI6XbK5ts.mp4 (Label: 23) to videos_test
# Copied kVoAhyyy3v0.mp4 (Label: 24) to videos_test
# Copied 9iytLJcY9gk.mp4 (Label: 25) to videos_test
# Copied eG-DeM1L2GA.mp4 (Label: 26) to videos_test
# Copied 4-9_szZr2xo.mp4 (Label: 27) to videos_test
# Copied iZXtwb_6GMQ.mp4 (Label: 28) to videos_test
# Copied u-pohRNlD6Q.mp4 (Label: 29) to videos_test
# Copied SgKsAhSyibY.mp4 (Label: 30) to videos_test
# Copied --dVV4_CSvw.mp4 (Label: 31) to videos_test
# Copied g6YjwYGwSlI.mp4 (Label: 32) to videos_test
# Copied z_ZK-kDGAdw.mp4 (Label: 33) to videos_test
# Copied MZmI_j8KUDU.mp4 (Label: 34) to videos_test
# Copied Vv_en5jttuY.mp4 (Label: 35) to videos_test
# Copied bQ7CWiB6TAg.mp4 (Label: 36) to videos_test
# Copied 1ZkogIfJNR8.mp4 (Label: 37) to videos_test
# Copied dSCtKL2kuOg.mp4 (Label: 38) to videos_test
# Copied i68ugk-w8jE.mp4 (Label: 39) to videos_test
# Copied BOqR-dhHu4o.mp4 (Label: 40) to videos_test
# Copied td7ZHHY8eKw.mp4 (Label: 41) to videos_test
# Copied L1mDlSDbb9k.mp4 (Label: 42) to videos_test
# Copied Nz_HZ63FPAI.mp4 (Label: 43) to videos_test
# Copied VgqbAvvnbdc.mp4 (Label: 44) to videos_test
# Copied h4i6EtHHemk.mp4 (Label: 45) to videos_test
# Copied -8jPV06bmhA.mp4 (Label: 46) to videos_test
# Copied sGiurZObjXU.mp4 (Label: 47) to videos_test
# Copied l_9GEyNNkJU.mp4 (Label: 48) to videos_test
# Copied -6k2ntyDP-c.mp4 (Label: 49) to videos_test
# Copied _5H3uP9Pp_4.mp4 (Label: 50) to videos_test
# Copied Y2B4DYzva8s.mp4 (Label: 51) to videos_test
# Copied eWXlBDGqq4I.mp4 (Label: 52) to videos_test
# Copied w7JiFVteEkQ.mp4 (Label: 53) to videos_test
# Copied BqX7dCrqAyA.mp4 (Label: 54) to videos_test
# Copied CXC3mTNNQu4.mp4 (Label: 55) to videos_test
# Copied m6yPz9fHJnY.mp4 (Label: 56) to videos_test
# Copied h11nI-9JZOA.mp4 (Label: 57) to videos_test
# Copied QRQfX7aUPqs.mp4 (Label: 58) to videos_test
# Copied sSuVVd9H43E.mp4 (Label: 59) to videos_test
# Copied 4k8MOsQ9VTM.mp4 (Label: 60) to videos_test
# Copied EZW9kLri-IU.mp4 (Label: 61) to videos_test
# Copied LoBd3OwfH7I.mp4 (Label: 62) to videos_test
# Copied iitmlePIA_w.mp4 (Label: 63) to videos_test
# Copied lS6hlWYnFJY.mp4 (Label: 64) to videos_test
# Copied OkjgIFol_qQ.mp4 (Label: 65) to videos_test
# Copied 0tIJZogdc9U.mp4 (Label: 66) to videos_test
# Copied 4QbjK2_ilTI.mp4 (Label: 67) to videos_test
# Copied 1-Ib4KHQG_o.mp4 (Label: 68) to videos_test
# Copied 2HKThTgoGgU.mp4 (Label: 69) to videos_test
# Copied HpCrqtLAVkE.mp4 (Label: 70) to videos_test
# Copied NZwDYzuwn3E.mp4 (Label: 71) to videos_test
# Copied kEem16uZpj0.mp4 (Label: 72) to videos_test
# Copied zHtZV7K0CmY.mp4 (Label: 73) to videos_test
# Copied LE1E-RNJ5nY.mp4 (Label: 74) to videos_test
# Copied zta-Iv-xK7I.mp4 (Label: 75) to videos_test
# Copied vet-EO2e4OY.mp4 (Label: 76) to videos_test
# Copied kASHckXd5gw.mp4 (Label: 77) to videos_test
# Copied uvPzX-Ti3cY.mp4 (Label: 78) to videos_test
# Copied UgMaD1Yv8i8.mp4 (Label: 79) to videos_test
# Copied lQOvNQHgoQs.mp4 (Label: 80) to videos_test
# Copied vNckPkeAI98.mp4 (Label: 81) to videos_test
# Copied blq__c14hGQ.mp4 (Label: 82) to videos_test
# Copied ffX7jCXs9sY.mp4 (Label: 83) to videos_test
# Copied NtUqv__6vdU.mp4 (Label: 84) to videos_test
# Copied oYEGRzzZfQI.mp4 (Label: 85) to videos_test
# Copied 0uGdiI1Rz_8.mp4 (Label: 86) to videos_test
# Copied -bOgXBuuge0.mp4 (Label: 87) to videos_test
# Copied U7B_CxhXgYM.mp4 (Label: 88) to videos_test
# Copied 0zbsWDsctMM.mp4 (Label: 89) to videos_test
# Copied -5LEMasZdOc.mp4 (Label: 90) to videos_test
# Copied cT_RNSRYNtE.mp4 (Label: 91) to videos_test
# Copied eCDR84avtAI.mp4 (Label: 92) to videos_test
# Copied N_eEvki6IYQ.mp4 (Label: 93) to videos_test
# Copied fGI_r0408Sw.mp4 (Label: 94) to videos_test
# Copied 9VTB4PiArAk.mp4 (Label: 95) to videos_test
# Copied JUF5uUhA3fo.mp4 (Label: 96) to videos_test
# Copied y67XqHwNZSo.mp4 (Label: 97) to videos_test
# Copied pVqwSkinQkE.mp4 (Label: 98) to videos_test
# Copied 4tn_mEgISZY.mp4 (Label: 99) to videos_test
# Copied baZKgZy9wdI.mp4 (Label: 100) to videos_test
# Copied qqrnC0WAZlI.mp4 (Label: 101) to videos_test
# Copied Wb5yXP_BPck.mp4 (Label: 102) to videos_test
# Copied c8n1096ZMFA.mp4 (Label: 103) to videos_test
# Copied eKrDYm11Y7s.mp4 (Label: 104) to videos_test
# Copied pvuiN-G8-yc.mp4 (Label: 105) to videos_test
# Copied A4JP5GTOf4k.mp4 (Label: 106) to videos_test
# Copied -5jFf2thMKg.mp4 (Label: 107) to videos_test
# Copied treyzEhuM_0.mp4 (Label: 108) to videos_test
# Copied f6263gcQyDw.mp4 (Label: 109) to videos_test
# Copied MA3qmqBmBHA.mp4 (Label: 110) to videos_test
# Copied h9OvyYd8vZ0.mp4 (Label: 111) to videos_test
# Copied Hd9_DTFGGjI.mp4 (Label: 112) to videos_test
# Copied 3WUESDiGU5U.mp4 (Label: 113) to videos_test
# Copied nITzANvDpos.mp4 (Label: 114) to videos_test
# Copied ivTBjENMTkY.mp4 (Label: 115) to videos_test
# Copied ITYTeU9_n2Y.mp4 (Label: 116) to videos_test
# Copied _0xo7EkS0tE.mp4 (Label: 117) to videos_test
# Copied Ka8Ko7qjSPY.mp4 (Label: 118) to videos_test
# Copied pK_6B96y-yU.mp4 (Label: 119) to videos_test
# Copied nnuhQ2o1UWE.mp4 (Label: 120) to videos_test
# Copied iEF8R8YCXWg.mp4 (Label: 121) to videos_test
# Copied u5u9y_ltKCI.mp4 (Label: 122) to videos_test
# Copied tweM6hUt2xU.mp4 (Label: 123) to videos_test
# Copied 1Ir_hvfdzpo.mp4 (Label: 124) to videos_test
# Copied sSpMlcGYGxY.mp4 (Label: 125) to videos_test
# Copied 9TSbWCDNdw0.mp4 (Label: 126) to videos_test
# Copied f4j7Nzt0dyE.mp4 (Label: 127) to videos_test
# Copied pL7wmBRHx_Q.mp4 (Label: 128) to videos_test
# Copied Xl6Ixg74NpI.mp4 (Label: 129) to videos_test
# Copied I84fWDl0fRg.mp4 (Label: 130) to videos_test
# Copied KPP2qRzMdos.mp4 (Label: 131) to videos_test
# Copied XdpOPyBQTIA.mp4 (Label: 132) to videos_test
# Copied 8KBHBWDj1bE.mp4 (Label: 133) to videos_test
# Copied e52FAOSEvHQ.mp4 (Label: 134) to videos_test
# Copied hska3TcUtFA.mp4 (Label: 135) to videos_test
# Copied k8yiq_f7fw8.mp4 (Label: 136) to videos_test
# Copied SddRTBuwbko.mp4 (Label: 137) to videos_test
# Copied rSb0PJ0sLKg.mp4 (Label: 138) to videos_test
# Copied A2IbV23RY6s.mp4 (Label: 139) to videos_test
# Copied lXM8u5_0wbI.mp4 (Label: 140) to videos_test
# Copied r4syWsNa_Js.mp4 (Label: 141) to videos_test
# Copied tahiCqWr6Jo.mp4 (Label: 142) to videos_test
# Copied ppg0WSpx0yY.mp4 (Label: 143) to videos_test
# Copied a_kBfppfkwo.mp4 (Label: 144) to videos_test
# Copied DIPowS1PFao.mp4 (Label: 145) to videos_test
# Copied HsrhpE6D_lw.mp4 (Label: 146) to videos_test
# Copied HCG8Kqkn-58.mp4 (Label: 147) to videos_test
# Copied 6OYCwRhdSS0.mp4 (Label: 148) to videos_test
# Copied 7m6IfCwJsHw.mp4 (Label: 149) to videos_test
# Copied PzD2BkZye2U.mp4 (Label: 150) to videos_test
# Copied ifmHO5lQq18.mp4 (Label: 151) to videos_test
# Copied uIZ7gdl30IA.mp4 (Label: 152) to videos_test
# Copied e8uB0GZsVOQ.mp4 (Label: 153) to videos_test
# Copied sBJk5li0O5o.mp4 (Label: 154) to videos_test
# Copied 67FSBl8CfBU.mp4 (Label: 155) to videos_test
# Copied JPs52tAeebA.mp4 (Label: 156) to videos_test
# Copied Od9R7LvvKXA.mp4 (Label: 157) to videos_test
# Copied cYon953RNCQ.mp4 (Label: 158) to videos_test
# Copied --wYHtYMK9o.mp4 (Label: 159) to videos_test
# Copied w3mLvqr4_RQ.mp4 (Label: 160) to videos_test
# Copied teFC5zq-SQk.mp4 (Label: 161) to videos_test
# Copied MlN9baLiJXc.mp4 (Label: 162) to videos_test
# Copied ocPxOsOvkd0.mp4 (Label: 163) to videos_test
# Copied 11KCs9EekNo.mp4 (Label: 164) to videos_test
# Copied fOg9c8wfP2Q.mp4 (Label: 165) to videos_test
# Copied M0O3qn_zgqo.mp4 (Label: 166) to videos_test
# Copied JHv17IUcO2c.mp4 (Label: 167) to videos_test
# Copied WAx5PiFvdoE.mp4 (Label: 168) to videos_test
# Copied YH801xSLkZM.mp4 (Label: 169) to videos_test
# Copied OQMxykD06iM.mp4 (Label: 170) to videos_test
# Copied 3JzBgr6wxlo.mp4 (Label: 171) to videos_test
# Copied ZgwXcCGr5fQ.mp4 (Label: 172) to videos_test
# Copied WXB_qERqjjA.mp4 (Label: 173) to videos_test
# Copied XEmj6SgGfYo.mp4 (Label: 174) to videos_test
# Copied 08exh0TpOlM.mp4 (Label: 175) to videos_test
# Copied Qw-slbWE8Bs.mp4 (Label: 176) to videos_test
# Copied j6VaRVmEwPU.mp4 (Label: 177) to videos_test
# Copied DfbacnhhjmQ.mp4 (Label: 178) to videos_test
# Copied e_2cryzWTwI.mp4 (Label: 179) to videos_test
# Copied 0gR5FP7HpZ4.mp4 (Label: 180) to videos_test
# Copied f_lSThX3i_A.mp4 (Label: 181) to videos_test
# Copied LLX0blBD6Fg.mp4 (Label: 182) to videos_test
# Copied pLcPnpNrTtw.mp4 (Label: 183) to videos_test
# Copied mvu2ZWvneAo.mp4 (Label: 184) to videos_test
# Copied JyUoHbZJQZ4.mp4 (Label: 185) to videos_test
# Copied yD42KW6cm-A.mp4 (Label: 186) to videos_test
# Copied xnWRdcQBHk8.mp4 (Label: 187) to videos_test
# Copied 8ZgvrZAHu0w.mp4 (Label: 188) to videos_test
# Copied -iS_ct6yvgA.mp4 (Label: 189) to videos_test
# Copied hVLUOocKcVI.mp4 (Label: 190) to videos_test
# Copied 05P1B4urnF4.mp4 (Label: 191) to videos_test
# Copied O45M1OCvLLU.mp4 (Label: 192) to videos_test
# Copied -0FzHADcl10.mp4 (Label: 193) to videos_test
# Copied 7dKCdmnzCME.mp4 (Label: 194) to videos_test
# Copied UyggWLyvWaQ.mp4 (Label: 195) to videos_test
# Copied HhKlMP4jjQw.mp4 (Label: 196) to videos_test
# Copied r70BEBb-3tc.mp4 (Label: 197) to videos_test
# Copied fu29_UHFaJY.mp4 (Label: 198) to videos_test
# Copied leWjhZKaK7Q.mp4 (Label: 199) to videos_test
# Copied IdiVhgF1kLo.mp4 (Label: 200) to videos_test
# Copied m7S7hRQVfm8.mp4 (Label: 201) to videos_test
# Copied W06ulT0k80U.mp4 (Label: 202) to videos_test
# Copied vXQX5XQfySY.mp4 (Label: 203) to videos_test
# Copied no3_ZKDWOTQ.mp4 (Label: 204) to videos_test
# Copied 5c9HlCmmAGw.mp4 (Label: 205) to videos_test
# Copied -gsRLvAO4mw.mp4 (Label: 206) to videos_test
# Copied uSYK3tZJYNc.mp4 (Label: 207) to videos_test
# Copied p8On73vMA1A.mp4 (Label: 208) to videos_test
# Copied udLMOf77S3U.mp4 (Label: 209) to videos_test
# Copied ljLey6nc_Us.mp4 (Label: 210) to videos_test
# Copied ZqbjxMIQhBM.mp4 (Label: 211) to videos_test
# Copied vtPEWwtodCU.mp4 (Label: 212) to videos_test
# Copied qvuM5tRdJ4o.mp4 (Label: 213) to videos_test
# Copied RxCdnvQOin0.mp4 (Label: 214) to videos_test
# Copied X9_7UNFztss.mp4 (Label: 215) to videos_test
# Copied jE4OreT7B9I.mp4 (Label: 216) to videos_test
# Copied 2GhcqTJoEaI.mp4 (Label: 217) to videos_test
# Copied HUrm5gkDREc.mp4 (Label: 218) to videos_test
# Copied ZQIh3uZTTEo.mp4 (Label: 219) to videos_test
# Copied 9mjAtIkbiI8.mp4 (Label: 220) to videos_test
# Copied 3AKiMufDtCI.mp4 (Label: 221) to videos_test
# Copied Q9_UQ2ucnYQ.mp4 (Label: 222) to videos_test
# Copied R0HmDcyCqFU.mp4 (Label: 223) to videos_test
# Copied Yqd0U012_Hw.mp4 (Label: 224) to videos_test
# Copied 7g4aL1EX8EI.mp4 (Label: 225) to videos_test
# Copied I8mYa7_5uik.mp4 (Label: 226) to videos_test
# Copied cxWLsLqZnqE.mp4 (Label: 227) to videos_test
# Copied jXn3W0t9Oro.mp4 (Label: 228) to videos_test
# Copied eow6z2S-n3U.mp4 (Label: 229) to videos_test
# Copied qoDCBrRmiF0.mp4 (Label: 230) to videos_test
# Copied 67vhJRyiwmI.mp4 (Label: 231) to videos_test
# Copied 0SDy6ZObNdE.mp4 (Label: 232) to videos_test
# Copied XHzUKr_C8zg.mp4 (Label: 233) to videos_test
# Copied YkGod1DOGsQ.mp4 (Label: 234) to videos_test
# Copied S-8ogZOLiWU.mp4 (Label: 235) to videos_test
# Copied -AZ9WaV2Ozk.mp4 (Label: 236) to videos_test
# Copied KrjgAicFObw.mp4 (Label: 237) to videos_test
# Copied fpOsy5VD_ss.mp4 (Label: 238) to videos_test
# Copied ziaUMoBoz8s.mp4 (Label: 239) to videos_test
# Copied ORORz9WXJww.mp4 (Label: 240) to videos_test
# Copied YgpvcsbKLtg.mp4 (Label: 241) to videos_test
# Copied 34sZrTPJc80.mp4 (Label: 242) to videos_test
# Copied NHysKK0dtQo.mp4 (Label: 243) to videos_test
# Copied 65rmeShvIxs.mp4 (Label: 244) to videos_test
# Copied UIC10idnF8M.mp4 (Label: 245) to videos_test
# Copied KUPwOAgtqOo.mp4 (Label: 246) to videos_test
# Copied RYPA6HPpldw.mp4 (Label: 247) to videos_test
# Copied WvrTm5camjE.mp4 (Label: 248) to videos_test
# Copied JfJHfgJp79s.mp4 (Label: 249) to videos_test
# Copied Ta4mtqsCjkU.mp4 (Label: 250) to videos_test
# Copied q3cRM4TVVRI.mp4 (Label: 251) to videos_test
# Copied VvckL4ljuBY.mp4 (Label: 252) to videos_test
# Copied Vi9DnsFTnWc.mp4 (Label: 253) to videos_test
# Copied JChuYeI0LVg.mp4 (Label: 254) to videos_test
# Copied foVSvlCcnGU.mp4 (Label: 255) to videos_test
# Copied KG1RzT2XD2g.mp4 (Label: 256) to videos_test
# Copied SM_dwYK7C4g.mp4 (Label: 257) to videos_test
# Copied SUhKIoo8Y7U.mp4 (Label: 258) to videos_test
# Copied aEfN-E9ZGTo.mp4 (Label: 259) to videos_test
# Copied igPW5PyFml0.mp4 (Label: 260) to videos_test
# Copied 1EVpjfsm0Vc.mp4 (Label: 261) to videos_test
# Copied ch5c9K3aZ9A.mp4 (Label: 262) to videos_test
# Copied MPvuxeSaEDY.mp4 (Label: 263) to videos_test
# Copied uazvUxVJ4u0.mp4 (Label: 264) to videos_test
# Copied kwYNw9kakwA.mp4 (Label: 265) to videos_test
# Copied HR_w7PNiW9w.mp4 (Label: 266) to videos_test
# Copied YsEiyNMj688.mp4 (Label: 267) to videos_test
# Copied RUcuktg9hkg.mp4 (Label: 268) to videos_test
# Copied zx3D8JErbKw.mp4 (Label: 269) to videos_test
# Copied rW5SZRkpBUo.mp4 (Label: 270) to videos_test
# Copied gB31XFXMk8Y.mp4 (Label: 271) to videos_test
# Copied v-FQSnLibok.mp4 (Label: 272) to videos_test
# Copied J-1gayS1jc8.mp4 (Label: 273) to videos_test
# Copied HNyH3m-EhT0.mp4 (Label: 274) to videos_test
# Copied QRGX-emNGKU.mp4 (Label: 275) to videos_test
# Copied TSHY23SOf5U.mp4 (Label: 276) to videos_test
# Copied qFjPNVIYFgE.mp4 (Label: 277) to videos_test
# Copied FFdvV2RAPYc.mp4 (Label: 278) to videos_test
# Copied eyglSiAKP-4.mp4 (Label: 279) to videos_test
# Copied TGrEoaUvDBA.mp4 (Label: 280) to videos_test
# Copied mmhnP-CB4is.mp4 (Label: 281) to videos_test
# Copied jlNHdd-dDuM.mp4 (Label: 282) to videos_test
# Copied s0kTTBizjl8.mp4 (Label: 283) to videos_test
# Copied SjbMhrbrQ4I.mp4 (Label: 284) to videos_test
# Copied evqKBdqRFe0.mp4 (Label: 285) to videos_test
# Copied NF7YB65qITA.mp4 (Label: 286) to videos_test
# Copied -2vSka0wXKY.mp4 (Label: 287) to videos_test
# Copied ivgfkFw9HLs.mp4 (Label: 288) to videos_test
# Copied RS4_Ez69Gs8.mp4 (Label: 289) to videos_test
# Copied 0HbXYa4MGUU.mp4 (Label: 290) to videos_test
# Copied K2uTgNHJN2E.mp4 (Label: 291) to videos_test
# Copied srYczCqU_og.mp4 (Label: 292) to videos_test
# Copied NC_98qZPfpQ.mp4 (Label: 293) to videos_test
# Copied sWxrjaO-Coo.mp4 (Label: 294) to videos_test
# Copied TEHuFWeGLWY.mp4 (Label: 295) to videos_test
# Copied u6PXN2gCiwY.mp4 (Label: 296) to videos_test
# Copied cBfWngnKR2s.mp4 (Label: 297) to videos_test
# Copied zZZohOGP3JA.mp4 (Label: 298) to videos_test
# Copied Jm3c8QSzJyY.mp4 (Label: 299) to videos_test
# Copied Dx7_D7yV7G4.mp4 (Label: 300) to videos_test
# Copied TS_DwPfdY8c.mp4 (Label: 301) to videos_test
# Copied U_CeyCr_92c.mp4 (Label: 302) to videos_test
# Copied 7HYdfNLhDKU.mp4 (Label: 303) to videos_test
# Copied UduXKyY0_nA.mp4 (Label: 304) to videos_test
# Copied Ex83kBAta5E.mp4 (Label: 305) to videos_test
# Copied xVMT8-5AwEk.mp4 (Label: 306) to videos_test
# Copied JTcCFhR6_Bw.mp4 (Label: 307) to videos_test
# Copied 96cq0YhXY3c.mp4 (Label: 308) to videos_test
# Copied bUcW94xnqdI.mp4 (Label: 309) to videos_test
# Copied XihcOEopJG0.mp4 (Label: 310) to videos_test
# Copied JbeJVuoNzJA.mp4 (Label: 311) to videos_test
# Copied A5VPOH64_3Q.mp4 (Label: 312) to videos_test
# Copied GvbG1efwhNg.mp4 (Label: 313) to videos_test
# Copied _6PUxb47zJY.mp4 (Label: 314) to videos_test
# Copied HtA0neqM9HE.mp4 (Label: 315) to videos_test
# Copied 0y_OCH1FnSU.mp4 (Label: 316) to videos_test
# Copied 4vN9UHxdy6Y.mp4 (Label: 317) to videos_test
# Copied PjJyTpUEoiQ.mp4 (Label: 318) to videos_test
# Copied 1RTQVuK8sHw.mp4 (Label: 319) to videos_test
# Copied 5GJshaytdzI.mp4 (Label: 320) to videos_test
# Copied X_1uRiZx1sw.mp4 (Label: 321) to videos_test
# Copied ZCeyRuMYdfw.mp4 (Label: 322) to videos_test
# Copied 2VRuFjC8HDM.mp4 (Label: 323) to videos_test
# Copied bq4btBTSbqQ.mp4 (Label: 324) to videos_test
# Copied X4C522pjiHs.mp4 (Label: 325) to videos_test
# Copied T4mVBwjSFio.mp4 (Label: 326) to videos_test
# Copied YOGkTLJFPNI.mp4 (Label: 327) to videos_test
# Copied VX2OSPXC07w.mp4 (Label: 328) to videos_test
# Copied Kl6xfVnJi8I.mp4 (Label: 329) to videos_test
# Copied M7nBhGpzPq8.mp4 (Label: 330) to videos_test
# Copied IMroMNXrvrE.mp4 (Label: 331) to videos_test
# Copied cR9PY6AE7cU.mp4 (Label: 332) to videos_test
# Copied X--u5OOFOVU.mp4 (Label: 333) to videos_test
# Copied 3sc7PXuzuI4.mp4 (Label: 334) to videos_test
# Copied gGzoOOi7u-c.mp4 (Label: 335) to videos_test
# Copied n3Z-qSJC5kM.mp4 (Label: 336) to videos_test
# Copied CDssc5DEun4.mp4 (Label: 337) to videos_test
# Copied k884aDwlkFo.mp4 (Label: 338) to videos_test
# Copied g7cNSVP4Zcg.mp4 (Label: 339) to videos_test
# Copied xwl83a16evo.mp4 (Label: 340) to videos_test
# Copied TTRjWksItbM.mp4 (Label: 341) to videos_test
# Copied -Y-fUYGcb7o.mp4 (Label: 342) to videos_test
# Copied gY2aoA_4Uz8.mp4 (Label: 343) to videos_test
# Copied 4y7F2p-Qpsg.mp4 (Label: 344) to videos_test
# Copied G2-gqXeZ31A.mp4 (Label: 345) to videos_test
# Copied kgIWRXPCO3I.mp4 (Label: 346) to videos_test
# Copied N0S9XCbj20M.mp4 (Label: 347) to videos_test
# Copied B0xZ0e4tqAU.mp4 (Label: 348) to videos_test
# Copied Xsvv0_AqZ1Y.mp4 (Label: 349) to videos_test
# Copied LTHLzLFKMsQ.mp4 (Label: 350) to videos_test
# Copied wUaMMoLb7vM.mp4 (Label: 351) to videos_test
# Copied QFmHnhLqf6c.mp4 (Label: 352) to videos_test
# Copied kp7SYmx1WgU.mp4 (Label: 353) to videos_test
# Copied SYSGcLYao6M.mp4 (Label: 354) to videos_test
# Copied E_yqNNBdvH4.mp4 (Label: 355) to videos_test
# Copied ONFppy-AC0M.mp4 (Label: 356) to videos_test
# Copied LOjAH8yLHCo.mp4 (Label: 357) to videos_test
# Copied bHdGTlzuwRQ.mp4 (Label: 358) to videos_test
# Copied cx51qWSOJdw.mp4 (Label: 359) to videos_test
# Copied t7ieFXz4wuE.mp4 (Label: 360) to videos_test
# Copied ob_-PkMuaWo.mp4 (Label: 361) to videos_test
# Copied 7kh42F2mvss.mp4 (Label: 362) to videos_test
# Copied PreiCD2ZAfM.mp4 (Label: 363) to videos_test
# Copied i9U41IZcUno.mp4 (Label: 364) to videos_test
# Copied vmNSRIKE63k.mp4 (Label: 365) to videos_test
# Copied H8XrS1ZADGw.mp4 (Label: 366) to videos_test
# Copied Vd-JMm9mRkE.mp4 (Label: 367) to videos_test
# Copied Rqn7ujRjVGc.mp4 (Label: 368) to videos_test
# Copied GWg_E15jgqs.mp4 (Label: 369) to videos_test
# Copied xAOCmkWq848.mp4 (Label: 370) to videos_test
# Copied kE3LVziVavY.mp4 (Label: 371) to videos_test
# Copied KDQuqREZR2E.mp4 (Label: 372) to videos_test
# Copied 5if6_kbe2aA.mp4 (Label: 373) to videos_test
# Copied EaCmPAoSDko.mp4 (Label: 374) to videos_test
# Copied A8sjbCSzUow.mp4 (Label: 375) to videos_test
# Copied bGpRXUIbsUY.mp4 (Label: 376) to videos_test
# Copied imrr0pL9c7I.mp4 (Label: 377) to videos_test
# Copied klt-rafGwIc.mp4 (Label: 378) to videos_test
# Copied 6bW84cNhI7U.mp4 (Label: 379) to videos_test
# Copied fTC8Z-8QmRA.mp4 (Label: 380) to videos_test
# Copied -M9NIBnVh3U.mp4 (Label: 381) to videos_test
# Copied vl30uIEhQVk.mp4 (Label: 382) to videos_test
# Copied E5w7UqteLps.mp4 (Label: 383) to videos_test
# Copied whfDpKgvfxA.mp4 (Label: 384) to videos_test
# Copied 81Zhsksm7Yo.mp4 (Label: 385) to videos_test
# Copied YkpkTy5Xs3w.mp4 (Label: 386) to videos_test
# Copied 0tYRSpnUusM.mp4 (Label: 387) to videos_test
# Copied DZLnEkHaBEg.mp4 (Label: 388) to videos_test
# Copied dzeivZlP6tU.mp4 (Label: 389) to videos_test
# Copied lbV0XEmU5pY.mp4 (Label: 390) to videos_test
# Copied 46JluODjBBo.mp4 (Label: 391) to videos_test
# Copied lYOZM9ehR8k.mp4 (Label: 392) to videos_test
# Copied UsrN8ZRlJLc.mp4 (Label: 393) to videos_test
# Copied 9Vfv3ox2gM8.mp4 (Label: 394) to videos_test
# Copied oedu_zW75h0.mp4 (Label: 395) to videos_test
# Copied upsu2XoqoFM.mp4 (Label: 396) to videos_test
# Copied z8_up0pRdWE.mp4 (Label: 397) to videos_test
# Copied 3a8zJ6AoXyU.mp4 (Label: 398) to videos_test
# Copied AYskGmjScDU.mp4 (Label: 399) to videos_test
# Total videos copied: 400
# Number of labels represented: 400
