# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm

# 加载模型和图像处理器
model = TimesformerForVideoClassification.from_pretrained("facebook/timesformer-base-finetuned-k400")
image_processor = AutoImageProcessor.from_pretrained("MCG-NJU/videomae-base-finetuned-kinetics")
model.to('cuda')  # 直接将模型加载到GPU中

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open("archive/kinetics400_val_list_videos.txt", "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

def split_video_into_segments(container, n_segments=8, frames_per_segment=16):
    frame_list = [frame.to_image() for frame in container.decode(video=0)]
    total_frames = len(frame_list)
    segment_length = total_frames // n_segments

    segments = []
    for i in range(n_segments):
        start_index = i * segment_length
        end_index = min(start_index + segment_length, total_frames)
        segment_frames = frame_list[start_index:end_index]

        while len(segment_frames) < frames_per_segment:
            segment_frames.append(segment_frames[-1])

        segments.append(segment_frames[:frames_per_segment])

    return segments

def predict_video_and_segments(model, image_processor, container, true_label):
    video_segments = split_video_into_segments(container)
    segment_outputs = []
    
    with torch.no_grad():
        # Process each segment
        for segment in video_segments:
            inputs = image_processor(list(segment), return_tensors="pt")
            inputs = {k: v.to('cuda') for k, v in inputs.items()}
            outputs = model(**inputs)
            logits = outputs.logits
            probabilities = F.softmax(logits, dim=-1)
            pred_label = logits.argmax(-1).item()
            pred_score = probabilities[0, pred_label].item()
            segment_outputs.append((pred_label, pred_score, probabilities))

        # Aggregate predictions for overall video prediction
        video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
        video_pred_label = video_probs.argmax().item()
        video_pred_score = video_probs[0, video_pred_label].item()
        video_true_score = video_probs[0, true_label].item()

    return video_pred_label, video_pred_score, video_true_score, segment_outputs

def process_videos(sampled_files, true_labels):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join("archive/videos_val", video_file)
        container = av.open(file_path)
        video_pred_label, video_pred_score, video_true_score, segment_outputs = predict_video_and_segments(model, image_processor, container, true_label)
        predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs))

    return predictions

# 准备视频样本
num_samples_per_class = 5
sampled_files = list(video_labels.items())[0][1][:num_samples_per_class]
true_labels = [list(video_labels.keys())[0]] * num_samples_per_class

# 获取数据和预测
video_data = process_videos(sampled_files, true_labels)

# 打印输出每个视频的整体预测结果及每个片段的结果
for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_labels[0]}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_score = probabilities[0, video_pred_label].item()
        segment_true_score = probabilities[0, true_labels[0]].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_score:.4f}, Segment True Label Score = {segment_true_score:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/5 [00:00<?, ?video/s]
# Video: jf7RDuUTrsQ.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.2028, True Label = 325, True Label Score = 0.0010
#   Segment 1: Predicted Label = 81, Prediction Score = 0.4557, Segment Video Label Score = 0.0373, Segment True Label Score = 0.0000
#   Segment 2: Predicted Label = 171, Prediction Score = 0.6322, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0004
#   Segment 3: Predicted Label = 1, Prediction Score = 0.5045, Segment Video Label Score = 0.5045, Segment True Label Score = 0.0000
#   Segment 4: Predicted Label = 289, Prediction Score = 0.4299, Segment Video Label Score = 0.1295, Segment True Label Score = 0.0000
#   Segment 5: Predicted Label = 1, Prediction Score = 0.4968, Segment Video Label Score = 0.4968, Segment True Label Score = 0.0054
#   Segment 6: Predicted Label = 127, Prediction Score = 0.4740, Segment Video Label Score = 0.4092, Segment True Label Score = 0.0000
#   Segment 7: Predicted Label = 57, Prediction Score = 0.3964, Segment Video Label Score = 0.0368, Segment True Label Score = 0.0000
#   Segment 8: Predicted Label = 81, Prediction Score = 0.4700, Segment Video Label Score = 0.0048, Segment True Label Score = 0.0022
# Video: EhRxb8-cNzQ.mp4, Overall Predicted Label = 149, Overall Prediction Score = 0.3158, True Label = 325, True Label Score = 0.0011
#   Segment 1: Predicted Label = 230, Prediction Score = 0.5502, Segment Video Label Score = 0.0019, Segment True Label Score = 0.0000
#   Segment 2: Predicted Label = 230, Prediction Score = 0.6382, Segment Video Label Score = 0.0491, Segment True Label Score = 0.0000
#   Segment 3: Predicted Label = 106, Prediction Score = 0.3546, Segment Video Label Score = 0.1676, Segment True Label Score = 0.0017
#   Segment 4: Predicted Label = 122, Prediction Score = 0.1118, Segment Video Label Score = 0.0334, Segment True Label Score = 0.0066
#   Segment 5: Predicted Label = 149, Prediction Score = 0.9921, Segment Video Label Score = 0.9921, Segment True Label Score = 0.0000
#   Segment 6: Predicted Label = 149, Prediction Score = 0.8774, Segment Video Label Score = 0.8774, Segment True Label Score = 0.0000
#   Segment 7: Predicted Label = 127, Prediction Score = 0.5743, Segment Video Label Score = 0.0236, Segment True Label Score = 0.0000
#   Segment 8: Predicted Label = 149, Prediction Score = 0.3811, Segment Video Label Score = 0.3811, Segment True Label Score = 0.0001
# Video: l2_Da-CMPfY.mp4, Overall Predicted Label = 302, Overall Prediction Score = 0.4586, True Label = 325, True Label Score = 0.0588
#   Segment 1: Predicted Label = 302, Prediction Score = 0.9208, Segment Video Label Score = 0.9208, Segment True Label Score = 0.0099
#   Segment 2: Predicted Label = 302, Prediction Score = 0.6358, Segment Video Label Score = 0.6358, Segment True Label Score = 0.0056
#   Segment 3: Predicted Label = 302, Prediction Score = 0.6041, Segment Video Label Score = 0.6041, Segment True Label Score = 0.0125
#   Segment 4: Predicted Label = 333, Prediction Score = 0.6571, Segment Video Label Score = 0.0046, Segment True Label Score = 0.0101
#   Segment 5: Predicted Label = 313, Prediction Score = 0.3895, Segment Video Label Score = 0.0017, Segment True Label Score = 0.0196
#   Segment 6: Predicted Label = 302, Prediction Score = 0.5067, Segment Video Label Score = 0.5067, Segment True Label Score = 0.0128
#   Segment 7: Predicted Label = 302, Prediction Score = 0.9150, Segment Video Label Score = 0.9150, Segment True Label Score = 0.0030
#   Segment 8: Predicted Label = 325, Prediction Score = 0.3969, Segment Video Label Score = 0.0797, Segment True Label Score = 0.3969
# Video: RM4HvsOOp88.mp4, Overall Predicted Label = 173, Overall Prediction Score = 0.1174, True Label = 325, True Label Score = 0.0126
#   Segment 1: Predicted Label = 154, Prediction Score = 0.1408, Segment Video Label Score = 0.0118, Segment True Label Score = 0.0207
#   Segment 2: Predicted Label = 346, Prediction Score = 0.2853, Segment Video Label Score = 0.1702, Segment True Label Score = 0.0049
#   Segment 3: Predicted Label = 393, Prediction Score = 0.1789, Segment Video Label Score = 0.0123, Segment True Label Score = 0.0091
#   Segment 4: Predicted Label = 173, Prediction Score = 0.1861, Segment Video Label Score = 0.1861, Segment True Label Score = 0.0242
#   Segment 5: Predicted Label = 34, Prediction Score = 0.1253, Segment Video Label Score = 0.0002, Segment True Label Score = 0.0227
#   Segment 6: Predicted Label = 306, Prediction Score = 0.1284, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0139
#   Segment 7: Predicted Label = 346, Prediction Score = 0.5618, Segment Video Label Score = 0.0184, Segment True Label Score = 0.0050
#   Segment 8: Predicted Label = 173, Prediction Score = 0.5401, Segment Video Label Score = 0.5401, Segment True Label Score = 0.0005
# Video: t8_Dpyynb4Q.mp4, Overall Predicted Label = 325, Overall Prediction Score = 0.3822, True Label = 325, True Label Score = 0.3822
#   Segment 1: Predicted Label = 151, Prediction Score = 0.7113, Segment Video Label Score = 0.1771, Segment True Label Score = 0.1771
#   Segment 2: Predicted Label = 151, Prediction Score = 0.6033, Segment Video Label Score = 0.2685, Segment True Label Score = 0.2685
#   Segment 3: Predicted Label = 325, Prediction Score = 0.7452, Segment Video Label Score = 0.7452, Segment True Label Score = 0.7452
#   Segment 4: Predicted Label = 325, Prediction Score = 0.4328, Segment Video Label Score = 0.4328, Segment True Label Score = 0.4328
#   Segment 5: Predicted Label = 151, Prediction Score = 0.5141, Segment Video Label Score = 0.2136, Segment True Label Score = 0.2136
#   Segment 6: Predicted Label = 151, Prediction Score = 0.6258, Segment Video Label Score = 0.1794, Segment True Label Score = 0.1794
#   Segment 7: Predicted Label = 325, Prediction Score = 0.4142, Segment Video Label Score = 0.4142, Segment True Label Score = 0.4142
#   Segment 8: Predicted Label = 325, Prediction Score = 0.6271, Segment Video Label Score = 0.6271, Segment True Label Score = 0.6271
