# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                outputs = self.model(**inputs)
                logits = outputs.logits
                probabilities = F.softmax(logits, dim=-1)
                pred_label = logits.argmax(-1).item()
                pred_score = probabilities[0, pred_label].item()
                segment_outputs.append((pred_label, pred_score, probabilities))
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        segment_outputs = video_processor.predict_video_and_segments(container, true_label)
        video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
        video_pred_label = video_probs.argmax().item()
        video_pred_score = video_probs[0, video_pred_label].item()
        video_true_score = video_probs[0, true_label].item()
        
        if use_exact:
            sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
            sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
        else:
            sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
            sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
        
        predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred))
    return predictions

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, true_labels[0]].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,
    "num_classes": 5,
    "num_samples_per_class": 5,
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": False  # 设置为True以使用精确Shapley Value计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

# 准备视频样本
sampled_files = []
true_labels = []
selected_classes = list(video_labels.keys())[:config["num_classes"]]
for cls in selected_classes:
    sampled_files.extend(video_labels[cls][:config["num_samples_per_class"]])
    true_labels.extend([cls] * config["num_samples_per_class"])

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=config["use_exact"])

# 打印并保存结果
save_results(video_data)

# 打印结果以便查看
for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_labels[0]}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_labels[0]].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/25 [00:00<?, ?video/s]
# Video: jf7RDuUTrsQ.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.2028, True Label = 325, True Label Score = 0.0010
#   Segment 1: Predicted Label = 81, Prediction Score = 0.4557, Segment Video Label Score = 0.0373, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = -0.0571
#   Segment 2: Predicted Label = 171, Prediction Score = 0.6322, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0004, SV True Label = -0.0002, SV Predicted Label = -0.0730
#   Segment 3: Predicted Label = 1, Prediction Score = 0.5045, Segment Video Label Score = 0.5045, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.1187
#   Segment 4: Predicted Label = 289, Prediction Score = 0.4299, Segment Video Label Score = 0.1295, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0496
#   Segment 5: Predicted Label = 1, Prediction Score = 0.4968, Segment Video Label Score = 0.4968, Segment True Label Score = 0.0054, SV True Label = 0.0015, SV Predicted Label = 0.1202
#   Segment 6: Predicted Label = 127, Prediction Score = 0.4740, Segment Video Label Score = 0.4092, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.1201
#   Segment 7: Predicted Label = 57, Prediction Score = 0.3964, Segment Video Label Score = 0.0368, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = -0.0639
#   Segment 8: Predicted Label = 81, Prediction Score = 0.4700, Segment Video Label Score = 0.0048, Segment True Label Score = 0.0022, SV True Label = 0.0006, SV Predicted Label = -0.0837
# Video: EhRxb8-cNzQ.mp4, Overall Predicted Label = 149, Overall Prediction Score = 0.3158, True Label = 325, True Label Score = 0.0011
#   Segment 1: Predicted Label = 230, Prediction Score = 0.5502, Segment Video Label Score = 0.0019, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = -0.1175
#   Segment 2: Predicted Label = 230, Prediction Score = 0.6382, Segment Video Label Score = 0.0491, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0987
#   Segment 3: Predicted Label = 106, Prediction Score = 0.3546, Segment Video Label Score = 0.1676, Segment True Label Score = 0.0017, SV True Label = 0.0005, SV Predicted Label = -0.0443
#   Segment 4: Predicted Label = 122, Prediction Score = 0.1118, Segment Video Label Score = 0.0334, Segment True Label Score = 0.0066, SV True Label = 0.0018, SV Predicted Label = -0.1070
#   Segment 5: Predicted Label = 149, Prediction Score = 0.9921, Segment Video Label Score = 0.9921, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = 0.2729
#   Segment 6: Predicted Label = 149, Prediction Score = 0.8774, Segment Video Label Score = 0.8774, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.2196
#   Segment 7: Predicted Label = 127, Prediction Score = 0.5743, Segment Video Label Score = 0.0236, Segment True Label Score = 0.0000, SV True Label = -0.0005, SV Predicted Label = -0.1121
#   Segment 8: Predicted Label = 149, Prediction Score = 0.3811, Segment Video Label Score = 0.3811, Segment True Label Score = 0.0001, SV True Label = -0.0002, SV Predicted Label = 0.0306
# Video: l2_Da-CMPfY.mp4, Overall Predicted Label = 302, Overall Prediction Score = 0.4586, True Label = 325, True Label Score = 0.0588
#   Segment 1: Predicted Label = 302, Prediction Score = 0.9208, Segment Video Label Score = 0.9208, Segment True Label Score = 0.0099, SV True Label = -0.0098, SV Predicted Label = 0.2125
#   Segment 2: Predicted Label = 302, Prediction Score = 0.6358, Segment Video Label Score = 0.6358, Segment True Label Score = 0.0056, SV True Label = -0.0169, SV Predicted Label = 0.0775
#   Segment 3: Predicted Label = 302, Prediction Score = 0.6041, Segment Video Label Score = 0.6041, Segment True Label Score = 0.0125, SV True Label = -0.0164, SV Predicted Label = 0.0251
#   Segment 4: Predicted Label = 333, Prediction Score = 0.6571, Segment Video Label Score = 0.0046, Segment True Label Score = 0.0101, SV True Label = -0.0199, SV Predicted Label = -0.1812
#   Segment 5: Predicted Label = 313, Prediction Score = 0.3895, Segment Video Label Score = 0.0017, Segment True Label Score = 0.0196, SV True Label = -0.0077, SV Predicted Label = -0.1755
#   Segment 6: Predicted Label = 302, Prediction Score = 0.5067, Segment Video Label Score = 0.5067, Segment True Label Score = 0.0128, SV True Label = -0.0148, SV Predicted Label = 0.0634
#   Segment 7: Predicted Label = 302, Prediction Score = 0.9150, Segment Video Label Score = 0.9150, Segment True Label Score = 0.0030, SV True Label = -0.0189, SV Predicted Label = 0.1788
#   Segment 8: Predicted Label = 325, Prediction Score = 0.3969, Segment Video Label Score = 0.0797, Segment True Label Score = 0.3969, SV True Label = 0.1139, SV Predicted Label = -0.1349
# Video: RM4HvsOOp88.mp4, Overall Predicted Label = 173, Overall Prediction Score = 0.1174, True Label = 325, True Label Score = 0.0126
#   Segment 1: Predicted Label = 154, Prediction Score = 0.1408, Segment Video Label Score = 0.0118, Segment True Label Score = 0.0207, SV True Label = 0.0026, SV Predicted Label = -0.0428
#   Segment 2: Predicted Label = 346, Prediction Score = 0.2853, Segment Video Label Score = 0.1702, Segment True Label Score = 0.0049, SV True Label = -0.0019, SV Predicted Label = 0.0197
#   Segment 3: Predicted Label = 393, Prediction Score = 0.1789, Segment Video Label Score = 0.0123, Segment True Label Score = 0.0091, SV True Label = -0.0012, SV Predicted Label = -0.0388
#   Segment 4: Predicted Label = 173, Prediction Score = 0.1861, Segment Video Label Score = 0.1861, Segment True Label Score = 0.0242, SV True Label = 0.0039, SV Predicted Label = 0.0202
#   Segment 5: Predicted Label = 34, Prediction Score = 0.1253, Segment Video Label Score = 0.0002, Segment True Label Score = 0.0227, SV True Label = 0.0038, SV Predicted Label = -0.0407
#   Segment 6: Predicted Label = 306, Prediction Score = 0.1284, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0139, SV True Label = 0.0012, SV Predicted Label = -0.0339
#   Segment 7: Predicted Label = 346, Prediction Score = 0.5618, Segment Video Label Score = 0.0184, Segment True Label Score = 0.0050, SV True Label = -0.0020, SV Predicted Label = -0.0425
#   Segment 8: Predicted Label = 173, Prediction Score = 0.5401, Segment Video Label Score = 0.5401, Segment True Label Score = 0.0005, SV True Label = -0.0046, SV Predicted Label = 0.1774
# Video: t8_Dpyynb4Q.mp4, Overall Predicted Label = 325, Overall Prediction Score = 0.3822, True Label = 325, True Label Score = 0.3822
#   Segment 1: Predicted Label = 151, Prediction Score = 0.7113, Segment Video Label Score = 0.1771, Segment True Label Score = 0.1771, SV True Label = -0.0678, SV Predicted Label = -0.0668
#   Segment 2: Predicted Label = 151, Prediction Score = 0.6033, Segment Video Label Score = 0.2685, Segment True Label Score = 0.2685, SV True Label = -0.0331, SV Predicted Label = -0.0255
#   Segment 3: Predicted Label = 325, Prediction Score = 0.7452, Segment Video Label Score = 0.7452, Segment True Label Score = 0.7452, SV True Label = 0.1377, SV Predicted Label = 0.1241
#   Segment 4: Predicted Label = 325, Prediction Score = 0.4328, Segment Video Label Score = 0.4328, Segment True Label Score = 0.4328, SV True Label = 0.0194, SV Predicted Label = 0.0197
#   Segment 5: Predicted Label = 151, Prediction Score = 0.5141, Segment Video Label Score = 0.2136, Segment True Label Score = 0.2136, SV True Label = -0.0511, SV Predicted Label = -0.0433
#   Segment 6: Predicted Label = 151, Prediction Score = 0.6258, Segment Video Label Score = 0.1794, Segment True Label Score = 0.1794, SV True Label = -0.0704, SV Predicted Label = -0.0575
#   Segment 7: Predicted Label = 325, Prediction Score = 0.4142, Segment Video Label Score = 0.4142, Segment True Label Score = 0.4142, SV True Label = 0.0186, SV Predicted Label = 0.0280
#   Segment 8: Predicted Label = 325, Prediction Score = 0.6271, Segment Video Label Score = 0.6271, Segment True Label Score = 0.6271, SV True Label = 0.1009, SV Predicted Label = 0.0778
# Video: JTlatknwOrY.mp4, Overall Predicted Label = 243, Overall Prediction Score = 0.4549, True Label = 325, True Label Score = 0.0184
#   Segment 1: Predicted Label = 392, Prediction Score = 0.3439, Segment Video Label Score = 0.3148, Segment True Label Score = 0.0000, SV True Label = 0.0028, SV Predicted Label = -0.0551
#   Segment 2: Predicted Label = 392, Prediction Score = 0.8649, Segment Video Label Score = 0.0281, Segment True Label Score = 0.0000, SV True Label = -0.0061, SV Predicted Label = -0.1442
#   Segment 3: Predicted Label = 243, Prediction Score = 0.9382, Segment Video Label Score = 0.9382, Segment True Label Score = 0.0000, SV True Label = -0.0075, SV Predicted Label = 0.2199
#   Segment 4: Predicted Label = 243, Prediction Score = 0.7217, Segment Video Label Score = 0.7217, Segment True Label Score = 0.0000, SV True Label = -0.0072, SV Predicted Label = 0.0649
#   Segment 5: Predicted Label = 243, Prediction Score = 0.2478, Segment Video Label Score = 0.2478, Segment True Label Score = 0.0000, SV True Label = -0.0010, SV Predicted Label = -0.0565
#   Segment 6: Predicted Label = 243, Prediction Score = 0.8982, Segment Video Label Score = 0.8982, Segment True Label Score = 0.0000, SV True Label = -0.0065, SV Predicted Label = 0.1483
#   Segment 7: Predicted Label = 243, Prediction Score = 0.4809, Segment Video Label Score = 0.4809, Segment True Label Score = 0.0000, SV True Label = 0.0046, SV Predicted Label = 0.0467
#   Segment 8: Predicted Label = 249, Prediction Score = 0.1752, Segment Video Label Score = 0.0092, Segment True Label Score = 0.0000, SV True Label = 0.0234, SV Predicted Label = -0.1563
# Video: nK15J54IVCI.mp4, Overall Predicted Label = 233, Overall Prediction Score = 0.9575, True Label = 325, True Label Score = 0.9575
#   Segment 1: Predicted Label = 233, Prediction Score = 0.9665, Segment Video Label Score = 0.9665, Segment True Label Score = 0.0000, SV True Label = 0.0206, SV Predicted Label = 0.0331
#   Segment 2: Predicted Label = 233, Prediction Score = 0.9698, Segment Video Label Score = 0.9698, Segment True Label Score = 0.0000, SV True Label = -0.0007, SV Predicted Label = -0.0023
#   Segment 3: Predicted Label = 233, Prediction Score = 0.9527, Segment Video Label Score = 0.9527, Segment True Label Score = 0.0000, SV True Label = 0.0853, SV Predicted Label = -0.0617
#   Segment 4: Predicted Label = 233, Prediction Score = 0.9495, Segment Video Label Score = 0.9495, Segment True Label Score = 0.0000, SV True Label = 0.0404, SV Predicted Label = 0.0153
#   Segment 5: Predicted Label = 233, Prediction Score = 0.9577, Segment Video Label Score = 0.9577, Segment True Label Score = 0.0000, SV True Label = 0.0265, SV Predicted Label = 0.0169
#   Segment 6: Predicted Label = 233, Prediction Score = 0.9569, Segment Video Label Score = 0.9569, Segment True Label Score = 0.0000, SV True Label = -0.0380, SV Predicted Label = 0.0453
#   Segment 7: Predicted Label = 233, Prediction Score = 0.9396, Segment Video Label Score = 0.9396, Segment True Label Score = 0.0000, SV True Label = 0.0229, SV Predicted Label = 0.0206
#   Segment 8: Predicted Label = 233, Prediction Score = 0.9669, Segment Video Label Score = 0.9669, Segment True Label Score = 0.0000, SV True Label = -0.0165, SV Predicted Label = 0.0733
# Video: YVZIirTvnlY.mp4, Overall Predicted Label = 79, Overall Prediction Score = 0.2029, True Label = 325, True Label Score = 0.0006
#   Segment 1: Predicted Label = 229, Prediction Score = 0.1548, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0007, SV True Label = 0.0000, SV Predicted Label = -0.0678
#   Segment 2: Predicted Label = 229, Prediction Score = 0.1533, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0007, SV True Label = 0.0000, SV Predicted Label = -0.0784
#   Segment 3: Predicted Label = 229, Prediction Score = 0.1572, Segment Video Label Score = 0.0034, Segment True Label Score = 0.0007, SV True Label = 0.0001, SV Predicted Label = -0.0620
#   Segment 4: Predicted Label = 316, Prediction Score = 0.1483, Segment Video Label Score = 0.0014, Segment True Label Score = 0.0046, SV True Label = -0.0000, SV Predicted Label = -0.0748
#   Segment 5: Predicted Label = 79, Prediction Score = 0.4008, Segment Video Label Score = 0.4008, Segment True Label Score = 0.0005, SV True Label = -0.0000, SV Predicted Label = 0.0917
#   Segment 6: Predicted Label = 79, Prediction Score = 0.4001, Segment Video Label Score = 0.4001, Segment True Label Score = 0.0005, SV True Label = -0.0000, SV Predicted Label = 0.0669
#   Segment 7: Predicted Label = 79, Prediction Score = 0.4005, Segment Video Label Score = 0.4005, Segment True Label Score = 0.0005, SV True Label = 0.0000, SV Predicted Label = 0.0811
#   Segment 8: Predicted Label = 79, Prediction Score = 0.4097, Segment Video Label Score = 0.4097, Segment True Label Score = 0.0005, SV True Label = -0.0000, SV Predicted Label = 0.0737
# Video: ZxR8ZT_dg-Q.mp4, Overall Predicted Label = 304, Overall Prediction Score = 0.2550, True Label = 325, True Label Score = 0.0870
#   Segment 1: Predicted Label = 304, Prediction Score = 0.3667, Segment Video Label Score = 0.3667, Segment True Label Score = 0.0000, SV True Label = -0.0265, SV Predicted Label = 0.0565
#   Segment 2: Predicted Label = 304, Prediction Score = 0.3491, Segment Video Label Score = 0.3491, Segment True Label Score = 0.0000, SV True Label = -0.0446, SV Predicted Label = 0.0409
#   Segment 3: Predicted Label = 256, Prediction Score = 0.7435, Segment Video Label Score = 0.0496, Segment True Label Score = 0.0000, SV True Label = -0.0405, SV Predicted Label = -0.0732
#   Segment 4: Predicted Label = 256, Prediction Score = 0.9648, Segment Video Label Score = 0.0029, Segment True Label Score = 0.0000, SV True Label = -0.0294, SV Predicted Label = -0.0750
#   Segment 5: Predicted Label = 149, Prediction Score = 0.4542, Segment Video Label Score = 0.1501, Segment True Label Score = 0.0000, SV True Label = -0.0295, SV Predicted Label = -0.0465
#   Segment 6: Predicted Label = 304, Prediction Score = 0.3935, Segment Video Label Score = 0.3935, Segment True Label Score = 0.0000, SV True Label = -0.0263, SV Predicted Label = 0.0740
#   Segment 7: Predicted Label = 304, Prediction Score = 0.3562, Segment Video Label Score = 0.3562, Segment True Label Score = 0.0000, SV True Label = 0.1100, SV Predicted Label = 0.0151
#   Segment 8: Predicted Label = 304, Prediction Score = 0.3721, Segment Video Label Score = 0.3721, Segment True Label Score = 0.0000, SV True Label = 0.0974, SV Predicted Label = 0.0435
# Video: cL389d29hq8.mp4, Overall Predicted Label = 373, Overall Prediction Score = 0.5845, True Label = 325, True Label Score = 0.0002
#   Segment 1: Predicted Label = 373, Prediction Score = 0.6221, Segment Video Label Score = 0.6221, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.0339
#   Segment 2: Predicted Label = 373, Prediction Score = 0.7631, Segment Video Label Score = 0.7631, Segment True Label Score = 0.0000, SV True Label = -0.0001, SV Predicted Label = 0.0936
#   Segment 3: Predicted Label = 373, Prediction Score = 0.5657, Segment Video Label Score = 0.5657, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = -0.0171
#   Segment 4: Predicted Label = 373, Prediction Score = 0.6653, Segment Video Label Score = 0.6653, Segment True Label Score = 0.0000, SV True Label = -0.0001, SV Predicted Label = 0.0524
#   Segment 5: Predicted Label = 373, Prediction Score = 0.6572, Segment Video Label Score = 0.6572, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.0310
#   Segment 6: Predicted Label = 373, Prediction Score = 0.5230, Segment Video Label Score = 0.5230, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = -0.0173
#   Segment 7: Predicted Label = 373, Prediction Score = 0.3026, Segment Video Label Score = 0.3026, Segment True Label Score = 0.0000, SV True Label = 0.0001, SV Predicted Label = -0.1201
#   Segment 8: Predicted Label = 373, Prediction Score = 0.5767, Segment Video Label Score = 0.5767, Segment True Label Score = 0.0000, SV True Label = 0.0002, SV Predicted Label = 0.0293
# Video: 8UxlDNur-Z0.mp4, Overall Predicted Label = 262, Overall Prediction Score = 0.4897, True Label = 325, True Label Score = 0.4897
#   Segment 1: Predicted Label = 267, Prediction Score = 0.3794, Segment Video Label Score = 0.2797, Segment True Label Score = 0.0000, SV True Label = -0.1080, SV Predicted Label = -0.0972
#   Segment 2: Predicted Label = 262, Prediction Score = 0.5964, Segment Video Label Score = 0.5964, Segment True Label Score = 0.0001, SV True Label = 0.0367, SV Predicted Label = 0.0862
#   Segment 3: Predicted Label = 267, Prediction Score = 0.3372, Segment Video Label Score = 0.1509, Segment True Label Score = 0.0001, SV True Label = -0.1055, SV Predicted Label = -0.1063
#   Segment 4: Predicted Label = 267, Prediction Score = 0.3588, Segment Video Label Score = 0.2149, Segment True Label Score = 0.0000, SV True Label = -0.0991, SV Predicted Label = -0.1240
#   Segment 5: Predicted Label = 45, Prediction Score = 0.5598, Segment Video Label Score = 0.1077, Segment True Label Score = 0.0003, SV True Label = -0.1403, SV Predicted Label = -0.1189
#   Segment 6: Predicted Label = 262, Prediction Score = 0.6989, Segment Video Label Score = 0.6989, Segment True Label Score = 0.0009, SV True Label = 0.1220, SV Predicted Label = 0.1204
#   Segment 7: Predicted Label = 262, Prediction Score = 0.9150, Segment Video Label Score = 0.9150, Segment True Label Score = 0.0000, SV True Label = 0.1433, SV Predicted Label = 0.1631
#   Segment 8: Predicted Label = 262, Prediction Score = 0.9540, Segment Video Label Score = 0.9540, Segment True Label Score = 0.0000, SV True Label = 0.2268, SV Predicted Label = 0.1544
# Video: sBwcUtMx2VM.mp4, Overall Predicted Label = 262, Overall Prediction Score = 0.5562, True Label = 325, True Label Score = 0.5562
#   Segment 1: Predicted Label = 262, Prediction Score = 0.8899, Segment Video Label Score = 0.8899, Segment True Label Score = 0.0000, SV True Label = 0.1477, SV Predicted Label = 0.1487
#   Segment 2: Predicted Label = 262, Prediction Score = 0.9884, Segment Video Label Score = 0.9884, Segment True Label Score = 0.0000, SV True Label = 0.1562, SV Predicted Label = 0.1442
#   Segment 3: Predicted Label = 262, Prediction Score = 0.9821, Segment Video Label Score = 0.9821, Segment True Label Score = 0.0000, SV True Label = 0.2110, SV Predicted Label = 0.1379
#   Segment 4: Predicted Label = 262, Prediction Score = 0.6151, Segment Video Label Score = 0.6151, Segment True Label Score = 0.0000, SV True Label = 0.0337, SV Predicted Label = 0.0154
#   Segment 5: Predicted Label = 127, Prediction Score = 0.8559, Segment Video Label Score = 0.0941, Segment True Label Score = 0.0000, SV True Label = -0.1566, SV Predicted Label = -0.1320
#   Segment 6: Predicted Label = 262, Prediction Score = 0.8785, Segment Video Label Score = 0.8785, Segment True Label Score = 0.0000, SV True Label = 0.1151, SV Predicted Label = 0.1668
#   Segment 7: Predicted Label = 127, Prediction Score = 0.6127, Segment Video Label Score = 0.0008, Segment True Label Score = 0.0000, SV True Label = -0.1999, SV Predicted Label = -0.2242
#   Segment 8: Predicted Label = 127, Prediction Score = 0.3598, Segment Video Label Score = 0.0003, Segment True Label Score = 0.0000, SV True Label = -0.2245, SV Predicted Label = -0.1742
# Video: glIq9KmXoYw.mp4, Overall Predicted Label = 262, Overall Prediction Score = 0.5530, True Label = 325, True Label Score = 0.5530
#   Segment 1: Predicted Label = 262, Prediction Score = 0.6699, Segment Video Label Score = 0.6699, Segment True Label Score = 0.0000, SV True Label = 0.0561, SV Predicted Label = 0.0626
#   Segment 2: Predicted Label = 41, Prediction Score = 0.5165, Segment Video Label Score = 0.0972, Segment True Label Score = 0.0000, SV True Label = -0.1688, SV Predicted Label = -0.1652
#   Segment 3: Predicted Label = 262, Prediction Score = 0.6458, Segment Video Label Score = 0.6458, Segment True Label Score = 0.0001, SV True Label = -0.0083, SV Predicted Label = 0.0476
#   Segment 4: Predicted Label = 262, Prediction Score = 0.5807, Segment Video Label Score = 0.5807, Segment True Label Score = 0.0000, SV True Label = 0.0329, SV Predicted Label = 0.0547
#   Segment 5: Predicted Label = 233, Prediction Score = 0.1365, Segment Video Label Score = 0.0532, Segment True Label Score = 0.0000, SV True Label = -0.1984, SV Predicted Label = -0.1978
#   Segment 6: Predicted Label = 262, Prediction Score = 0.6943, Segment Video Label Score = 0.6943, Segment True Label Score = 0.0001, SV True Label = 0.0237, SV Predicted Label = 0.0887
#   Segment 7: Predicted Label = 262, Prediction Score = 0.9147, Segment Video Label Score = 0.9147, Segment True Label Score = 0.0000, SV True Label = 0.2374, SV Predicted Label = 0.1382
#   Segment 8: Predicted Label = 262, Prediction Score = 0.7679, Segment Video Label Score = 0.7679, Segment True Label Score = 0.0000, SV True Label = 0.1044, SV Predicted Label = 0.0493
# Video: pibG2NjwKfA.mp4, Overall Predicted Label = 264, Overall Prediction Score = 0.1887, True Label = 325, True Label Score = 0.0621
#   Segment 1: Predicted Label = 264, Prediction Score = 0.1957, Segment Video Label Score = 0.1957, Segment True Label Score = 0.0011, SV True Label = 0.0020, SV Predicted Label = 0.0056
#   Segment 2: Predicted Label = 156, Prediction Score = 0.7042, Segment Video Label Score = 0.0797, Segment True Label Score = 0.0005, SV True Label = -0.0129, SV Predicted Label = -0.0346
#   Segment 3: Predicted Label = 264, Prediction Score = 0.5028, Segment Video Label Score = 0.5028, Segment True Label Score = 0.0022, SV True Label = 0.0072, SV Predicted Label = 0.1266
#   Segment 4: Predicted Label = 264, Prediction Score = 0.3607, Segment Video Label Score = 0.3607, Segment True Label Score = 0.0013, SV True Label = 0.0226, SV Predicted Label = 0.0662
#   Segment 5: Predicted Label = 252, Prediction Score = 0.4088, Segment Video Label Score = 0.2580, Segment True Label Score = 0.0001, SV True Label = 0.0435, SV Predicted Label = 0.0264
#   Segment 6: Predicted Label = 158, Prediction Score = 0.2496, Segment Video Label Score = 0.0888, Segment True Label Score = 0.0002, SV True Label = -0.0166, SV Predicted Label = -0.0353
#   Segment 7: Predicted Label = 252, Prediction Score = 0.1498, Segment Video Label Score = 0.0215, Segment True Label Score = 0.0022, SV True Label = -0.0212, SV Predicted Label = -0.0601
#   Segment 8: Predicted Label = 36, Prediction Score = 0.3662, Segment Video Label Score = 0.0025, Segment True Label Score = 0.0009, SV True Label = -0.0169, SV Predicted Label = -0.0681
# Video: c_orAN_W-kU.mp4, Overall Predicted Label = 262, Overall Prediction Score = 0.9103, True Label = 325, True Label Score = 0.9103
#   Segment 1: Predicted Label = 262, Prediction Score = 0.4209, Segment Video Label Score = 0.4209, Segment True Label Score = 0.0001, SV True Label = -0.1586, SV Predicted Label = -0.1449
#   Segment 2: Predicted Label = 262, Prediction Score = 0.9950, Segment Video Label Score = 0.9950, Segment True Label Score = 0.0000, SV True Label = 0.0354, SV Predicted Label = 0.0346
#   Segment 3: Predicted Label = 262, Prediction Score = 0.9924, Segment Video Label Score = 0.9924, Segment True Label Score = 0.0000, SV True Label = 0.0614, SV Predicted Label = 0.0914
#   Segment 4: Predicted Label = 262, Prediction Score = 0.9062, Segment Video Label Score = 0.9062, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0139
#   Segment 5: Predicted Label = 262, Prediction Score = 0.9938, Segment Video Label Score = 0.9938, Segment True Label Score = 0.0000, SV True Label = 0.0908, SV Predicted Label = 0.0615
#   Segment 6: Predicted Label = 262, Prediction Score = 0.9961, Segment Video Label Score = 0.9961, Segment True Label Score = 0.0000, SV True Label = 0.0731, SV Predicted Label = 0.0799
#   Segment 7: Predicted Label = 262, Prediction Score = 0.9877, Segment Video Label Score = 0.9877, Segment True Label Score = 0.0000, SV True Label = 0.0345, SV Predicted Label = 0.0048
#   Segment 8: Predicted Label = 262, Prediction Score = 0.9905, Segment Video Label Score = 0.9905, Segment True Label Score = 0.0000, SV True Label = -0.0029, SV Predicted Label = 0.0170
# Video: y9r115bgfNk.mp4, Overall Predicted Label = 254, Overall Prediction Score = 0.4981, True Label = 325, True Label Score = 0.0001
#   Segment 1: Predicted Label = 254, Prediction Score = 0.9853, Segment Video Label Score = 0.9853, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.1557
#   Segment 2: Predicted Label = 254, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.2508
#   Segment 3: Predicted Label = 254, Prediction Score = 0.9998, Segment Video Label Score = 0.9998, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.2040
#   Segment 4: Predicted Label = 254, Prediction Score = 0.9998, Segment Video Label Score = 0.9998, Segment True Label Score = 0.0000, SV True Label = -0.0000, SV Predicted Label = 0.2359
#   Segment 5: Predicted Label = 123, Prediction Score = 0.7675, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = 0.0002, SV Predicted Label = -0.1984
#   Segment 6: Predicted Label = 123, Prediction Score = 0.7122, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = 0.0000, SV Predicted Label = -0.1912
#   Segment 7: Predicted Label = 123, Prediction Score = 0.8637, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = 0.0000, SV Predicted Label = -0.2062
#   Segment 8: Predicted Label = 212, Prediction Score = 0.5701, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0001, SV True Label = -0.0000, SV Predicted Label = -0.1742
# Video: 1hnDIZGrBGE.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.1153, True Label = 325, True Label Score = 0.0411
#   Segment 1: Predicted Label = 277, Prediction Score = 0.8576, Segment Video Label Score = 0.0356, Segment True Label Score = 0.0000, SV True Label = -0.0152, SV Predicted Label = -0.0216
#   Segment 2: Predicted Label = 147, Prediction Score = 0.1999, Segment Video Label Score = 0.0014, Segment True Label Score = 0.0146, SV True Label = -0.0119, SV Predicted Label = -0.0547
#   Segment 3: Predicted Label = 256, Prediction Score = 0.2095, Segment Video Label Score = 0.0157, Segment True Label Score = 0.0003, SV True Label = -0.0137, SV Predicted Label = -0.0415
#   Segment 4: Predicted Label = 20, Prediction Score = 0.2774, Segment Video Label Score = 0.0968, Segment True Label Score = 0.0034, SV True Label = -0.0205, SV Predicted Label = -0.0010
#   Segment 5: Predicted Label = 233, Prediction Score = 0.7129, Segment Video Label Score = 0.0009, Segment True Label Score = 0.0000, SV True Label = -0.0174, SV Predicted Label = -0.0358
#   Segment 6: Predicted Label = 1, Prediction Score = 0.7297, Segment Video Label Score = 0.7297, Segment True Label Score = 0.0000, SV True Label = -0.0126, SV Predicted Label = 0.2338
#   Segment 7: Predicted Label = 293, Prediction Score = 0.3917, Segment Video Label Score = 0.0357, Segment True Label Score = 0.0000, SV True Label = -0.0171, SV Predicted Label = -0.0224
#   Segment 8: Predicted Label = 320, Prediction Score = 0.3177, Segment Video Label Score = 0.0069, Segment True Label Score = 0.0001, SV True Label = 0.1125, SV Predicted Label = -0.0404
# Video: 4gGPVcFzI-M.mp4, Overall Predicted Label = 127, Overall Prediction Score = 0.2812, True Label = 325, True Label Score = 0.0135
#   Segment 1: Predicted Label = 97, Prediction Score = 0.1900, Segment Video Label Score = 0.0630, Segment True Label Score = 0.0000, SV True Label = -0.0048, SV Predicted Label = -0.0617
#   Segment 2: Predicted Label = 127, Prediction Score = 0.6712, Segment Video Label Score = 0.6712, Segment True Label Score = 0.0000, SV True Label = -0.0043, SV Predicted Label = 0.1309
#   Segment 3: Predicted Label = 127, Prediction Score = 0.2730, Segment Video Label Score = 0.2730, Segment True Label Score = 0.0000, SV True Label = 0.0267, SV Predicted Label = -0.0075
#   Segment 4: Predicted Label = 127, Prediction Score = 0.7635, Segment Video Label Score = 0.7635, Segment True Label Score = 0.0000, SV True Label = -0.0059, SV Predicted Label = 0.2196
#   Segment 5: Predicted Label = 316, Prediction Score = 0.4505, Segment Video Label Score = 0.3324, Segment True Label Score = 0.0000, SV True Label = 0.0004, SV Predicted Label = 0.0271
#   Segment 6: Predicted Label = 149, Prediction Score = 0.6236, Segment Video Label Score = 0.1360, Segment True Label Score = 0.0000, SV True Label = -0.0050, SV Predicted Label = -0.0485
#   Segment 7: Predicted Label = 180, Prediction Score = 0.6572, Segment Video Label Score = 0.0016, Segment True Label Score = 0.0000, SV True Label = -0.0009, SV Predicted Label = -0.1141
#   Segment 8: Predicted Label = 288, Prediction Score = 0.5488, Segment Video Label Score = 0.0093, Segment True Label Score = 0.0000, SV True Label = -0.0038, SV Predicted Label = -0.0968
# Video: -1fippPF1oI.mp4, Overall Predicted Label = 127, Overall Prediction Score = 0.2081, True Label = 325, True Label Score = 0.1520
#   Segment 1: Predicted Label = 127, Prediction Score = 0.9633, Segment Video Label Score = 0.9633, Segment True Label Score = 0.0000, SV True Label = -0.0592, SV Predicted Label = 0.2412
#   Segment 2: Predicted Label = 16, Prediction Score = 0.5120, Segment Video Label Score = 0.2230, Segment True Label Score = 0.0000, SV True Label = -0.0589, SV Predicted Label = 0.0155
#   Segment 3: Predicted Label = 320, Prediction Score = 0.1670, Segment Video Label Score = 0.1620, Segment True Label Score = 0.0003, SV True Label = 0.0075, SV Predicted Label = -0.0005
#   Segment 4: Predicted Label = 127, Prediction Score = 0.2907, Segment Video Label Score = 0.2907, Segment True Label Score = 0.0000, SV True Label = -0.0302, SV Predicted Label = 0.0364
#   Segment 5: Predicted Label = 320, Prediction Score = 0.9025, Segment Video Label Score = 0.0003, Segment True Label Score = 0.0000, SV True Label = 0.2606, SV Predicted Label = -0.0805
#   Segment 6: Predicted Label = 112, Prediction Score = 0.2509, Segment Video Label Score = 0.0046, Segment True Label Score = 0.0000, SV True Label = -0.0221, SV Predicted Label = -0.0503
#   Segment 7: Predicted Label = 79, Prediction Score = 0.3990, Segment Video Label Score = 0.0176, Segment True Label Score = 0.0002, SV True Label = -0.0243, SV Predicted Label = -0.0565
#   Segment 8: Predicted Label = 26, Prediction Score = 0.4388, Segment Video Label Score = 0.0034, Segment True Label Score = 0.0002, SV True Label = -0.0534, SV Predicted Label = -0.0676
# Video: riNGtZoFmNE.mp4, Overall Predicted Label = 127, Overall Prediction Score = 0.1146, True Label = 325, True Label Score = 0.0826
#   Segment 1: Predicted Label = 305, Prediction Score = 0.2380, Segment Video Label Score = 0.0009, Segment True Label Score = 0.0000, SV True Label = -0.0258, SV Predicted Label = -0.0561
#   Segment 2: Predicted Label = 100, Prediction Score = 0.4877, Segment Video Label Score = 0.0001, Segment True Label Score = 0.0000, SV True Label = -0.0223, SV Predicted Label = -0.0329
#   Segment 3: Predicted Label = 320, Prediction Score = 0.2139, Segment Video Label Score = 0.0007, Segment True Label Score = 0.0000, SV True Label = 0.0606, SV Predicted Label = -0.0459
#   Segment 4: Predicted Label = 127, Prediction Score = 0.9001, Segment Video Label Score = 0.9001, Segment True Label Score = 0.0000, SV True Label = -0.0306, SV Predicted Label = 0.2998
#   Segment 5: Predicted Label = 137, Prediction Score = 0.2352, Segment Video Label Score = 0.0070, Segment True Label Score = 0.0005, SV True Label = -0.0167, SV Predicted Label = -0.0346
#   Segment 6: Predicted Label = 150, Prediction Score = 0.1976, Segment Video Label Score = 0.0001, Segment True Label Score = 0.0000, SV True Label = -0.0148, SV Predicted Label = -0.0327
#   Segment 7: Predicted Label = 210, Prediction Score = 0.1184, Segment Video Label Score = 0.0073, Segment True Label Score = 0.0000, SV True Label = -0.0014, SV Predicted Label = -0.0450
#   Segment 8: Predicted Label = 233, Prediction Score = 0.5033, Segment Video Label Score = 0.0007, Segment True Label Score = 0.0000, SV True Label = 0.0628, SV Predicted Label = -0.0396
# Video: ZnIDviwA8CE.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.3576, True Label = 325, True Label Score = 0.3576
#   Segment 1: Predicted Label = 244, Prediction Score = 0.9689, Segment Video Label Score = 0.9689, Segment True Label Score = 0.0000, SV True Label = 0.2466, SV Predicted Label = 0.2432
#   Segment 2: Predicted Label = 244, Prediction Score = 0.8593, Segment Video Label Score = 0.8593, Segment True Label Score = 0.0000, SV True Label = 0.1708, SV Predicted Label = 0.2405
#   Segment 3: Predicted Label = 244, Prediction Score = 0.8552, Segment Video Label Score = 0.8552, Segment True Label Score = 0.0000, SV True Label = 0.1908, SV Predicted Label = 0.1839
#   Segment 4: Predicted Label = 233, Prediction Score = 0.3322, Segment Video Label Score = 0.0195, Segment True Label Score = 0.0000, SV True Label = -0.1400, SV Predicted Label = -0.1285
#   Segment 5: Predicted Label = 233, Prediction Score = 0.3794, Segment Video Label Score = 0.0654, Segment True Label Score = 0.0000, SV True Label = -0.0991, SV Predicted Label = -0.1144
#   Segment 6: Predicted Label = 346, Prediction Score = 0.3985, Segment Video Label Score = 0.0688, Segment True Label Score = 0.0000, SV True Label = -0.0937, SV Predicted Label = -0.0988
#   Segment 7: Predicted Label = 134, Prediction Score = 0.1925, Segment Video Label Score = 0.0212, Segment True Label Score = 0.0000, SV True Label = -0.1195, SV Predicted Label = -0.1162
#   Segment 8: Predicted Label = 247, Prediction Score = 0.7648, Segment Video Label Score = 0.0021, Segment True Label Score = 0.0000, SV True Label = -0.1078, SV Predicted Label = -0.1550
# Video: -zpKHNrNsn4.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.9967, True Label = 325, True Label Score = 0.9967
#   Segment 1: Predicted Label = 244, Prediction Score = 0.9954, Segment Video Label Score = 0.9954, Segment True Label Score = 0.0000, SV True Label = 0.0003, SV Predicted Label = -0.0359
#   Segment 2: Predicted Label = 244, Prediction Score = 0.9931, Segment Video Label Score = 0.9931, Segment True Label Score = 0.0000, SV True Label = 0.0263, SV Predicted Label = 0.0405
#   Segment 3: Predicted Label = 244, Prediction Score = 0.9967, Segment Video Label Score = 0.9967, Segment True Label Score = 0.0000, SV True Label = -0.0102, SV Predicted Label = -0.0242
#   Segment 4: Predicted Label = 244, Prediction Score = 0.9970, Segment Video Label Score = 0.9970, Segment True Label Score = 0.0000, SV True Label = 0.0367, SV Predicted Label = -0.0429
#   Segment 5: Predicted Label = 244, Prediction Score = 0.9982, Segment Video Label Score = 0.9982, Segment True Label Score = 0.0000, SV True Label = 0.0177, SV Predicted Label = 0.0468
#   Segment 6: Predicted Label = 244, Prediction Score = 0.9972, Segment Video Label Score = 0.9972, Segment True Label Score = 0.0000, SV True Label = 0.0473, SV Predicted Label = 0.0591
#   Segment 7: Predicted Label = 244, Prediction Score = 0.9974, Segment Video Label Score = 0.9974, Segment True Label Score = 0.0000, SV True Label = 0.0055, SV Predicted Label = 0.0359
#   Segment 8: Predicted Label = 244, Prediction Score = 0.9989, Segment Video Label Score = 0.9989, Segment True Label Score = 0.0000, SV True Label = 0.0226, SV Predicted Label = 0.0669
# Video: GCh5bbKJgbE.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.9431, True Label = 325, True Label Score = 0.9431
#   Segment 1: Predicted Label = 244, Prediction Score = 0.9533, Segment Video Label Score = 0.9533, Segment True Label Score = 0.0000, SV True Label = -0.0193, SV Predicted Label = 0.0169
#   Segment 2: Predicted Label = 244, Prediction Score = 0.8825, Segment Video Label Score = 0.8825, Segment True Label Score = 0.0000, SV True Label = 0.0118, SV Predicted Label = 0.0103
#   Segment 3: Predicted Label = 244, Prediction Score = 0.9693, Segment Video Label Score = 0.9693, Segment True Label Score = 0.0000, SV True Label = 0.0296, SV Predicted Label = 0.0309
#   Segment 4: Predicted Label = 244, Prediction Score = 0.9317, Segment Video Label Score = 0.9317, Segment True Label Score = 0.0000, SV True Label = 0.0388, SV Predicted Label = 0.0661
#   Segment 5: Predicted Label = 244, Prediction Score = 0.9795, Segment Video Label Score = 0.9795, Segment True Label Score = 0.0000, SV True Label = 0.0533, SV Predicted Label = 0.0227
#   Segment 6: Predicted Label = 244, Prediction Score = 0.9779, Segment Video Label Score = 0.9779, Segment True Label Score = 0.0000, SV True Label = 0.0306, SV Predicted Label = 0.0216
#   Segment 7: Predicted Label = 244, Prediction Score = 0.8858, Segment Video Label Score = 0.8858, Segment True Label Score = 0.0000, SV True Label = -0.0551, SV Predicted Label = -0.0265
#   Segment 8: Predicted Label = 244, Prediction Score = 0.9644, Segment Video Label Score = 0.9644, Segment True Label Score = 0.0000, SV True Label = 0.0493, SV Predicted Label = -0.0045
# Video: ymeIZj6pE-A.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.9805, True Label = 325, True Label Score = 0.9805
#   Segment 1: Predicted Label = 244, Prediction Score = 0.9974, Segment Video Label Score = 0.9974, Segment True Label Score = 0.0000, SV True Label = -0.0169, SV Predicted Label = -0.0178
#   Segment 2: Predicted Label = 244, Prediction Score = 0.9973, Segment Video Label Score = 0.9973, Segment True Label Score = 0.0000, SV True Label = 0.0469, SV Predicted Label = 0.0663
#   Segment 3: Predicted Label = 244, Prediction Score = 0.9961, Segment Video Label Score = 0.9961, Segment True Label Score = 0.0000, SV True Label = -0.0082, SV Predicted Label = 0.0717
#   Segment 4: Predicted Label = 244, Prediction Score = 0.9442, Segment Video Label Score = 0.9442, Segment True Label Score = 0.0000, SV True Label = -0.0276, SV Predicted Label = 0.0192
#   Segment 5: Predicted Label = 244, Prediction Score = 0.9298, Segment Video Label Score = 0.9298, Segment True Label Score = 0.0000, SV True Label = -0.0265, SV Predicted Label = 0.0207
#   Segment 6: Predicted Label = 244, Prediction Score = 0.9884, Segment Video Label Score = 0.9884, Segment True Label Score = 0.0000, SV True Label = 0.0167, SV Predicted Label = -0.0086
#   Segment 7: Predicted Label = 244, Prediction Score = 0.9962, Segment Video Label Score = 0.9962, Segment True Label Score = 0.0000, SV True Label = 0.0733, SV Predicted Label = -0.0038
#   Segment 8: Predicted Label = 244, Prediction Score = 0.9947, Segment Video Label Score = 0.9947, Segment True Label Score = 0.0000, SV True Label = 0.0862, SV Predicted Label = -0.0038
# Video: cVJpNDYeD6w.mp4, Overall Predicted Label = 244, Overall Prediction Score = 0.9220, True Label = 325, True Label Score = 0.9220
#   Segment 1: Predicted Label = 244, Prediction Score = 0.7458, Segment Video Label Score = 0.7458, Segment True Label Score = 0.0000, SV True Label = -0.0494, SV Predicted Label = -0.0450
#   Segment 2: Predicted Label = 244, Prediction Score = 0.9987, Segment Video Label Score = 0.9987, Segment True Label Score = 0.0000, SV True Label = 0.0197, SV Predicted Label = 0.0528
#   Segment 3: Predicted Label = 244, Prediction Score = 0.7265, Segment Video Label Score = 0.7265, Segment True Label Score = 0.0000, SV True Label = -0.0420, SV Predicted Label = -0.0829
#   Segment 4: Predicted Label = 244, Prediction Score = 0.9773, Segment Video Label Score = 0.9773, Segment True Label Score = 0.0000, SV True Label = 0.0449, SV Predicted Label = -0.0077
#   Segment 5: Predicted Label = 244, Prediction Score = 0.9651, Segment Video Label Score = 0.9651, Segment True Label Score = 0.0000, SV True Label = 0.0453, SV Predicted Label = 0.0001
#   Segment 6: Predicted Label = 244, Prediction Score = 0.9843, Segment Video Label Score = 0.9843, Segment True Label Score = 0.0000, SV True Label = 0.0062, SV Predicted Label = 0.0691
#   Segment 7: Predicted Label = 244, Prediction Score = 0.9956, Segment Video Label Score = 0.9956, Segment True Label Score = 0.0000, SV True Label = 0.0799, SV Predicted Label = 0.0521
#   Segment 8: Predicted Label = 244, Prediction Score = 0.9825, Segment Video Label Score = 0.9825, Segment True Label Score = 0.0000, SV True Label = 0.0286, SV Predicted Label = 0.0977
