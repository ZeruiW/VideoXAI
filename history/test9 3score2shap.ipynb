# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import itertools
import random
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm

# 加载模型和图像处理器
model = TimesformerForVideoClassification.from_pretrained("facebook/timesformer-base-finetuned-k400")
image_processor = AutoImageProcessor.from_pretrained("MCG-NJU/videomae-base-finetuned-kinetics")
model.to('cuda')  # 直接将模型加载到GPU中

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open("archive/kinetics400_val_list_videos.txt", "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

def split_video_into_segments(container, n_segments=8, frames_per_segment=16):
    frame_list = [frame.to_image() for frame in container.decode(video=0)]
    total_frames = len(frame_list)
    segment_length = total_frames // n_segments

    segments = []
    for i in range(n_segments):
        start_index = i * segment_length
        end_index = min(start_index + segment_length, total_frames)
        segment_frames = frame_list[start_index:end_index]

        while len(segment_frames) < frames_per_segment:
            segment_frames.append(segment_frames[-1])

        segments.append(segment_frames[:frames_per_segment])

    return segments

def predict_video_and_segments(model, image_processor, container, true_label):
    video_segments = split_video_into_segments(container)
    segment_outputs = []
    
    with torch.no_grad():
        # Process each segment
        for segment in video_segments:
            inputs = image_processor(list(segment), return_tensors="pt")
            inputs = {k: v.to('cuda') for k, v in inputs.items()}
            outputs = model(**inputs)
            logits = outputs.logits
            probabilities = F.softmax(logits, dim=-1)
            pred_label = logits.argmax(-1).item()
            pred_score = probabilities[0, pred_label].item()
            segment_outputs.append((pred_label, pred_score, probabilities))

        # Aggregate predictions for overall video prediction
        video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
        video_pred_label = video_probs.argmax().item()
        video_pred_score = video_probs[0, video_pred_label].item()
        video_true_score = video_probs[0, true_label].item()

    return video_pred_label, video_pred_score, video_true_score, segment_outputs

def shapley_value_approx(segment_outputs, label_index, num_samples=100):
    n = len(segment_outputs)
    shapley_values = [0] * n

    for _ in range(num_samples):
        random_subset = sorted(range(n), key=lambda _: random.random())  # 随机排序所有片段
        subset_prob = torch.zeros_like(segment_outputs[0][2])  # 初始化为零概率

        # 顺序添加片段，计算每次添加的边际贡献
        for i, index in enumerate(random_subset):
            old_contribution = subset_prob[0, label_index].item()
            subset_prob += segment_outputs[index][2]
            subset_prob /= (i + 1)  # 计算新的平均概率
            new_contribution = subset_prob[0, label_index].item()
            shapley_values[index] += new_contribution - old_contribution

    # 平均所有采样贡献
    shapley_values = [val / num_samples for val in shapley_values]
    return shapley_values

def process_videos(sampled_files, true_labels):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join("archive/videos_val", video_file)
        container = av.open(file_path)
        video_pred_label, video_pred_score, video_true_score, segment_outputs = predict_video_and_segments(model, image_processor, container, true_label)
        sv_true_label = shapley_value_approx(segment_outputs, true_label)
        sv_video_pred = shapley_value_approx(segment_outputs, video_pred_label)
        predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred))

    return predictions

# 准备视频样本
num_samples_per_class = 5
sampled_files = list(video_labels.items())[0][1][:num_samples_per_class]
true_labels = [list(video_labels.keys())[0]] * num_samples_per_class

# 获取数据和预测
video_data = process_videos(sampled_files, true_labels)

# 打印输出每个视频的整体预测结果及每个片段的结果
for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_labels[0]}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_labels[0]].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/5 [00:00<?, ?video/s]
# Video: jf7RDuUTrsQ.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.2028, True Label = 325, True Label Score = 0.0010
#   Segment 1: Predicted Label = 81, Prediction Score = 0.4557, Segment Video Label Score = 0.0373, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0588
#   Segment 2: Predicted Label = 171, Prediction Score = 0.6322, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0004, SV True Label = -0.0001, SV Predicted Label = -0.0747
#   Segment 3: Predicted Label = 1, Prediction Score = 0.5045, Segment Video Label Score = 0.5045, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.1109
#   Segment 4: Predicted Label = 289, Prediction Score = 0.4299, Segment Video Label Score = 0.1295, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0077
#   Segment 5: Predicted Label = 1, Prediction Score = 0.4968, Segment Video Label Score = 0.4968, Segment True Label Score = 0.0054, SV True Label = 0.0015, SV Predicted Label = 0.1049
#   Segment 6: Predicted Label = 127, Prediction Score = 0.4740, Segment Video Label Score = 0.4092, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.0854
#   Segment 7: Predicted Label = 57, Prediction Score = 0.3964, Segment Video Label Score = 0.0368, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = -0.0684
#   Segment 8: Predicted Label = 81, Prediction Score = 0.4700, Segment Video Label Score = 0.0048, Segment True Label Score = 0.0022, SV True Label = 0.0004, SV Predicted Label = -0.0628
# Video: EhRxb8-cNzQ.mp4, Overall Predicted Label = 149, Overall Prediction Score = 0.3158, True Label = 325, True Label Score = 0.0011
#   Segment 1: Predicted Label = 230, Prediction Score = 0.5502, Segment Video Label Score = 0.0019, Segment True Label Score = 0.0000, SV True Label = -0.0005, SV Predicted Label = -0.1103
#   Segment 2: Predicted Label = 230, Prediction Score = 0.6382, Segment Video Label Score = 0.0491, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0967
#   Segment 3: Predicted Label = 106, Prediction Score = 0.3546, Segment Video Label Score = 0.1676, Segment True Label Score = 0.0017, SV True Label = 0.0004, SV Predicted Label = -0.0737
#   Segment 4: Predicted Label = 122, Prediction Score = 0.1118, Segment Video Label Score = 0.0334, Segment True Label Score = 0.0066, SV True Label = 0.0018, SV Predicted Label = -0.1242
#   Segment 5: Predicted Label = 149, Prediction Score = 0.9921, Segment Video Label Score = 0.9921, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = 0.2623
#   Segment 6: Predicted Label = 149, Prediction Score = 0.8774, Segment Video Label Score = 0.8774, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.2394
#   Segment 7: Predicted Label = 127, Prediction Score = 0.5743, Segment Video Label Score = 0.0236, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = -0.0976
#   Segment 8: Predicted Label = 149, Prediction Score = 0.3811, Segment Video Label Score = 0.3811, Segment True Label Score = 0.0001, SV True Label = -0.0003, SV Predicted Label = 0.0413
# Video: l2_Da-CMPfY.mp4, Overall Predicted Label = 302, Overall Prediction Score = 0.4586, True Label = 325, True Label Score = 0.0588
#   Segment 1: Predicted Label = 302, Prediction Score = 0.9208, Segment Video Label Score = 0.9208, Segment True Label Score = 0.0099, SV True Label = -0.0188, SV Predicted Label = 0.2190
#   Segment 2: Predicted Label = 302, Prediction Score = 0.6358, Segment Video Label Score = 0.6358, Segment True Label Score = 0.0056, SV True Label = -0.0176, SV Predicted Label = 0.0775
#   Segment 3: Predicted Label = 302, Prediction Score = 0.6041, Segment Video Label Score = 0.6041, Segment True Label Score = 0.0125, SV True Label = -0.0145, SV Predicted Label = 0.0621
#   Segment 4: Predicted Label = 333, Prediction Score = 0.6571, Segment Video Label Score = 0.0046, Segment True Label Score = 0.0101, SV True Label = -0.0121, SV Predicted Label = -0.1805
#   Segment 5: Predicted Label = 313, Prediction Score = 0.3895, Segment Video Label Score = 0.0017, Segment True Label Score = 0.0196, SV True Label = -0.0165, SV Predicted Label = -0.1420
#   Segment 6: Predicted Label = 302, Prediction Score = 0.5067, Segment Video Label Score = 0.5067, Segment True Label Score = 0.0128, SV True Label = -0.0095, SV Predicted Label = 0.0252
#   Segment 7: Predicted Label = 302, Prediction Score = 0.9150, Segment Video Label Score = 0.9150, Segment True Label Score = 0.0030, SV True Label = -0.0149, SV Predicted Label = 0.1641
#   Segment 8: Predicted Label = 325, Prediction Score = 0.3969, Segment Video Label Score = 0.0797, Segment True Label Score = 0.3969, SV True Label = 0.1136, SV Predicted Label = -0.1626
# Video: RM4HvsOOp88.mp4, Overall Predicted Label = 173, Overall Prediction Score = 0.1174, True Label = 325, True Label Score = 0.0126
#   Segment 1: Predicted Label = 154, Prediction Score = 0.1408, Segment Video Label Score = 0.0118, Segment True Label Score = 0.0207, SV True Label = 0.0032, SV Predicted Label = -0.0474
#   Segment 2: Predicted Label = 346, Prediction Score = 0.2853, Segment Video Label Score = 0.1702, Segment True Label Score = 0.0049, SV True Label = -0.0038, SV Predicted Label = 0.0051
#   Segment 3: Predicted Label = 393, Prediction Score = 0.1789, Segment Video Label Score = 0.0123, Segment True Label Score = 0.0091, SV True Label = -0.0021, SV Predicted Label = -0.0415
#   Segment 4: Predicted Label = 173, Prediction Score = 0.1861, Segment Video Label Score = 0.1861, Segment True Label Score = 0.0242, SV True Label = 0.0075, SV Predicted Label = 0.0264
#   Segment 5: Predicted Label = 34, Prediction Score = 0.1253, Segment Video Label Score = 0.0002, Segment True Label Score = 0.0227, SV True Label = 0.0039, SV Predicted Label = -0.0362
#   Segment 6: Predicted Label = 306, Prediction Score = 0.1284, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0139, SV True Label = 0.0012, SV Predicted Label = -0.0480
#   Segment 7: Predicted Label = 346, Prediction Score = 0.5618, Segment Video Label Score = 0.0184, Segment True Label Score = 0.0050, SV True Label = -0.0034, SV Predicted Label = -0.0394
#   Segment 8: Predicted Label = 173, Prediction Score = 0.5401, Segment Video Label Score = 0.5401, Segment True Label Score = 0.0005, SV True Label = -0.0047, SV Predicted Label = 0.1914
# Video: t8_Dpyynb4Q.mp4, Overall Predicted Label = 325, Overall Prediction Score = 0.3822, True Label = 325, True Label Score = 0.3822
#   Segment 1: Predicted Label = 151, Prediction Score = 0.7113, Segment Video Label Score = 0.1771, Segment True Label Score = 0.1771, SV True Label = -0.0790, SV Predicted Label = -0.0841
#   Segment 2: Predicted Label = 151, Prediction Score = 0.6033, Segment Video Label Score = 0.2685, Segment True Label Score = 0.2685, SV True Label = -0.0319, SV Predicted Label = -0.0580
#   Segment 3: Predicted Label = 325, Prediction Score = 0.7452, Segment Video Label Score = 0.7452, Segment True Label Score = 0.7452, SV True Label = 0.1704, SV Predicted Label = 0.1621
#   Segment 4: Predicted Label = 325, Prediction Score = 0.4328, Segment Video Label Score = 0.4328, Segment True Label Score = 0.4328, SV True Label = 0.0218, SV Predicted Label = 0.0327
#   Segment 5: Predicted Label = 151, Prediction Score = 0.5141, Segment Video Label Score = 0.2136, Segment True Label Score = 0.2136, SV True Label = -0.0648, SV Predicted Label = -0.0351
#   Segment 6: Predicted Label = 151, Prediction Score = 0.6258, Segment Video Label Score = 0.1794, Segment True Label Score = 0.1794, SV True Label = -0.1015, SV Predicted Label = -0.0745
#   Segment 7: Predicted Label = 325, Prediction Score = 0.4142, Segment Video Label Score = 0.4142, Segment True Label Score = 0.4142, SV True Label = 0.0181, SV Predicted Label = 0.0365
#   Segment 8: Predicted Label = 325, Prediction Score = 0.6271, Segment Video Label Score = 0.6271, Segment True Label Score = 0.6271, SV True Label = 0.1212, SV Predicted Label = 0.0765
