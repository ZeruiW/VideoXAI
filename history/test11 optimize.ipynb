# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm

# 定义视频处理类
class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        # 用户可以在这里更换为ViViT模型，例如：
        # if "vivit" in model_name.lower():
        #     return ViViTForVideoClassification.from_pretrained(model_name)
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                outputs = self.model(**inputs)
                logits = outputs.logits
                probabilities = F.softmax(logits, dim=-1)
                pred_label = logits.argmax(-1).item()
                pred_score = probabilities[0, pred_label].item()
                segment_outputs.append((pred_label, pred_score, probabilities))
        return segment_outputs

# 定义Shapley值计算类
class ShapleyCalculator:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

def process_videos(video_processor, shap_calculator, sampled_files, true_labels):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join("archive/videos_val", video_file)
        container = av.open(file_path)
        segment_outputs = video_processor.predict_video_and_segments(container, true_label)
        video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
        video_pred_label = video_probs.argmax().item()
        video_pred_score = video_probs[0, video_pred_label].item()
        video_true_score = video_probs[0, true_label].item()
        
        sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
        sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
        
        predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred))
    return predictions

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, true_labels[0]].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,
    "num_samples_per_class": 5,
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val"
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = ShapleyCalculator(num_samples=config["num_samples"])

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

# 准备视频样本
sampled_files = list(video_labels.items())[0][1][:config["num_samples_per_class"]]
true_labels = [list(video_labels.keys())[0]] * config["num_samples_per_class"]

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, sampled_files, true_labels)

# 打印并保存结果
save_results(video_data)

# 打印结果以便查看
for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_labels[0]}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_labels[0]].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/5 [00:00<?, ?video/s]
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/transformers/feature_extraction_utils.py:141: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   return torch.tensor(value)
# Video: jf7RDuUTrsQ.mp4, Overall Predicted Label = 1, Overall Prediction Score = 0.2028, True Label = 325, True Label Score = 0.0010
#   Segment 1: Predicted Label = 81, Prediction Score = 0.4557, Segment Video Label Score = 0.0373, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = -0.0540
#   Segment 2: Predicted Label = 171, Prediction Score = 0.6322, Segment Video Label Score = 0.0035, Segment True Label Score = 0.0004, SV True Label = -0.0002, SV Predicted Label = -0.0642
#   Segment 3: Predicted Label = 1, Prediction Score = 0.5045, Segment Video Label Score = 0.5045, Segment True Label Score = 0.0000, SV True Label = -0.0004, SV Predicted Label = 0.1339
#   Segment 4: Predicted Label = 289, Prediction Score = 0.4299, Segment Video Label Score = 0.1295, Segment True Label Score = 0.0000, SV True Label = -0.0005, SV Predicted Label = -0.0228
#   Segment 5: Predicted Label = 1, Prediction Score = 0.4968, Segment Video Label Score = 0.4968, Segment True Label Score = 0.0054, SV True Label = 0.0017, SV Predicted Label = 0.1150
#   Segment 6: Predicted Label = 127, Prediction Score = 0.4740, Segment Video Label Score = 0.4092, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.0696
#   Segment 7: Predicted Label = 57, Prediction Score = 0.3964, Segment Video Label Score = 0.0368, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.0670
#   Segment 8: Predicted Label = 81, Prediction Score = 0.4700, Segment Video Label Score = 0.0048, Segment True Label Score = 0.0022, SV True Label = 0.0005, SV Predicted Label = -0.0783
# Video: EhRxb8-cNzQ.mp4, Overall Predicted Label = 149, Overall Prediction Score = 0.3158, True Label = 325, True Label Score = 0.0011
#   Segment 1: Predicted Label = 230, Prediction Score = 0.5502, Segment Video Label Score = 0.0019, Segment True Label Score = 0.0000, SV True Label = -0.0005, SV Predicted Label = -0.0983
#   Segment 2: Predicted Label = 230, Prediction Score = 0.6382, Segment Video Label Score = 0.0491, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.1088
#   Segment 3: Predicted Label = 106, Prediction Score = 0.3546, Segment Video Label Score = 0.1676, Segment True Label Score = 0.0017, SV True Label = 0.0003, SV Predicted Label = -0.0589
#   Segment 4: Predicted Label = 122, Prediction Score = 0.1118, Segment Video Label Score = 0.0334, Segment True Label Score = 0.0066, SV True Label = 0.0023, SV Predicted Label = -0.0928
#   Segment 5: Predicted Label = 149, Prediction Score = 0.9921, Segment Video Label Score = 0.9921, Segment True Label Score = 0.0000, SV True Label = -0.0005, SV Predicted Label = 0.2462
#   Segment 6: Predicted Label = 149, Prediction Score = 0.8774, Segment Video Label Score = 0.8774, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = 0.2483
#   Segment 7: Predicted Label = 127, Prediction Score = 0.5743, Segment Video Label Score = 0.0236, Segment True Label Score = 0.0000, SV True Label = -0.0003, SV Predicted Label = -0.1100
#   Segment 8: Predicted Label = 149, Prediction Score = 0.3811, Segment Video Label Score = 0.3811, Segment True Label Score = 0.0001, SV True Label = -0.0004, SV Predicted Label = 0.0249
# Video: l2_Da-CMPfY.mp4, Overall Predicted Label = 302, Overall Prediction Score = 0.4586, True Label = 325, True Label Score = 0.0588
#   Segment 1: Predicted Label = 302, Prediction Score = 0.9208, Segment Video Label Score = 0.9208, Segment True Label Score = 0.0099, SV True Label = -0.0166, SV Predicted Label = 0.2198
#   Segment 2: Predicted Label = 302, Prediction Score = 0.6358, Segment Video Label Score = 0.6358, Segment True Label Score = 0.0056, SV True Label = -0.0212, SV Predicted Label = 0.0622
#   Segment 3: Predicted Label = 302, Prediction Score = 0.6041, Segment Video Label Score = 0.6041, Segment True Label Score = 0.0125, SV True Label = -0.0202, SV Predicted Label = 0.0386
#   Segment 4: Predicted Label = 333, Prediction Score = 0.6571, Segment Video Label Score = 0.0046, Segment True Label Score = 0.0101, SV True Label = -0.0145, SV Predicted Label = -0.1619
#   Segment 5: Predicted Label = 313, Prediction Score = 0.3895, Segment Video Label Score = 0.0017, Segment True Label Score = 0.0196, SV True Label = -0.0158, SV Predicted Label = -0.1607
#   Segment 6: Predicted Label = 302, Prediction Score = 0.5067, Segment Video Label Score = 0.5067, Segment True Label Score = 0.0128, SV True Label = -0.0155, SV Predicted Label = -0.0169
#   Segment 7: Predicted Label = 302, Prediction Score = 0.9150, Segment Video Label Score = 0.9150, Segment True Label Score = 0.0030, SV True Label = -0.0198, SV Predicted Label = 0.2228
#   Segment 8: Predicted Label = 325, Prediction Score = 0.3969, Segment Video Label Score = 0.0797, Segment True Label Score = 0.3969, SV True Label = 0.1331, SV Predicted Label = -0.1396
# Video: RM4HvsOOp88.mp4, Overall Predicted Label = 173, Overall Prediction Score = 0.1174, True Label = 325, True Label Score = 0.0126
#   Segment 1: Predicted Label = 154, Prediction Score = 0.1408, Segment Video Label Score = 0.0118, Segment True Label Score = 0.0207, SV True Label = 0.0028, SV Predicted Label = -0.0485
#   Segment 2: Predicted Label = 346, Prediction Score = 0.2853, Segment Video Label Score = 0.1702, Segment True Label Score = 0.0049, SV True Label = -0.0029, SV Predicted Label = 0.0218
#   Segment 3: Predicted Label = 393, Prediction Score = 0.1789, Segment Video Label Score = 0.0123, Segment True Label Score = 0.0091, SV True Label = -0.0011, SV Predicted Label = -0.0394
#   Segment 4: Predicted Label = 173, Prediction Score = 0.1861, Segment Video Label Score = 0.1861, Segment True Label Score = 0.0242, SV True Label = 0.0058, SV Predicted Label = 0.0346
#   Segment 5: Predicted Label = 34, Prediction Score = 0.1253, Segment Video Label Score = 0.0002, Segment True Label Score = 0.0227, SV True Label = 0.0036, SV Predicted Label = -0.0399
#   Segment 6: Predicted Label = 306, Prediction Score = 0.1284, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0139, SV True Label = 0.0002, SV Predicted Label = -0.0403
#   Segment 7: Predicted Label = 346, Prediction Score = 0.5618, Segment Video Label Score = 0.0184, Segment True Label Score = 0.0050, SV True Label = -0.0023, SV Predicted Label = -0.0313
#   Segment 8: Predicted Label = 173, Prediction Score = 0.5401, Segment Video Label Score = 0.5401, Segment True Label Score = 0.0005, SV True Label = -0.0045, SV Predicted Label = 0.1554
# Video: t8_Dpyynb4Q.mp4, Overall Predicted Label = 325, Overall Prediction Score = 0.3822, True Label = 325, True Label Score = 0.3822
#   Segment 1: Predicted Label = 151, Prediction Score = 0.7113, Segment Video Label Score = 0.1771, Segment True Label Score = 0.1771, SV True Label = -0.0966, SV Predicted Label = -0.0659
#   Segment 2: Predicted Label = 151, Prediction Score = 0.6033, Segment Video Label Score = 0.2685, Segment True Label Score = 0.2685, SV True Label = -0.0521, SV Predicted Label = -0.0448
#   Segment 3: Predicted Label = 325, Prediction Score = 0.7452, Segment Video Label Score = 0.7452, Segment True Label Score = 0.7452, SV True Label = 0.1913, SV Predicted Label = 0.1077
#   Segment 4: Predicted Label = 325, Prediction Score = 0.4328, Segment Video Label Score = 0.4328, Segment True Label Score = 0.4328, SV True Label = 0.0295, SV Predicted Label = 0.0424
#   Segment 5: Predicted Label = 151, Prediction Score = 0.5141, Segment Video Label Score = 0.2136, Segment True Label Score = 0.2136, SV True Label = -0.0771, SV Predicted Label = -0.0555
#   Segment 6: Predicted Label = 151, Prediction Score = 0.6258, Segment Video Label Score = 0.1794, Segment True Label Score = 0.1794, SV True Label = -0.0812, SV Predicted Label = -0.0674
#   Segment 7: Predicted Label = 325, Prediction Score = 0.4142, Segment Video Label Score = 0.4142, Segment True Label Score = 0.4142, SV True Label = 0.0068, SV Predicted Label = 0.0206
#   Segment 8: Predicted Label = 325, Prediction Score = 0.6271, Segment Video Label Score = 0.6271, Segment True Label Score = 0.6271, SV True Label = 0.1341, SV Predicted Label = 0.1194
