# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                outputs = self.model(**inputs)
                logits = outputs.logits
                probabilities = F.softmax(logits, dim=-1)
                pred_label = logits.argmax(-1).item()
                pred_score = probabilities[0, pred_label].item()
                segment_outputs.append((pred_label, pred_score, probabilities))
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        segment_outputs = video_processor.predict_video_and_segments(container, true_label)
        video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
        video_pred_label = video_probs.argmax().item()
        video_pred_score = video_probs[0, video_pred_label].item()
        video_true_score = video_probs[0, true_label].item()
        
        if use_exact:
            sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
            sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
        else:
            sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
            sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
        
        predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred))
    return predictions

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, true_labels[predictions.index((video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred))]].item()  # 使用当前 video 的 true_label
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,  # 近似 Shapley Value 计算的采样次数
    "num_classes": 2,    # 要测试的类的数量
    "num_samples_per_class": 2,  # 每个类的样本数量
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": True  # 设置为 True 以使用精确 Shapley Value 计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

# 准备视频样本
sampled_files = []
true_labels = []
selected_classes = random.sample(list(video_labels.keys()), config["num_classes"])  # 随机选择指定数量的类别
for cls in selected_classes:
    sampled_files.extend(random.sample(video_labels[cls], config["num_samples_per_class"]))  # 从每个类别中随机选择指定数量的样本
    true_labels.extend([cls] * config["num_samples_per_class"])

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=config["use_exact"])

# 打印并保存结果
save_results(video_data)

# 打印结果以便查看
for video_file, video_pred_label, video_pred_score, video_true_score, segment_outputs, sv_true_label, sv_video_pred in video_data:
    true_label = true_labels[sampled_files.index(video_file)]
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_label}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_label].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/4 [00:00<?, ?video/s]
# Video: v3huVwrvWE4.mp4, Overall Predicted Label = 274, Overall Prediction Score = 0.3703, True Label = 274, True Label Score = 0.3703
#   Segment 1: Predicted Label = 274, Prediction Score = 0.5398, Segment Video Label Score = 0.5398, Segment True Label Score = 0.5398, SV True Label = 0.0509, SV Predicted Label = 0.0509
#   Segment 2: Predicted Label = 274, Prediction Score = 0.8703, Segment Video Label Score = 0.8703, Segment True Label Score = 0.8703, SV True Label = 0.1446, SV Predicted Label = 0.1446
#   Segment 3: Predicted Label = 199, Prediction Score = 0.5585, Segment Video Label Score = 0.2043, Segment True Label Score = 0.2043, SV True Label = -0.0442, SV Predicted Label = -0.0442
#   Segment 4: Predicted Label = 274, Prediction Score = 0.7340, Segment Video Label Score = 0.7340, Segment True Label Score = 0.7340, SV True Label = 0.1060, SV Predicted Label = 0.1060
#   Segment 5: Predicted Label = 175, Prediction Score = 0.3332, Segment Video Label Score = 0.1794, Segment True Label Score = 0.1794, SV True Label = -0.0512, SV Predicted Label = -0.0512
#   Segment 6: Predicted Label = 261, Prediction Score = 0.5145, Segment Video Label Score = 0.4267, Segment True Label Score = 0.4267, SV True Label = 0.0189, SV Predicted Label = 0.0189
#   Segment 7: Predicted Label = 261, Prediction Score = 0.9819, Segment Video Label Score = 0.0071, Segment True Label Score = 0.0071, SV True Label = -0.1001, SV Predicted Label = -0.1001
#   Segment 8: Predicted Label = 261, Prediction Score = 0.9930, Segment Video Label Score = 0.0012, Segment True Label Score = 0.0012, SV True Label = -0.1017, SV Predicted Label = -0.1017
# Video: 8q1JCjiSvMI.mp4, Overall Predicted Label = 274, Overall Prediction Score = 0.2024, True Label = 274, True Label Score = 0.2024
#   Segment 1: Predicted Label = 121, Prediction Score = 0.3737, Segment Video Label Score = 0.0007, Segment True Label Score = 0.0007, SV True Label = -0.0556, SV Predicted Label = -0.0556
#   Segment 2: Predicted Label = 121, Prediction Score = 0.3274, Segment Video Label Score = 0.0004, Segment True Label Score = 0.0004, SV True Label = -0.0557, SV Predicted Label = -0.0557
#   Segment 3: Predicted Label = 48, Prediction Score = 0.2113, Segment Video Label Score = 0.0328, Segment True Label Score = 0.0328, SV True Label = -0.0465, SV Predicted Label = -0.0465
#   Segment 4: Predicted Label = 274, Prediction Score = 0.3834, Segment Video Label Score = 0.3834, Segment True Label Score = 0.3834, SV True Label = 0.0529, SV Predicted Label = 0.0529
#   Segment 5: Predicted Label = 274, Prediction Score = 0.9987, Segment Video Label Score = 0.9987, Segment True Label Score = 0.9987, SV True Label = 0.2273, SV Predicted Label = 0.2273
#   Segment 6: Predicted Label = 378, Prediction Score = 0.4643, Segment Video Label Score = 0.1827, Segment True Label Score = 0.1827, SV True Label = -0.0040, SV Predicted Label = -0.0040
#   Segment 7: Predicted Label = 277, Prediction Score = 0.2952, Segment Video Label Score = 0.0100, Segment True Label Score = 0.0100, SV True Label = -0.0529, SV Predicted Label = -0.0529
#   Segment 8: Predicted Label = 219, Prediction Score = 0.4238, Segment Video Label Score = 0.0104, Segment True Label Score = 0.0104, SV True Label = -0.0529, SV Predicted Label = -0.0529
# Video: _UHqvOqbqzc.mp4, Overall Predicted Label = 395, Overall Prediction Score = 0.9311, True Label = 395, True Label Score = 0.9311
#   Segment 1: Predicted Label = 395, Prediction Score = 0.9712, Segment Video Label Score = 0.9712, Segment True Label Score = 0.9712, SV True Label = 0.0186, SV Predicted Label = 0.0186
#   Segment 2: Predicted Label = 395, Prediction Score = 0.7827, Segment Video Label Score = 0.7827, Segment True Label Score = 0.7827, SV True Label = -0.0348, SV Predicted Label = -0.0348
#   Segment 3: Predicted Label = 395, Prediction Score = 0.8783, Segment Video Label Score = 0.8783, Segment True Label Score = 0.8783, SV True Label = -0.0077, SV Predicted Label = -0.0077
#   Segment 4: Predicted Label = 395, Prediction Score = 0.9626, Segment Video Label Score = 0.9626, Segment True Label Score = 0.9626, SV True Label = 0.0162, SV Predicted Label = 0.0162
#   Segment 5: Predicted Label = 395, Prediction Score = 0.9485, Segment Video Label Score = 0.9485, Segment True Label Score = 0.9485, SV True Label = 0.0122, SV Predicted Label = 0.0122
#   Segment 6: Predicted Label = 395, Prediction Score = 0.9553, Segment Video Label Score = 0.9553, Segment True Label Score = 0.9553, SV True Label = 0.0141, SV Predicted Label = 0.0141
#   Segment 7: Predicted Label = 395, Prediction Score = 0.9632, Segment Video Label Score = 0.9632, Segment True Label Score = 0.9632, SV True Label = 0.0164, SV Predicted Label = 0.0164
#   Segment 8: Predicted Label = 395, Prediction Score = 0.9873, Segment Video Label Score = 0.9873, Segment True Label Score = 0.9873, SV True Label = 0.0232, SV Predicted Label = 0.0232
# Video: SLHqXKWlQx4.mp4, Overall Predicted Label = 395, Overall Prediction Score = 0.9676, True Label = 395, True Label Score = 0.9676
#   Segment 1: Predicted Label = 395, Prediction Score = 0.9332, Segment Video Label Score = 0.9332, Segment True Label Score = 0.9332, SV True Label = -0.0022, SV Predicted Label = -0.0022
#   Segment 2: Predicted Label = 395, Prediction Score = 0.9127, Segment Video Label Score = 0.9127, Segment True Label Score = 0.9127, SV True Label = -0.0080, SV Predicted Label = -0.0080
#   Segment 3: Predicted Label = 395, Prediction Score = 0.9796, Segment Video Label Score = 0.9796, Segment True Label Score = 0.9796, SV True Label = 0.0110, SV Predicted Label = 0.0110
#   Segment 4: Predicted Label = 395, Prediction Score = 0.9688, Segment Video Label Score = 0.9688, Segment True Label Score = 0.9688, SV True Label = 0.0079, SV Predicted Label = 0.0079
#   Segment 5: Predicted Label = 395, Prediction Score = 0.9828, Segment Video Label Score = 0.9828, Segment True Label Score = 0.9828, SV True Label = 0.0119, SV Predicted Label = 0.0119
#   Segment 6: Predicted Label = 395, Prediction Score = 0.9846, Segment Video Label Score = 0.9846, Segment True Label Score = 0.9846, SV True Label = 0.0124, SV Predicted Label = 0.0124
#   Segment 7: Predicted Label = 395, Prediction Score = 0.9930, Segment Video Label Score = 0.9930, Segment True Label Score = 0.9930, SV True Label = 0.0148, SV Predicted Label = 0.0148
#   Segment 8: Predicted Label = 395, Prediction Score = 0.9859, Segment Video Label Score = 0.9859, Segment True Label Score = 0.9859, SV True Label = 0.0127, SV Predicted Label = 0.0127
