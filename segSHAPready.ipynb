# %% [markdown]
# CPU Adversarial Pertubation

# %%
import os
import cv2
import numpy as np
from PIL import Image
from tqdm import tqdm
from skimage.util import random_noise
from skimage.filters import gaussian
from skimage.transform import rescale, AffineTransform, warp
from scipy.ndimage import zoom as scizoom

def add_gaussian_noise(image):
    noisy_image = random_noise(image, mode='gaussian', mean=0, var=0.01)
    return (noisy_image * 255).astype(np.uint8)

def add_motion_blur(image):
    size = 5  # Size of the kernel
    kernel_motion_blur = np.zeros((size, size))
    kernel_motion_blur[int((size-1)/2), :] = np.ones(size)
    kernel_motion_blur = kernel_motion_blur / size
    output = cv2.filter2D(image, -1, kernel_motion_blur)
    return output

def add_shot_noise(image):
    image = image / 255.0
    noisy_image = np.random.poisson(image * 255) / 255.0
    noisy_image = np.clip(noisy_image, 0, 1) * 255
    return noisy_image.astype(np.uint8)

def add_zoom_blur(image, zoom_factor=2):
    h, w = image.shape[:2]
    # Zoom in to the image and then crop to original size
    zoomed = scizoom(image, (zoom_factor, zoom_factor, 1))
    start_h = (zoomed.shape[0] - h) // 2
    start_w = (zoomed.shape[1] - w) // 2
    zoomed_cropped = zoomed[start_h:start_h+h, start_w:start_w+w]
    return zoomed_cropped.astype(np.uint8)

def process_videos(input_folder, output_folder, perturbation_type='gaussian_noise'):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for dirname, _, filenames in os.walk(input_folder):
        for filename in tqdm(filenames):
            if filename.endswith('.mp4'):
                cap = cv2.VideoCapture(os.path.join(dirname, filename))
                
                # Get properties from input to use on output
                frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                fps = cap.get(cv2.CAP_PROP_FPS)
                
                fourcc = cv2.VideoWriter_fourcc(*'mp4v')
                out_path = os.path.join(output_folder, filename)
                out = cv2.VideoWriter(out_path, fourcc, fps, (frame_width, frame_height))
                
                while True:
                    ret, frame = cap.read()
                    if not ret:
                        break
                    
                    if perturbation_type == 'gaussian_noise':
                        frame = add_gaussian_noise(frame)
                    elif perturbation_type == 'motion_blur':
                        frame = add_motion_blur(frame)
                    elif perturbation_type == 'shot_noise':
                        frame = add_shot_noise(frame)
                    elif perturbation_type == 'zoom_blur':
                        frame = add_zoom_blur(frame)
                    
                    out.write(frame)
                
                cap.release()
                out.release()

# Example usage:
input_folder = 'archive/videos_val'
output_folder = 'archive/gaussian_noise_perturbated'
perturbation_type = 'gaussian_noise'  # Can be 'gaussian_noise', 'shot_noise', or 'motion_blur'

process_videos(input_folder, output_folder, perturbation_type)
# Out:
#   0%|          | 0/19796 [00:00<?, ?it/s]
#   0%|          | 20/19796 [01:24<23:13:07,  4.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 80
#      77 output_folder = 'archive/gaussian_noise_perturbated'
#      78 perturbation_type = 'gaussian_noise'  # Can be 'gaussian_noise', 'shot_noise', or 'motion_blur'
# ---> 80 process_videos(input_folder, output_folder, perturbation_type)
#
# Cell In[5], line 62, in process_videos(input_folder, output_folder, perturbation_type)
#      59     break
#      61 if perturbation_type == 'gaussian_noise':
# ---> 62     frame = add_gaussian_noise(frame)
#      63 elif perturbation_type == 'motion_blur':
#      64     frame = add_motion_blur(frame)
#
# Cell In[5], line 12, in add_gaussian_noise(image)
#      11 def add_gaussian_noise(image):
# ---> 12     noisy_image = random_noise(image, mode='gaussian', mean=0, var=0.01)
#      13     return (noisy_image * 255).astype(np.uint8)
#
# File ~/.local/lib/python3.12/site-packages/skimage/util/noise.py:175, in random_noise(image, mode, rng, clip, **kwargs)
#     172     kwargs.setdefault(kw, kwdefaults[kw])
#     174 if mode == 'gaussian':
# --> 175     noise = rng.normal(kwargs['mean'], kwargs['var'] ** 0.5, image.shape)
#     176     out = image + noise
#     178 elif mode == 'localvar':
#     179     # Ensure local variance input is correct
#
# KeyboardInterrupt:

# %% [markdown]
# GPU Adversarial Pertubation

# %%
import os
import cv2
import numpy as np
from PIL import Image
import torch
import torchvision.transforms.functional as TF
from tqdm import tqdm
from skimage.util import random_noise
from skimage.filters import gaussian
from scipy.ndimage import zoom as scizoom

# 设置使用的设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 添加高斯噪声
def add_gaussian_noise(image, std=0.1):
    noise = torch.randn(image.size(), device=device) * std
    noisy_image = image + noise
    return noisy_image.clamp(0, 1)

# 添加射击噪声
def add_shot_noise(image, scale=50):
    noisy_image = torch.poisson(image * scale) / scale
    return noisy_image.clamp(0, 1)

# 添加运动模糊
def add_motion_blur(image, kernel_size=5):
    kernel_motion_blur = torch.zeros((3, 1, kernel_size, kernel_size), device=device)
    kernel_motion_blur[:, 0, kernel_size//2, :] = torch.ones(kernel_size)
    kernel_motion_blur /= kernel_size
    padded_image = torch.nn.functional.pad(image, (kernel_size//2, kernel_size//2, kernel_size//2, kernel_size//2), mode='replicate')
    image_blurred = torch.nn.functional.conv2d(padded_image.unsqueeze(0), kernel_motion_blur, groups=3)
    return image_blurred.squeeze(0)

# 添加缩放模糊
def add_zoom_blur(image, zoom_factor=1.1):
    h, w = image.shape[1:]
    image_zoomed = TF.resize(image, int(zoom_factor * max(h, w)))
    center_crop = TF.center_crop(image_zoomed, [h, w])
    return center_crop

# 视频处理函数
def process_videos(input_folder, output_folder, perturbation_type='gaussian_noise', param=0.1):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in tqdm(os.listdir(input_folder)):
        if filename.endswith('.mp4'):
            cap = cv2.VideoCapture(os.path.join(input_folder, filename))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = cap.get(cv2.CAP_PROP_FPS)
            
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out_path = os.path.join(output_folder, filename)
            out = cv2.VideoWriter(out_path, fourcc, fps, (frame_width, frame_height))
            
            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                
                frame = TF.to_tensor(frame).to(device)
                
                if perturbation_type == 'gaussian_noise':
                    frame = add_gaussian_noise(frame, std=param)
                elif perturbation_type == 'shot_noise':
                    frame = add_shot_noise(frame, scale=param)
                elif perturbation_type == 'motion_blur':
                    frame = add_motion_blur(frame, kernel_size=int(param))
                elif perturbation_type == 'zoom_blur':
                    frame = add_zoom_blur(frame, zoom_factor=param)
                
                frame = TF.to_pil_image(frame.cpu())
                frame = np.array(frame)
                out.write(frame)
            
            cap.release()
            out.release()

# Example usage
input_folder = 'archive/videos_val'
output_folder = 'archive/zoom_blur'
perturbation_type = 'zoom_blur'  # Can be 'gaussian_noise', 'shot_noise', 'motion_blur', 'zoom_blur'
param = 1.1  # Example parameters: 0.1 for gaussian_noise, 3000 for shot_noise, 5 for motion_blur, 1.1 for zoom_blur

process_videos(input_folder, output_folder, perturbation_type, param)
# Out:
#   0%|          | 0/19796 [00:00<?, ?it/s]
# 100%|██████████| 19796/19796 [8:04:16<00:00,  1.47s/it]

# %% [markdown]
# Select class Run 1 n_segments=8, frames_per_segment=16

# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                try:
                    outputs = self.model(**inputs)
                    logits = outputs.logits
                    probabilities = F.softmax(logits, dim=-1)
                    pred_label = logits.argmax(-1).item()
                    pred_score = probabilities[0, pred_label].item()
                    segment_outputs.append((pred_label, pred_score, probabilities))
                except RuntimeError as e:
                    print(f"Error processing segment: {e}")
                    continue
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        try:
            segment_outputs = video_processor.predict_video_and_segments(container, true_label)
            if not segment_outputs:
                print(f"Skipping video {video_file} due to empty segment outputs.")
                continue
            video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
            video_pred_label = video_probs.argmax().item()
            video_pred_score = video_probs[0, video_pred_label].item()
            video_true_score = video_probs[0, true_label].item()
            
            if use_exact:
                sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
            else:
                sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
            
            predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred))
        except Exception as e:
            print(f"Error processing video {video_file}: {e}")
            continue
    return predictions

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "video_true_label": video_true_label,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, video_true_label].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,  # 近似 Shapley Value 计算的采样次数
    "num_classes": 10,    # 要测试的类的数量
    "num_samples_per_class": 3,  # 每个类的样本数量
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": True  # 设置为 True 以使用精确 Shapley Value 计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签，并按类别组织
video_labels = defaultdict(list)
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

# 准备视频样本
sampled_files = []
true_labels = []
selected_classes = random.sample(list(video_labels.keys()), config["num_classes"])  # 随机选择指定数量的类别
for cls in selected_classes:
    sampled_files.extend(random.sample(video_labels[cls], config["num_samples_per_class"]))  # 从每个类别中随机选择指定数量的样本
    true_labels.extend([cls] * config["num_samples_per_class"])

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=config["use_exact"])

# 打印并保存结果
save_results(video_data)

# 打印结果以便查看
for video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_label}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_label].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/30 [00:00<?, ?video/s]
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/transformers/feature_extraction_utils.py:141: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   return torch.tensor(value)
# Video: zSCSoHcKJg0.mp4, Overall Predicted Label = 362, Overall Prediction Score = 0.4941, True Label = 362, True Label Score = 0.4941
#   Segment 1: Predicted Label = 135, Prediction Score = 0.6605, Segment Video Label Score = 0.0289, Segment True Label Score = 0.0289, SV True Label = -0.1280, SV Predicted Label = -0.1280
#   Segment 2: Predicted Label = 135, Prediction Score = 0.6573, Segment Video Label Score = 0.0480, Segment True Label Score = 0.0480, SV True Label = -0.1226, SV Predicted Label = -0.1226
#   Segment 3: Predicted Label = 135, Prediction Score = 0.6638, Segment Video Label Score = 0.0768, Segment True Label Score = 0.0768, SV True Label = -0.1145, SV Predicted Label = -0.1145
#   Segment 4: Predicted Label = 135, Prediction Score = 0.7144, Segment Video Label Score = 0.1425, Segment True Label Score = 0.1425, SV True Label = -0.0958, SV Predicted Label = -0.0958
#   Segment 5: Predicted Label = 362, Prediction Score = 0.8103, Segment Video Label Score = 0.8103, Segment True Label Score = 0.8103, SV True Label = 0.0935, SV Predicted Label = 0.0935
#   Segment 6: Predicted Label = 362, Prediction Score = 0.8753, Segment Video Label Score = 0.8753, Segment True Label Score = 0.8753, SV True Label = 0.1119, SV Predicted Label = 0.1119
#   Segment 7: Predicted Label = 362, Prediction Score = 0.9796, Segment Video Label Score = 0.9796, Segment True Label Score = 0.9796, SV True Label = 0.1415, SV Predicted Label = 0.1415
#   Segment 8: Predicted Label = 362, Prediction Score = 0.9915, Segment Video Label Score = 0.9915, Segment True Label Score = 0.9915, SV True Label = 0.1449, SV Predicted Label = 0.1449
# Video: 0RnlrsxG1hY.mp4, Overall Predicted Label = 362, Overall Prediction Score = 0.9109, True Label = 362, True Label Score = 0.9109
#   Segment 1: Predicted Label = 362, Prediction Score = 0.9870, Segment Video Label Score = 0.9870, Segment True Label Score = 0.9870, SV True Label = 0.0287, SV Predicted Label = 0.0287
#   Segment 2: Predicted Label = 362, Prediction Score = 0.9501, Segment Video Label Score = 0.9501, Segment True Label Score = 0.9501, SV True Label = 0.0182, SV Predicted Label = 0.0182
#   Segment 3: Predicted Label = 362, Prediction Score = 0.9567, Segment Video Label Score = 0.9567, Segment True Label Score = 0.9567, SV True Label = 0.0201, SV Predicted Label = 0.0201
#   Segment 4: Predicted Label = 362, Prediction Score = 0.9654, Segment Video Label Score = 0.9654, Segment True Label Score = 0.9654, SV True Label = 0.0226, SV Predicted Label = 0.0226
#   Segment 5: Predicted Label = 362, Prediction Score = 0.6497, Segment Video Label Score = 0.6497, Segment True Label Score = 0.6497, SV True Label = -0.0669, SV Predicted Label = -0.0669
#   Segment 6: Predicted Label = 362, Prediction Score = 0.9976, Segment Video Label Score = 0.9976, Segment True Label Score = 0.9976, SV True Label = 0.0317, SV Predicted Label = 0.0317
#   Segment 7: Predicted Label = 362, Prediction Score = 0.7969, Segment Video Label Score = 0.7969, Segment True Label Score = 0.7969, SV True Label = -0.0252, SV Predicted Label = -0.0252
#   Segment 8: Predicted Label = 362, Prediction Score = 0.9836, Segment Video Label Score = 0.9836, Segment True Label Score = 0.9836, SV True Label = 0.0277, SV Predicted Label = 0.0277
# Video: 2gXNJYH5nk0.mp4, Overall Predicted Label = 362, Overall Prediction Score = 0.2922, True Label = 362, True Label Score = 0.2922
#   Segment 1: Predicted Label = 362, Prediction Score = 0.4190, Segment Video Label Score = 0.4190, Segment True Label Score = 0.4190, SV True Label = 0.0383, SV Predicted Label = 0.0383
#   Segment 2: Predicted Label = 191, Prediction Score = 0.4967, Segment Video Label Score = 0.0007, Segment True Label Score = 0.0007, SV True Label = -0.0804, SV Predicted Label = -0.0804
#   Segment 3: Predicted Label = 191, Prediction Score = 0.5574, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.0805, SV Predicted Label = -0.0805
#   Segment 4: Predicted Label = 191, Prediction Score = 0.3265, Segment Video Label Score = 0.0950, Segment True Label Score = 0.0950, SV True Label = -0.0536, SV Predicted Label = -0.0536
#   Segment 5: Predicted Label = 144, Prediction Score = 0.3476, Segment Video Label Score = 0.2498, Segment True Label Score = 0.2498, SV True Label = -0.0097, SV Predicted Label = -0.0097
#   Segment 6: Predicted Label = 362, Prediction Score = 0.3568, Segment Video Label Score = 0.3568, Segment True Label Score = 0.3568, SV True Label = 0.0206, SV Predicted Label = 0.0206
#   Segment 7: Predicted Label = 362, Prediction Score = 0.4879, Segment Video Label Score = 0.4879, Segment True Label Score = 0.4879, SV True Label = 0.0578, SV Predicted Label = 0.0578
#   Segment 8: Predicted Label = 362, Prediction Score = 0.7280, Segment Video Label Score = 0.7280, Segment True Label Score = 0.7280, SV True Label = 0.1258, SV Predicted Label = 0.1258
# Video: MKv1mkOcom8.mp4, Overall Predicted Label = 31, Overall Prediction Score = 0.9992, True Label = 31, True Label Score = 0.9992
#   Segment 1: Predicted Label = 31, Prediction Score = 0.9984, Segment Video Label Score = 0.9984, Segment True Label Score = 0.9984, SV True Label = 0.0076, SV Predicted Label = 0.0076
#   Segment 2: Predicted Label = 31, Prediction Score = 0.9993, Segment Video Label Score = 0.9993, Segment True Label Score = 0.9993, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 3: Predicted Label = 31, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0080, SV Predicted Label = 0.0080
#   Segment 4: Predicted Label = 31, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 5: Predicted Label = 31, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 6: Predicted Label = 31, Prediction Score = 0.9985, Segment Video Label Score = 0.9985, Segment True Label Score = 0.9985, SV True Label = 0.0076, SV Predicted Label = 0.0076
#   Segment 7: Predicted Label = 31, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0079, SV Predicted Label = 0.0079
#   Segment 8: Predicted Label = 31, Prediction Score = 0.9996, Segment Video Label Score = 0.9996, Segment True Label Score = 0.9996, SV True Label = 0.0079, SV Predicted Label = 0.0079
# Video: jBNaXp62dDg.mp4, Overall Predicted Label = 31, Overall Prediction Score = 0.9994, True Label = 31, True Label Score = 0.9994
#   Segment 1: Predicted Label = 31, Prediction Score = 0.9992, Segment Video Label Score = 0.9992, Segment True Label Score = 0.9992, SV True Label = 0.0077, SV Predicted Label = 0.0077
#   Segment 2: Predicted Label = 31, Prediction Score = 0.9996, Segment Video Label Score = 0.9996, Segment True Label Score = 0.9996, SV True Label = 0.0079, SV Predicted Label = 0.0079
#   Segment 3: Predicted Label = 31, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 4: Predicted Label = 31, Prediction Score = 0.9995, Segment Video Label Score = 0.9995, Segment True Label Score = 0.9995, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 5: Predicted Label = 31, Prediction Score = 0.9995, Segment Video Label Score = 0.9995, Segment True Label Score = 0.9995, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 6: Predicted Label = 31, Prediction Score = 0.9996, Segment Video Label Score = 0.9996, Segment True Label Score = 0.9996, SV True Label = 0.0079, SV Predicted Label = 0.0079
#   Segment 7: Predicted Label = 31, Prediction Score = 0.9993, Segment Video Label Score = 0.9993, Segment True Label Score = 0.9993, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 8: Predicted Label = 31, Prediction Score = 0.9992, Segment Video Label Score = 0.9992, Segment True Label Score = 0.9992, SV True Label = 0.0078, SV Predicted Label = 0.0078
# Video: 4JxH3S5JwMs.mp4, Overall Predicted Label = 31, Overall Prediction Score = 0.9988, True Label = 31, True Label Score = 0.9988
#   Segment 1: Predicted Label = 31, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0080, SV Predicted Label = 0.0080
#   Segment 2: Predicted Label = 31, Prediction Score = 0.9988, Segment Video Label Score = 0.9988, Segment True Label Score = 0.9988, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 3: Predicted Label = 31, Prediction Score = 0.9988, Segment Video Label Score = 0.9988, Segment True Label Score = 0.9988, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 4: Predicted Label = 31, Prediction Score = 0.9986, Segment Video Label Score = 0.9986, Segment True Label Score = 0.9986, SV True Label = 0.0077, SV Predicted Label = 0.0077
#   Segment 5: Predicted Label = 31, Prediction Score = 0.9989, Segment Video Label Score = 0.9989, Segment True Label Score = 0.9989, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 6: Predicted Label = 31, Prediction Score = 0.9987, Segment Video Label Score = 0.9987, Segment True Label Score = 0.9987, SV True Label = 0.0077, SV Predicted Label = 0.0077
#   Segment 7: Predicted Label = 31, Prediction Score = 0.9987, Segment Video Label Score = 0.9987, Segment True Label Score = 0.9987, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 8: Predicted Label = 31, Prediction Score = 0.9989, Segment Video Label Score = 0.9989, Segment True Label Score = 0.9989, SV True Label = 0.0078, SV Predicted Label = 0.0078
# Video: fHHxqljpHGU.mp4, Overall Predicted Label = 347, Overall Prediction Score = 0.9413, True Label = 347, True Label Score = 0.9413
#   Segment 1: Predicted Label = 347, Prediction Score = 0.9075, Segment Video Label Score = 0.9075, Segment True Label Score = 0.9075, SV True Label = -0.0022, SV Predicted Label = -0.0022
#   Segment 2: Predicted Label = 347, Prediction Score = 0.9873, Segment Video Label Score = 0.9873, Segment True Label Score = 0.9873, SV True Label = 0.0204, SV Predicted Label = 0.0204
#   Segment 3: Predicted Label = 347, Prediction Score = 0.9959, Segment Video Label Score = 0.9959, Segment True Label Score = 0.9959, SV True Label = 0.0229, SV Predicted Label = 0.0229
#   Segment 4: Predicted Label = 347, Prediction Score = 0.9875, Segment Video Label Score = 0.9875, Segment True Label Score = 0.9875, SV True Label = 0.0205, SV Predicted Label = 0.0205
#   Segment 5: Predicted Label = 347, Prediction Score = 0.8526, Segment Video Label Score = 0.8526, Segment True Label Score = 0.8526, SV True Label = -0.0178, SV Predicted Label = -0.0178
#   Segment 6: Predicted Label = 347, Prediction Score = 0.8959, Segment Video Label Score = 0.8959, Segment True Label Score = 0.8959, SV True Label = -0.0055, SV Predicted Label = -0.0055
#   Segment 7: Predicted Label = 347, Prediction Score = 0.9971, Segment Video Label Score = 0.9971, Segment True Label Score = 0.9971, SV True Label = 0.0232, SV Predicted Label = 0.0232
#   Segment 8: Predicted Label = 347, Prediction Score = 0.9064, Segment Video Label Score = 0.9064, Segment True Label Score = 0.9064, SV True Label = -0.0025, SV Predicted Label = -0.0025
# Video: qmEetAxzAF0.mp4, Overall Predicted Label = 347, Overall Prediction Score = 0.3661, True Label = 347, True Label Score = 0.3661
#   Segment 1: Predicted Label = 106, Prediction Score = 0.3345, Segment Video Label Score = 0.0082, Segment True Label Score = 0.0082, SV True Label = -0.0986, SV Predicted Label = -0.0986
#   Segment 2: Predicted Label = 347, Prediction Score = 0.9752, Segment Video Label Score = 0.9752, Segment True Label Score = 0.9752, SV True Label = 0.1755, SV Predicted Label = 0.1755
#   Segment 3: Predicted Label = 347, Prediction Score = 0.6662, Segment Video Label Score = 0.6662, Segment True Label Score = 0.6662, SV True Label = 0.0879, SV Predicted Label = 0.0879
#   Segment 4: Predicted Label = 347, Prediction Score = 0.9654, Segment Video Label Score = 0.9654, Segment True Label Score = 0.9654, SV True Label = 0.1728, SV Predicted Label = 0.1728
#   Segment 5: Predicted Label = 347, Prediction Score = 0.3139, Segment Video Label Score = 0.3139, Segment True Label Score = 0.3139, SV True Label = -0.0119, SV Predicted Label = -0.0119
#   Segment 6: Predicted Label = 1, Prediction Score = 0.6127, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.1009, SV Predicted Label = -0.1009
#   Segment 7: Predicted Label = 16, Prediction Score = 0.4494, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.1009, SV Predicted Label = -0.1009
#   Segment 8: Predicted Label = 1, Prediction Score = 0.8011, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.1009, SV Predicted Label = -0.1009
# Video: DOVh-taDZ5k.mp4, Overall Predicted Label = 347, Overall Prediction Score = 0.1684, True Label = 347, True Label Score = 0.1684
#   Segment 1: Predicted Label = 399, Prediction Score = 0.4550, Segment Video Label Score = 0.0002, Segment True Label Score = 0.0002, SV True Label = -0.0464, SV Predicted Label = -0.0464
#   Segment 2: Predicted Label = 399, Prediction Score = 0.7007, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.0464, SV Predicted Label = -0.0464
#   Segment 3: Predicted Label = 257, Prediction Score = 0.1036, Segment Video Label Score = 0.0005, Segment True Label Score = 0.0005, SV True Label = -0.0463, SV Predicted Label = -0.0463
#   Segment 4: Predicted Label = 294, Prediction Score = 0.2123, Segment Video Label Score = 0.0004, Segment True Label Score = 0.0004, SV True Label = -0.0463, SV Predicted Label = -0.0463
#   Segment 5: Predicted Label = 347, Prediction Score = 0.8472, Segment Video Label Score = 0.8472, Segment True Label Score = 0.8472, SV True Label = 0.1937, SV Predicted Label = 0.1937
#   Segment 6: Predicted Label = 123, Prediction Score = 0.9858, Segment Video Label Score = 0.0001, Segment True Label Score = 0.0001, SV True Label = -0.0464, SV Predicted Label = -0.0464
#   Segment 7: Predicted Label = 124, Prediction Score = 0.1097, Segment Video Label Score = 0.0004, Segment True Label Score = 0.0004, SV True Label = -0.0463, SV Predicted Label = -0.0463
#   Segment 8: Predicted Label = 347, Prediction Score = 0.4986, Segment Video Label Score = 0.4986, Segment True Label Score = 0.4986, SV True Label = 0.0949, SV Predicted Label = 0.0949
# Video: p6i5r1eRxMk.mp4, Overall Predicted Label = 301, Overall Prediction Score = 0.4490, True Label = 301, True Label Score = 0.4490
#   Segment 1: Predicted Label = 242, Prediction Score = 0.9679, Segment Video Label Score = 0.0140, Segment True Label Score = 0.0140, SV True Label = -0.1198, SV Predicted Label = -0.1198
#   Segment 2: Predicted Label = 242, Prediction Score = 0.9543, Segment Video Label Score = 0.0073, Segment True Label Score = 0.0073, SV True Label = -0.1217, SV Predicted Label = -0.1217
#   Segment 3: Predicted Label = 242, Prediction Score = 0.9226, Segment Video Label Score = 0.0540, Segment True Label Score = 0.0540, SV True Label = -0.1085, SV Predicted Label = -0.1085
#   Segment 4: Predicted Label = 301, Prediction Score = 0.9627, Segment Video Label Score = 0.9627, Segment True Label Score = 0.9627, SV True Label = 0.1491, SV Predicted Label = 0.1491
#   Segment 5: Predicted Label = 301, Prediction Score = 0.8502, Segment Video Label Score = 0.8502, Segment True Label Score = 0.8502, SV True Label = 0.1172, SV Predicted Label = 0.1172
#   Segment 6: Predicted Label = 293, Prediction Score = 0.2717, Segment Video Label Score = 0.0090, Segment True Label Score = 0.0090, SV True Label = -0.1212, SV Predicted Label = -0.1212
#   Segment 7: Predicted Label = 301, Prediction Score = 0.9897, Segment Video Label Score = 0.9897, Segment True Label Score = 0.9897, SV True Label = 0.1568, SV Predicted Label = 0.1568
#   Segment 8: Predicted Label = 301, Prediction Score = 0.7052, Segment Video Label Score = 0.7052, Segment True Label Score = 0.7052, SV True Label = 0.0761, SV Predicted Label = 0.0761
# Video: Ty63fNlVsrU.mp4, Overall Predicted Label = 301, Overall Prediction Score = 0.7218, True Label = 301, True Label Score = 0.7218
#   Segment 1: Predicted Label = 301, Prediction Score = 0.8402, Segment Video Label Score = 0.8402, Segment True Label Score = 0.8402, SV True Label = 0.0392, SV Predicted Label = 0.0392
#   Segment 2: Predicted Label = 301, Prediction Score = 0.8402, Segment Video Label Score = 0.8402, Segment True Label Score = 0.8402, SV True Label = 0.0392, SV Predicted Label = 0.0392
#   Segment 3: Predicted Label = 301, Prediction Score = 0.4561, Segment Video Label Score = 0.4561, Segment True Label Score = 0.4561, SV True Label = -0.0697, SV Predicted Label = -0.0697
#   Segment 4: Predicted Label = 301, Prediction Score = 0.9961, Segment Video Label Score = 0.9961, Segment True Label Score = 0.9961, SV True Label = 0.0834, SV Predicted Label = 0.0834
#   Segment 5: Predicted Label = 301, Prediction Score = 0.8440, Segment Video Label Score = 0.8440, Segment True Label Score = 0.8440, SV True Label = 0.0403, SV Predicted Label = 0.0403
#   Segment 6: Predicted Label = 301, Prediction Score = 0.9830, Segment Video Label Score = 0.9830, Segment True Label Score = 0.9830, SV True Label = 0.0797, SV Predicted Label = 0.0797
#   Segment 7: Predicted Label = 97, Prediction Score = 0.6091, Segment Video Label Score = 0.0030, Segment True Label Score = 0.0030, SV True Label = -0.1981, SV Predicted Label = -0.1981
#   Segment 8: Predicted Label = 301, Prediction Score = 0.8117, Segment Video Label Score = 0.8117, Segment True Label Score = 0.8117, SV True Label = 0.0311, SV Predicted Label = 0.0311
# Video: IyiHUUPVf58.mp4, Overall Predicted Label = 222, Overall Prediction Score = 0.2676, True Label = 301, True Label Score = 0.2270
#   Segment 1: Predicted Label = 266, Prediction Score = 0.3838, Segment Video Label Score = 0.0012, Segment True Label Score = 0.0006, SV True Label = -0.0624, SV Predicted Label = -0.0734
#   Segment 2: Predicted Label = 266, Prediction Score = 0.3993, Segment Video Label Score = 0.0004, Segment True Label Score = 0.0002, SV True Label = -0.0625, SV Predicted Label = -0.0737
#   Segment 3: Predicted Label = 74, Prediction Score = 0.1230, Segment Video Label Score = 0.0045, Segment True Label Score = 0.0104, SV True Label = -0.0596, SV Predicted Label = -0.0725
#   Segment 4: Predicted Label = 301, Prediction Score = 0.7936, Segment Video Label Score = 0.1678, Segment True Label Score = 0.7936, SV True Label = 0.1624, SV Predicted Label = -0.0262
#   Segment 5: Predicted Label = 222, Prediction Score = 0.9973, Segment Video Label Score = 0.9973, Segment True Label Score = 0.0022, SV True Label = -0.0619, SV Predicted Label = 0.2089
#   Segment 6: Predicted Label = 222, Prediction Score = 0.9541, Segment Video Label Score = 0.9541, Segment True Label Score = 0.0404, SV True Label = -0.0511, SV Predicted Label = 0.1967
#   Segment 7: Predicted Label = 301, Prediction Score = 0.9293, Segment Video Label Score = 0.0093, Segment True Label Score = 0.9293, SV True Label = 0.2009, SV Predicted Label = -0.0711
#   Segment 8: Predicted Label = 127, Prediction Score = 0.1951, Segment Video Label Score = 0.0063, Segment True Label Score = 0.0390, SV True Label = -0.0515, SV Predicted Label = -0.0720
# Video: tWlJVMz96z4.mp4, Overall Predicted Label = 254, Overall Prediction Score = 0.6619, True Label = 254, True Label Score = 0.6619
#   Segment 1: Predicted Label = 299, Prediction Score = 0.7431, Segment Video Label Score = 0.0147, Segment True Label Score = 0.0147, SV True Label = -0.1783, SV Predicted Label = -0.1783
#   Segment 2: Predicted Label = 254, Prediction Score = 0.3142, Segment Video Label Score = 0.3142, Segment True Label Score = 0.3142, SV True Label = -0.0934, SV Predicted Label = -0.0934
#   Segment 3: Predicted Label = 299, Prediction Score = 0.5310, Segment Video Label Score = 0.0168, Segment True Label Score = 0.0168, SV True Label = -0.1777, SV Predicted Label = -0.1777
#   Segment 4: Predicted Label = 254, Prediction Score = 0.9762, Segment Video Label Score = 0.9762, Segment True Label Score = 0.9762, SV True Label = 0.0943, SV Predicted Label = 0.0943
#   Segment 5: Predicted Label = 254, Prediction Score = 0.9954, Segment Video Label Score = 0.9954, Segment True Label Score = 0.9954, SV True Label = 0.0997, SV Predicted Label = 0.0997
#   Segment 6: Predicted Label = 254, Prediction Score = 0.9859, Segment Video Label Score = 0.9859, Segment True Label Score = 0.9859, SV True Label = 0.0970, SV Predicted Label = 0.0970
#   Segment 7: Predicted Label = 254, Prediction Score = 0.9974, Segment Video Label Score = 0.9974, Segment True Label Score = 0.9974, SV True Label = 0.1003, SV Predicted Label = 0.1003
#   Segment 8: Predicted Label = 254, Prediction Score = 0.9947, Segment Video Label Score = 0.9947, Segment True Label Score = 0.9947, SV True Label = 0.0995, SV Predicted Label = 0.0995
# Video: JChuYeI0LVg.mp4, Overall Predicted Label = 254, Overall Prediction Score = 0.5011, True Label = 254, True Label Score = 0.5011
#   Segment 1: Predicted Label = 202, Prediction Score = 0.9937, Segment Video Label Score = 0.0037, Segment True Label Score = 0.0037, SV True Label = -0.1371, SV Predicted Label = -0.1371
#   Segment 2: Predicted Label = 202, Prediction Score = 0.8278, Segment Video Label Score = 0.1685, Segment True Label Score = 0.1685, SV True Label = -0.0904, SV Predicted Label = -0.0904
#   Segment 3: Predicted Label = 280, Prediction Score = 0.5127, Segment Video Label Score = 0.0022, Segment True Label Score = 0.0022, SV True Label = -0.1375, SV Predicted Label = -0.1375
#   Segment 4: Predicted Label = 254, Prediction Score = 0.9962, Segment Video Label Score = 0.9962, Segment True Label Score = 0.9962, SV True Label = 0.1443, SV Predicted Label = 0.1443
#   Segment 5: Predicted Label = 254, Prediction Score = 0.7230, Segment Video Label Score = 0.7230, Segment True Label Score = 0.7230, SV True Label = 0.0668, SV Predicted Label = 0.0668
#   Segment 6: Predicted Label = 254, Prediction Score = 0.7727, Segment Video Label Score = 0.7727, Segment True Label Score = 0.7727, SV True Label = 0.0809, SV Predicted Label = 0.0809
#   Segment 7: Predicted Label = 254, Prediction Score = 0.4885, Segment Video Label Score = 0.4885, Segment True Label Score = 0.4885, SV True Label = 0.0003, SV Predicted Label = 0.0003
#   Segment 8: Predicted Label = 254, Prediction Score = 0.8540, Segment Video Label Score = 0.8540, Segment True Label Score = 0.8540, SV True Label = 0.1040, SV Predicted Label = 0.1040
# Video: UUg157jFT5k.mp4, Overall Predicted Label = 254, Overall Prediction Score = 0.9667, True Label = 254, True Label Score = 0.9667
#   Segment 1: Predicted Label = 254, Prediction Score = 0.9995, Segment Video Label Score = 0.9995, Segment True Label Score = 0.9995, SV True Label = 0.0169, SV Predicted Label = 0.0169
#   Segment 2: Predicted Label = 254, Prediction Score = 0.7373, Segment Video Label Score = 0.7373, Segment True Label Score = 0.7373, SV True Label = -0.0575, SV Predicted Label = -0.0575
#   Segment 3: Predicted Label = 254, Prediction Score = 0.9967, Segment Video Label Score = 0.9967, Segment True Label Score = 0.9967, SV True Label = 0.0161, SV Predicted Label = 0.0161
#   Segment 4: Predicted Label = 254, Prediction Score = 1.0000, Segment Video Label Score = 1.0000, Segment True Label Score = 1.0000, SV True Label = 0.0170, SV Predicted Label = 0.0170
#   Segment 5: Predicted Label = 254, Prediction Score = 1.0000, Segment Video Label Score = 1.0000, Segment True Label Score = 1.0000, SV True Label = 0.0170, SV Predicted Label = 0.0170
#   Segment 6: Predicted Label = 254, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0170, SV Predicted Label = 0.0170
#   Segment 7: Predicted Label = 254, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0170, SV Predicted Label = 0.0170
#   Segment 8: Predicted Label = 254, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0170, SV Predicted Label = 0.0170
# Video: 5tudeVVPcXk.mp4, Overall Predicted Label = 224, Overall Prediction Score = 0.8742, True Label = 224, True Label Score = 0.8742
#   Segment 1: Predicted Label = 224, Prediction Score = 1.0000, Segment Video Label Score = 1.0000, Segment True Label Score = 1.0000, SV True Label = 0.0425, SV Predicted Label = 0.0425
#   Segment 2: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0425, SV Predicted Label = 0.0425
#   Segment 3: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0425, SV Predicted Label = 0.0425
#   Segment 4: Predicted Label = 224, Prediction Score = 1.0000, Segment Video Label Score = 1.0000, Segment True Label Score = 1.0000, SV True Label = 0.0425, SV Predicted Label = 0.0425
#   Segment 5: Predicted Label = 224, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0423, SV Predicted Label = 0.0423
#   Segment 6: Predicted Label = 224, Prediction Score = 0.9938, Segment Video Label Score = 0.9938, Segment True Label Score = 0.9938, SV True Label = 0.0407, SV Predicted Label = 0.0407
#   Segment 7: Predicted Label = 304, Prediction Score = 0.6638, Segment Video Label Score = 0.0004, Segment True Label Score = 0.0004, SV True Label = -0.2409, SV Predicted Label = -0.2409
#   Segment 8: Predicted Label = 224, Prediction Score = 1.0000, Segment Video Label Score = 1.0000, Segment True Label Score = 1.0000, SV True Label = 0.0425, SV Predicted Label = 0.0425
# Video: BHZLeikiPao.mp4, Overall Predicted Label = 224, Overall Prediction Score = 0.9999, True Label = 224, True Label Score = 0.9999
#   Segment 1: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 2: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 3: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 4: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 5: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 6: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 7: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
#   Segment 8: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.9999, Segment True Label Score = 0.9999, SV True Label = 0.0078, SV Predicted Label = 0.0078
# Video: n4icILNnvYU.mp4, Overall Predicted Label = 392, Overall Prediction Score = 0.1815, True Label = 224, True Label Score = 0.1442
#   Segment 1: Predicted Label = 234, Prediction Score = 0.3779, Segment Video Label Score = 0.0005, Segment True Label Score = 0.0009, SV True Label = -0.0395, SV Predicted Label = -0.0499
#   Segment 2: Predicted Label = 397, Prediction Score = 0.3027, Segment Video Label Score = 0.2345, Segment True Label Score = 0.0008, SV True Label = -0.0395, SV Predicted Label = 0.0165
#   Segment 3: Predicted Label = 106, Prediction Score = 0.3034, Segment Video Label Score = 0.0007, Segment True Label Score = 0.0008, SV True Label = -0.0395, SV Predicted Label = -0.0498
#   Segment 4: Predicted Label = 106, Prediction Score = 0.4683, Segment Video Label Score = 0.0017, Segment True Label Score = 0.0582, SV True Label = -0.0233, SV Predicted Label = -0.0495
#   Segment 5: Predicted Label = 224, Prediction Score = 0.9999, Segment Video Label Score = 0.0000, Segment True Label Score = 0.9999, SV True Label = 0.2437, SV Predicted Label = -0.0500
#   Segment 6: Predicted Label = 392, Prediction Score = 0.9397, Segment Video Label Score = 0.9397, Segment True Label Score = 0.0000, SV True Label = -0.0398, SV Predicted Label = 0.2164
#   Segment 7: Predicted Label = 392, Prediction Score = 0.1946, Segment Video Label Score = 0.1946, Segment True Label Score = 0.0752, SV True Label = -0.0184, SV Predicted Label = 0.0051
#   Segment 8: Predicted Label = 233, Prediction Score = 0.5554, Segment Video Label Score = 0.0801, Segment True Label Score = 0.0180, SV True Label = -0.0347, SV Predicted Label = -0.0273
# Video: ObO_Gnw1nOQ.mp4, Overall Predicted Label = 134, Overall Prediction Score = 0.5099, True Label = 134, True Label Score = 0.5099
#   Segment 1: Predicted Label = 134, Prediction Score = 0.7453, Segment Video Label Score = 0.7453, Segment True Label Score = 0.7453, SV True Label = 0.0707, SV Predicted Label = 0.0707
#   Segment 2: Predicted Label = 134, Prediction Score = 0.4282, Segment Video Label Score = 0.4282, Segment True Label Score = 0.4282, SV True Label = -0.0192, SV Predicted Label = -0.0192
#   Segment 3: Predicted Label = 134, Prediction Score = 0.4734, Segment Video Label Score = 0.4734, Segment True Label Score = 0.4734, SV True Label = -0.0063, SV Predicted Label = -0.0063
#   Segment 4: Predicted Label = 134, Prediction Score = 0.3304, Segment Video Label Score = 0.3304, Segment True Label Score = 0.3304, SV True Label = -0.0469, SV Predicted Label = -0.0469
#   Segment 5: Predicted Label = 134, Prediction Score = 0.6246, Segment Video Label Score = 0.6246, Segment True Label Score = 0.6246, SV True Label = 0.0365, SV Predicted Label = 0.0365
#   Segment 6: Predicted Label = 134, Prediction Score = 0.4873, Segment Video Label Score = 0.4873, Segment True Label Score = 0.4873, SV True Label = -0.0024, SV Predicted Label = -0.0024
#   Segment 7: Predicted Label = 255, Prediction Score = 0.9267, Segment Video Label Score = 0.0032, Segment True Label Score = 0.0032, SV True Label = -0.1396, SV Predicted Label = -0.1396
#   Segment 8: Predicted Label = 134, Prediction Score = 0.9864, Segment Video Label Score = 0.9864, Segment True Label Score = 0.9864, SV True Label = 0.1391, SV Predicted Label = 0.1391
# Video: feTWuKPZA_k.mp4, Overall Predicted Label = 134, Overall Prediction Score = 0.9806, True Label = 134, True Label Score = 0.9806
#   Segment 1: Predicted Label = 134, Prediction Score = 0.9780, Segment Video Label Score = 0.9780, Segment True Label Score = 0.9780, SV True Label = 0.0069, SV Predicted Label = 0.0069
#   Segment 2: Predicted Label = 134, Prediction Score = 0.9847, Segment Video Label Score = 0.9847, Segment True Label Score = 0.9847, SV True Label = 0.0088, SV Predicted Label = 0.0088
#   Segment 3: Predicted Label = 134, Prediction Score = 0.9947, Segment Video Label Score = 0.9947, Segment True Label Score = 0.9947, SV True Label = 0.0117, SV Predicted Label = 0.0117
#   Segment 4: Predicted Label = 134, Prediction Score = 0.9965, Segment Video Label Score = 0.9965, Segment True Label Score = 0.9965, SV True Label = 0.0122, SV Predicted Label = 0.0122
#   Segment 5: Predicted Label = 134, Prediction Score = 0.9995, Segment Video Label Score = 0.9995, Segment True Label Score = 0.9995, SV True Label = 0.0130, SV Predicted Label = 0.0130
#   Segment 6: Predicted Label = 134, Prediction Score = 0.9972, Segment Video Label Score = 0.9972, Segment True Label Score = 0.9972, SV True Label = 0.0124, SV Predicted Label = 0.0124
#   Segment 7: Predicted Label = 134, Prediction Score = 0.8990, Segment Video Label Score = 0.8990, Segment True Label Score = 0.8990, SV True Label = -0.0155, SV Predicted Label = -0.0155
#   Segment 8: Predicted Label = 134, Prediction Score = 0.9953, Segment Video Label Score = 0.9953, Segment True Label Score = 0.9953, SV True Label = 0.0118, SV Predicted Label = 0.0118
# Video: gUE0mw5AGPQ.mp4, Overall Predicted Label = 134, Overall Prediction Score = 0.2777, True Label = 134, True Label Score = 0.2777
#   Segment 1: Predicted Label = 2, Prediction Score = 0.1972, Segment Video Label Score = 0.0599, Segment True Label Score = 0.0599, SV True Label = -0.0596, SV Predicted Label = -0.0596
#   Segment 2: Predicted Label = 2, Prediction Score = 0.3792, Segment Video Label Score = 0.0600, Segment True Label Score = 0.0600, SV True Label = -0.0595, SV Predicted Label = -0.0595
#   Segment 3: Predicted Label = 304, Prediction Score = 0.2986, Segment Video Label Score = 0.0065, Segment True Label Score = 0.0065, SV True Label = -0.0747, SV Predicted Label = -0.0747
#   Segment 4: Predicted Label = 134, Prediction Score = 0.7934, Segment Video Label Score = 0.7934, Segment True Label Score = 0.7934, SV True Label = 0.1484, SV Predicted Label = 0.1484
#   Segment 5: Predicted Label = 134, Prediction Score = 0.4346, Segment Video Label Score = 0.4346, Segment True Label Score = 0.4346, SV True Label = 0.0467, SV Predicted Label = 0.0467
#   Segment 6: Predicted Label = 330, Prediction Score = 0.3543, Segment Video Label Score = 0.2588, Segment True Label Score = 0.2588, SV True Label = -0.0032, SV Predicted Label = -0.0032
#   Segment 7: Predicted Label = 134, Prediction Score = 0.5555, Segment Video Label Score = 0.5555, Segment True Label Score = 0.5555, SV True Label = 0.0809, SV Predicted Label = 0.0809
#   Segment 8: Predicted Label = 119, Prediction Score = 0.5905, Segment Video Label Score = 0.0524, Segment True Label Score = 0.0524, SV True Label = -0.0617, SV Predicted Label = -0.0617
# Video: WLIVKnWo2NU.mp4, Overall Predicted Label = 109, Overall Prediction Score = 0.2388, True Label = 114, True Label Score = 0.2240
#   Segment 1: Predicted Label = 114, Prediction Score = 0.9297, Segment Video Label Score = 0.0138, Segment True Label Score = 0.9297, SV True Label = 0.2018, SV Predicted Label = -0.0619
#   Segment 2: Predicted Label = 109, Prediction Score = 0.6126, Segment Video Label Score = 0.6126, Segment True Label Score = 0.0782, SV True Label = -0.0396, SV Predicted Label = 0.1078
#   Segment 3: Predicted Label = 74, Prediction Score = 0.2216, Segment Video Label Score = 0.0986, Segment True Label Score = 0.0327, SV True Label = -0.0525, SV Predicted Label = -0.0379
#   Segment 4: Predicted Label = 115, Prediction Score = 0.3561, Segment Video Label Score = 0.2842, Segment True Label Score = 0.0713, SV True Label = -0.0416, SV Predicted Label = 0.0147
#   Segment 5: Predicted Label = 114, Prediction Score = 0.6401, Segment Video Label Score = 0.3366, Segment True Label Score = 0.6401, SV True Label = 0.1197, SV Predicted Label = 0.0296
#   Segment 6: Predicted Label = 109, Prediction Score = 0.3378, Segment Video Label Score = 0.3378, Segment True Label Score = 0.0047, SV True Label = -0.0604, SV Predicted Label = 0.0299
#   Segment 7: Predicted Label = 16, Prediction Score = 0.5869, Segment Video Label Score = 0.0728, Segment True Label Score = 0.0105, SV True Label = -0.0588, SV Predicted Label = -0.0452
#   Segment 8: Predicted Label = 16, Prediction Score = 0.2948, Segment Video Label Score = 0.1541, Segment True Label Score = 0.0251, SV True Label = -0.0546, SV Predicted Label = -0.0221
# Video: 2ZzgcL5BM5c.mp4, Overall Predicted Label = 114, Overall Prediction Score = 0.4206, True Label = 114, True Label Score = 0.4206
#   Segment 1: Predicted Label = 219, Prediction Score = 0.1577, Segment Video Label Score = 0.0003, Segment True Label Score = 0.0003, SV True Label = -0.1159, SV Predicted Label = -0.1159
#   Segment 2: Predicted Label = 366, Prediction Score = 0.1939, Segment Video Label Score = 0.0001, Segment True Label Score = 0.0001, SV True Label = -0.1159, SV Predicted Label = -0.1159
#   Segment 3: Predicted Label = 366, Prediction Score = 0.1080, Segment Video Label Score = 0.0009, Segment True Label Score = 0.0009, SV True Label = -0.1157, SV Predicted Label = -0.1157
#   Segment 4: Predicted Label = 176, Prediction Score = 0.7473, Segment Video Label Score = 0.0010, Segment True Label Score = 0.0010, SV True Label = -0.1157, SV Predicted Label = -0.1157
#   Segment 5: Predicted Label = 114, Prediction Score = 0.9091, Segment Video Label Score = 0.9091, Segment True Label Score = 0.9091, SV True Label = 0.1418, SV Predicted Label = 0.1418
#   Segment 6: Predicted Label = 114, Prediction Score = 0.8888, Segment Video Label Score = 0.8888, Segment True Label Score = 0.8888, SV True Label = 0.1360, SV Predicted Label = 0.1360
#   Segment 7: Predicted Label = 114, Prediction Score = 0.7515, Segment Video Label Score = 0.7515, Segment True Label Score = 0.7515, SV True Label = 0.0971, SV Predicted Label = 0.0971
#   Segment 8: Predicted Label = 114, Prediction Score = 0.8131, Segment Video Label Score = 0.8131, Segment True Label Score = 0.8131, SV True Label = 0.1146, SV Predicted Label = 0.1146
# Video: M6GkGNHPtE8.mp4, Overall Predicted Label = 114, Overall Prediction Score = 0.8388, True Label = 114, True Label Score = 0.8388
#   Segment 1: Predicted Label = 114, Prediction Score = 0.9901, Segment Video Label Score = 0.9901, Segment True Label Score = 0.9901, SV True Label = 0.0494, SV Predicted Label = 0.0494
#   Segment 2: Predicted Label = 114, Prediction Score = 0.6957, Segment Video Label Score = 0.6957, Segment True Label Score = 0.6957, SV True Label = -0.0340, SV Predicted Label = -0.0340
#   Segment 3: Predicted Label = 114, Prediction Score = 0.9989, Segment Video Label Score = 0.9989, Segment True Label Score = 0.9989, SV True Label = 0.0519, SV Predicted Label = 0.0519
#   Segment 4: Predicted Label = 114, Prediction Score = 0.9995, Segment Video Label Score = 0.9995, Segment True Label Score = 0.9995, SV True Label = 0.0521, SV Predicted Label = 0.0521
#   Segment 5: Predicted Label = 41, Prediction Score = 0.4017, Segment Video Label Score = 0.0418, Segment True Label Score = 0.0418, SV True Label = -0.2194, SV Predicted Label = -0.2194
#   Segment 6: Predicted Label = 114, Prediction Score = 0.9992, Segment Video Label Score = 0.9992, Segment True Label Score = 0.9992, SV True Label = 0.0520, SV Predicted Label = 0.0520
#   Segment 7: Predicted Label = 114, Prediction Score = 0.9984, Segment Video Label Score = 0.9984, Segment True Label Score = 0.9984, SV True Label = 0.0518, SV Predicted Label = 0.0518
#   Segment 8: Predicted Label = 114, Prediction Score = 0.9866, Segment Video Label Score = 0.9866, Segment True Label Score = 0.9866, SV True Label = 0.0485, SV Predicted Label = 0.0485
# Video: vI9xWy69vQM.mp4, Overall Predicted Label = 127, Overall Prediction Score = 0.1224, True Label = 332, True Label Score = 0.0634
#   Segment 1: Predicted Label = 372, Prediction Score = 0.1078, Segment Video Label Score = 0.0060, Segment True Label Score = 0.0692, SV True Label = 0.0021, SV Predicted Label = -0.0320
#   Segment 2: Predicted Label = 145, Prediction Score = 0.4025, Segment Video Label Score = 0.0013, Segment True Label Score = 0.1645, SV True Label = 0.0291, SV Predicted Label = -0.0334
#   Segment 3: Predicted Label = 193, Prediction Score = 0.3133, Segment Video Label Score = 0.0005, Segment True Label Score = 0.0240, SV True Label = -0.0107, SV Predicted Label = -0.0336
#   Segment 4: Predicted Label = 332, Prediction Score = 0.1437, Segment Video Label Score = 0.0440, Segment True Label Score = 0.1437, SV True Label = 0.0232, SV Predicted Label = -0.0213
#   Segment 5: Predicted Label = 127, Prediction Score = 0.2752, Segment Video Label Score = 0.2752, Segment True Label Score = 0.0083, SV True Label = -0.0151, SV Predicted Label = 0.0443
#   Segment 6: Predicted Label = 127, Prediction Score = 0.1163, Segment Video Label Score = 0.1163, Segment True Label Score = 0.0055, SV True Label = -0.0159, SV Predicted Label = -0.0008
#   Segment 7: Predicted Label = 398, Prediction Score = 0.5939, Segment Video Label Score = 0.1398, Segment True Label Score = 0.0115, SV True Label = -0.0142, SV Predicted Label = 0.0059
#   Segment 8: Predicted Label = 127, Prediction Score = 0.3960, Segment Video Label Score = 0.3960, Segment True Label Score = 0.0806, SV True Label = 0.0054, SV Predicted Label = 0.0785
# Video: Thb061h_OEA.mp4, Overall Predicted Label = 332, Overall Prediction Score = 0.6881, True Label = 332, True Label Score = 0.6881
#   Segment 1: Predicted Label = 332, Prediction Score = 0.9549, Segment Video Label Score = 0.9549, Segment True Label Score = 0.9549, SV True Label = 0.0810, SV Predicted Label = 0.0810
#   Segment 2: Predicted Label = 332, Prediction Score = 0.7874, Segment Video Label Score = 0.7874, Segment True Label Score = 0.7874, SV True Label = 0.0335, SV Predicted Label = 0.0335
#   Segment 3: Predicted Label = 332, Prediction Score = 0.9896, Segment Video Label Score = 0.9896, Segment True Label Score = 0.9896, SV True Label = 0.0909, SV Predicted Label = 0.0909
#   Segment 4: Predicted Label = 332, Prediction Score = 0.9994, Segment Video Label Score = 0.9994, Segment True Label Score = 0.9994, SV True Label = 0.0936, SV Predicted Label = 0.0936
#   Segment 5: Predicted Label = 332, Prediction Score = 0.9992, Segment Video Label Score = 0.9992, Segment True Label Score = 0.9992, SV True Label = 0.0936, SV Predicted Label = 0.0936
#   Segment 6: Predicted Label = 332, Prediction Score = 0.3772, Segment Video Label Score = 0.3772, Segment True Label Score = 0.3772, SV True Label = -0.0827, SV Predicted Label = -0.0827
#   Segment 7: Predicted Label = 2, Prediction Score = 0.2489, Segment Video Label Score = 0.1137, Segment True Label Score = 0.1137, SV True Label = -0.1574, SV Predicted Label = -0.1574
#   Segment 8: Predicted Label = 332, Prediction Score = 0.2832, Segment Video Label Score = 0.2832, Segment True Label Score = 0.2832, SV True Label = -0.1094, SV Predicted Label = -0.1094
# Video: k1kLVyllTIE.mp4, Overall Predicted Label = 399, Overall Prediction Score = 0.1286, True Label = 332, True Label Score = 0.0167
#   Segment 1: Predicted Label = 399, Prediction Score = 0.3903, Segment Video Label Score = 0.3903, Segment True Label Score = 0.0102, SV True Label = -0.0017, SV Predicted Label = 0.0752
#   Segment 2: Predicted Label = 399, Prediction Score = 0.3888, Segment Video Label Score = 0.3888, Segment True Label Score = 0.0073, SV True Label = -0.0025, SV Predicted Label = 0.0748
#   Segment 3: Predicted Label = 256, Prediction Score = 0.5003, Segment Video Label Score = 0.0097, Segment True Label Score = 0.0474, SV True Label = 0.0088, SV Predicted Label = -0.0327
#   Segment 4: Predicted Label = 256, Prediction Score = 0.3160, Segment Video Label Score = 0.0098, Segment True Label Score = 0.0055, SV True Label = -0.0031, SV Predicted Label = -0.0327
#   Segment 5: Predicted Label = 398, Prediction Score = 0.1090, Segment Video Label Score = 0.0545, Segment True Label Score = 0.0148, SV True Label = -0.0004, SV Predicted Label = -0.0200
#   Segment 6: Predicted Label = 304, Prediction Score = 0.3490, Segment Video Label Score = 0.0020, Segment True Label Score = 0.0298, SV True Label = 0.0038, SV Predicted Label = -0.0349
#   Segment 7: Predicted Label = 87, Prediction Score = 0.2490, Segment Video Label Score = 0.1600, Segment True Label Score = 0.0043, SV True Label = -0.0034, SV Predicted Label = 0.0099
#   Segment 8: Predicted Label = 304, Prediction Score = 0.2174, Segment Video Label Score = 0.0141, Segment True Label Score = 0.0145, SV True Label = -0.0005, SV Predicted Label = -0.0315
# Video: ZqlAPN0DEl4.mp4, Overall Predicted Label = 65, Overall Prediction Score = 0.5116, True Label = 65, True Label Score = 0.5116
#   Segment 1: Predicted Label = 254, Prediction Score = 0.2737, Segment Video Label Score = 0.0038, Segment True Label Score = 0.0038, SV True Label = -0.1400, SV Predicted Label = -0.1400
#   Segment 2: Predicted Label = 65, Prediction Score = 0.9517, Segment Video Label Score = 0.9517, Segment True Label Score = 0.9517, SV True Label = 0.1288, SV Predicted Label = 0.1288
#   Segment 3: Predicted Label = 65, Prediction Score = 0.9591, Segment Video Label Score = 0.9591, Segment True Label Score = 0.9591, SV True Label = 0.1309, SV Predicted Label = 0.1309
#   Segment 4: Predicted Label = 65, Prediction Score = 0.9654, Segment Video Label Score = 0.9654, Segment True Label Score = 0.9654, SV True Label = 0.1327, SV Predicted Label = 0.1327
#   Segment 5: Predicted Label = 65, Prediction Score = 0.9677, Segment Video Label Score = 0.9677, Segment True Label Score = 0.9677, SV True Label = 0.1333, SV Predicted Label = 0.1333
#   Segment 6: Predicted Label = 257, Prediction Score = 0.4514, Segment Video Label Score = 0.1493, Segment True Label Score = 0.1493, SV True Label = -0.0987, SV Predicted Label = -0.0987
#   Segment 7: Predicted Label = 257, Prediction Score = 0.6567, Segment Video Label Score = 0.0462, Segment True Label Score = 0.0462, SV True Label = -0.1279, SV Predicted Label = -0.1279
#   Segment 8: Predicted Label = 257, Prediction Score = 0.5650, Segment Video Label Score = 0.0495, Segment True Label Score = 0.0495, SV True Label = -0.1270, SV Predicted Label = -0.1270
# Video: -fN6cQFbu1M.mp4, Overall Predicted Label = 65, Overall Prediction Score = 0.9546, True Label = 65, True Label Score = 0.9546
#   Segment 1: Predicted Label = 65, Prediction Score = 0.9744, Segment Video Label Score = 0.9744, Segment True Label Score = 0.9744, SV True Label = 0.0130, SV Predicted Label = 0.0130
#   Segment 2: Predicted Label = 65, Prediction Score = 0.9871, Segment Video Label Score = 0.9871, Segment True Label Score = 0.9871, SV True Label = 0.0167, SV Predicted Label = 0.0167
#   Segment 3: Predicted Label = 65, Prediction Score = 0.9903, Segment Video Label Score = 0.9903, Segment True Label Score = 0.9903, SV True Label = 0.0176, SV Predicted Label = 0.0176
#   Segment 4: Predicted Label = 65, Prediction Score = 0.9746, Segment Video Label Score = 0.9746, Segment True Label Score = 0.9746, SV True Label = 0.0131, SV Predicted Label = 0.0131
#   Segment 5: Predicted Label = 65, Prediction Score = 0.9858, Segment Video Label Score = 0.9858, Segment True Label Score = 0.9858, SV True Label = 0.0163, SV Predicted Label = 0.0163
#   Segment 6: Predicted Label = 65, Prediction Score = 0.9837, Segment Video Label Score = 0.9837, Segment True Label Score = 0.9837, SV True Label = 0.0157, SV Predicted Label = 0.0157
#   Segment 7: Predicted Label = 65, Prediction Score = 0.9643, Segment Video Label Score = 0.9643, Segment True Label Score = 0.9643, SV True Label = 0.0102, SV Predicted Label = 0.0102
#   Segment 8: Predicted Label = 65, Prediction Score = 0.7768, Segment Video Label Score = 0.7768, Segment True Label Score = 0.7768, SV True Label = -0.0430, SV Predicted Label = -0.0430
# Video: T9c_KZVHP4E.mp4, Overall Predicted Label = 42, Overall Prediction Score = 0.3394, True Label = 65, True Label Score = 0.0432
#   Segment 1: Predicted Label = 278, Prediction Score = 0.9118, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0002, SV True Label = -0.0119, SV Predicted Label = -0.0935
#   Segment 2: Predicted Label = 42, Prediction Score = 0.7055, Segment Video Label Score = 0.7055, Segment True Label Score = 0.0019, SV True Label = -0.0114, SV Predicted Label = 0.1064
#   Segment 3: Predicted Label = 42, Prediction Score = 0.9875, Segment Video Label Score = 0.9875, Segment True Label Score = 0.0007, SV True Label = -0.0117, SV Predicted Label = 0.1864
#   Segment 4: Predicted Label = 42, Prediction Score = 0.9819, Segment Video Label Score = 0.9819, Segment True Label Score = 0.0010, SV True Label = -0.0116, SV Predicted Label = 0.1848
#   Segment 5: Predicted Label = 65, Prediction Score = 0.2697, Segment Video Label Score = 0.0148, Segment True Label Score = 0.2697, SV True Label = 0.0645, SV Predicted Label = -0.0893
#   Segment 6: Predicted Label = 101, Prediction Score = 0.1476, Segment Video Label Score = 0.0168, Segment True Label Score = 0.0718, SV True Label = 0.0084, SV Predicted Label = -0.0888
#   Segment 7: Predicted Label = 234, Prediction Score = 0.8860, Segment Video Label Score = 0.0083, Segment True Label Score = 0.0003, SV True Label = -0.0118, SV Predicted Label = -0.0912
#   Segment 8: Predicted Label = 304, Prediction Score = 0.2158, Segment Video Label Score = 0.0000, Segment True Label Score = 0.0000, SV True Label = -0.0119, SV Predicted Label = -0.0935

# %% [markdown]
# All dataset include

# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                try:
                    outputs = self.model(**inputs)
                    logits = outputs.logits
                    probabilities = F.softmax(logits, dim=-1)
                    pred_label = logits.argmax(-1).item()
                    pred_score = probabilities[0, pred_label].item()
                    segment_outputs.append((pred_label, pred_score, probabilities))
                except RuntimeError as e:
                    print(f"Error processing segment: {e}")
                    continue
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False):
    predictions = []
    for video_file, true_label in tqdm(zip(sampled_files, true_labels), desc="Processing videos", total=len(sampled_files), unit="video"):
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        try:
            segment_outputs = video_processor.predict_video_and_segments(container, true_label)
            if not segment_outputs:
                print(f"Skipping video {video_file} due to empty segment outputs.")
                continue
            video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
            video_pred_label = video_probs.argmax().item()
            video_pred_score = video_probs[0, video_pred_label].item()
            video_true_score = video_probs[0, true_label].item()
            
            if use_exact:
                sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
            else:
                sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
            
            predictions.append((video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred))
        except Exception as e:
            print(f"Error processing video {video_file}: {e}")
            continue
    return predictions

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "video_true_label": video_true_label,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, video_true_label].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,  # 近似 Shapley Value 计算的采样次数
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": True  # 设置为 True 以使用精确 Shapley Value 计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签
video_files = []
true_labels = []
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_files.append(name)
        true_labels.append(int(label))

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, video_files, true_labels, use_exact=config["use_exact"])

# 打印并保存结果
save_results(video_data)

# 打印结果以便查看
for video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_label}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_label].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   0%|          | 0/19796 [00:00<?, ?video/s]
# Error processing video jf7RDuUTrsQ.mp4: Unable to create tensor, you should probably activate padding with 'padding=True' to have batched tensors with the same length.

# %% [markdown]
# 添加断电续传 & performance

# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                try:
                    outputs = self.model(**inputs)
                    logits = outputs.logits
                    probabilities = F.softmax(logits, dim=-1)
                    pred_label = logits.argmax(-1).item()
                    pred_score = probabilities[0, pred_label].item()
                    segment_outputs.append((pred_label, pred_score, probabilities))
                except RuntimeError as e:
                    print(f"Error processing segment: {e}")
                    continue
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False, start_index=0):
    predictions = []
    for idx, (video_file, true_label) in tqdm(enumerate(zip(sampled_files, true_labels)), desc="Processing videos", total=len(sampled_files), initial=start_index, unit="video"):
        if idx < start_index:
            continue
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        try:
            segment_outputs = video_processor.predict_video_and_segments(container, true_label)
            if not segment_outputs:
                print(f"Skipping video {video_file} due to empty segment outputs.")
                continue
            video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
            video_pred_label = video_probs.argmax().item()
            video_pred_score = video_probs[0, video_pred_label].item()
            video_true_score = video_probs[0, true_label].item()
            
            if use_exact:
                sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
            else:
                sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
            
            prediction = (video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred)
            predictions.append(prediction)
            save_partial_results(prediction, "results.json")
        except Exception as e:
            print(f"Error processing video {video_file}: {e}")
            continue
    return predictions

def save_partial_results(prediction, filename):
    video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred = prediction
    video_result = {
        "video_file": video_file,
        "video_pred_label": video_pred_label,
        "video_pred_score": video_pred_score,
        "video_true_score": video_true_score,
        "video_true_label": video_true_label,
        "segments": []
    }
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, video_true_label].item()
        video_result["segments"].append({
            "segment_index": i + 1,
            "segment_label": segment_label,
            "segment_score": segment_score,
            "segment_video_label_score": segment_video_label_score,
            "segment_true_label_score": segment_true_label_score,
            "sv_true_label": sv_true_label[i],
            "sv_video_pred": sv_video_pred[i]
        })
    
    if os.path.exists(filename):
        with open(filename, "r") as f:
            results = json.load(f)
    else:
        results = []
    
    results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

def load_existing_results(filename):
    if os.path.exists(filename):
        with open(filename, "r") as f:
            results = json.load(f)
            processed_files = {result["video_file"] for result in results}
            return results, processed_files
    return [], set()

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "video_true_label": video_true_label,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, video_true_label].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

def compute_metrics(predictions):
    true_labels = [pred[4] for pred in predictions]
    pred_labels = [pred[1] for pred in predictions]
    
    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')
    
    return accuracy, precision, recall, f1

def save_performance_metrics(accuracy, precision, recall, f1, filename="performance.json"):
    performance = {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }
    
    with open(filename, "w") as f:
        json.dump(performance, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,  # 近似 Shapley Value 计算的采样次数
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": True  # 设置为 True 以使用精确 Shapley Value 计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签
video_files = []
true_labels = []
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_files.append(name)
        true_labels.append(int(label))

# 加载现有结果和已处理文件
existing_results, processed_files = load_existing_results("results.json")

# 筛选未处理文件
unprocessed_files = [f for f in video_files if f not in processed_files]
unprocessed_labels = [true_labels[video_files.index(f)] for f in unprocessed_files]

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, unprocessed_files, unprocessed_labels, use_exact=config["use_exact"], start_index=len(existing_results))

# 合并现有结果与新结果
all_results = existing_results + video_data

# 打印并保存结果
save_results(all_results)

# 计算并输出指标
accuracy, precision, recall, f1 = compute_metrics(all_results)
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# 保存性能指标
save_performance_metrics(accuracy, precision, recall, f1, filename="performance.json")

# 打印详细结果
for video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_label}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_label].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Processing videos:   4%|3         | 750/19046 [00:00<?, ?video/s]
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/transformers/feature_extraction_utils.py:141: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   return torch.tensor(value)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 248
#     245 unprocessed_labels = [true_labels[video_files.index(f)] for f in unprocessed_files]
#     247 # 获取数据和预测
# --> 248 video_data = process_videos(video_processor, shap_calculator, unprocessed_files, unprocessed_labels, use_exact=config["use_exact"], start_index=len(existing_results))
#     250 # 合并现有结果与新结果
#     251 all_results = existing_results + video_data
#
# Cell In[3], line 101, in process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact, start_index)
#      99 container = av.open(file_path)
#     100 try:
# --> 101     segment_outputs = video_processor.predict_video_and_segments(container, true_label)
#     102     if not segment_outputs:
#     103         print(f"Skipping video {video_file} due to empty segment outputs.")
#
# Cell In[3], line 40, in VideoProcessor.predict_video_and_segments(self, container, true_label)
#      39 def predict_video_and_segments(self, container, true_label):
# ---> 40     video_segments = self.split_video_into_segments(container)
#      41     segment_outputs = []
#      42     with torch.no_grad():
#
# Cell In[3], line 28, in VideoProcessor.split_video_into_segments(self, container, n_segments, frames_per_segment)
#      27 def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
# ---> 28     frame_list = [frame.to_image() for frame in container.decode(video=0)]
#      29     total_frames = len(frame_list)
#      30     segment_length = total_frames // n_segments
#
# File av/video/frame.pyx:275, in av.video.frame.VideoFrame.to_image()
#
# File ~/miniconda3/envs/mmxai/lib/python3.12/site-packages/PIL/Image.py:2944, in frombytes(mode, size, data, decoder_name, *args)
#    2940         color = im.palette.getcolor(color)
#    2941     return im._new(core.fill(mode, size, color))
# -> 2944 def frombytes(mode, size, data, decoder_name="raw", *args) -> Image:
#    2945     """
#    2946     Creates a copy of an image memory from pixel data in a buffer.
#    2947
#    (...)
#    2965     :returns: An :py:class:`~PIL.Image.Image` object.
#    2966     """
#    2968     _check_size(size)
#
# KeyboardInterrupt:

# %% [markdown]
# 添加能耗记录

# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
import time
import subprocess
import psutil
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                try:
                    outputs = self.model(**inputs)
                    logits = outputs.logits
                    probabilities = F.softmax(logits, dim=-1)
                    pred_label = logits.argmax(-1).item()
                    pred_score = probabilities[0, pred_label].item()
                    segment_outputs.append((pred_label, pred_score, probabilities))
                except RuntimeError as e:
                    print(f"Error processing segment: {e}")
                    continue
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples
    
    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def get_gpu_energy():
    try:
        result = subprocess.check_output(['nvidia-smi', '--query-gpu=energy.draw', '--format=csv,noheader,nounits'])
        return float(result.strip().split()[0])
    except Exception as e:
        print(f"Error reading GPU energy: {e}")
        return 0.0

def get_cpu_energy():
    try:
        energy = 0.0
        for domain in psutil.sensors_battery():
            energy += domain.power * domain.energy
        return energy
    except Exception as e:
        print(f"Error reading CPU energy: {e}")
        return 0.0

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False, start_index=0):
    predictions = []
    for idx, (video_file, true_label) in tqdm(enumerate(zip(sampled_files, true_labels)), desc="Processing videos", total=len(sampled_files), initial=start_index, unit="video"):
        if idx < start_index:
            continue
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        try:
            segment_outputs = video_processor.predict_video_and_segments(container, true_label)
            if not segment_outputs:
                print(f"Skipping video {video_file} due to empty segment outputs.")
                continue
            video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
            video_pred_label = video_probs.argmax().item()
            video_pred_score = video_probs[0, video_pred_label].item()
            video_true_score = video_probs[0, true_label].item()
            
            if use_exact:
                sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
            else:
                sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
            
            prediction = (video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred)
            predictions.append(prediction)
            save_partial_results(prediction, "results.json")
        except Exception as e:
            print(f"Error processing video {video_file}: {e}")
            continue
    return predictions

def save_partial_results(prediction, filename):
    video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred = prediction
    video_result = {
        "video_file": video_file,
        "video_pred_label": video_pred_label,
        "video_pred_score": video_pred_score,
        "video_true_score": video_true_score,
        "video_true_label": video_true_label,
        "segments": []
    }
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, video_true_label].item()
        video_result["segments"].append({
            "segment_index": i + 1,
            "segment_label": segment_label,
            "segment_score": segment_score,
            "segment_video_label_score": segment_video_label_score,
            "segment_true_label_score": segment_true_label_score,
            "sv_true_label": sv_true_label[i],
            "sv_video_pred": sv_video_pred[i]
        })
    
    if os.path.exists(filename):
        with open(filename, "r") as f:
            results = json.load(f)
    else:
        results = []
    
    results.append(video_result)
    
    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

def load_existing_results(filename):
    if os.path.exists(filename):
        with open(filename, "r") as f:
            results = json.load(f)
            processed_files = {result["video_file"] for result in results}
            return results, processed_files
    return [], set()

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "video_true_label": video_true_label,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, video_true_label].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
            results.append(video_result)
        
        with open(filename, "w") as f:
            json.dump(results, f, indent=4)

def compute_metrics(predictions):
    true_labels = [pred[4] for pred in predictions]
    pred_labels = [pred[1] for pred in predictions]
    
    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')
    
    return accuracy, precision, recall, f1

def save_performance_metrics(accuracy, precision, recall, f1, time_consumed, cpu_energy, gpu_energy, filename="performance.json"):
    performance = {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "time_consumed": time_consumed,
        "cpu_energy": cpu_energy,
        "gpu_energy": gpu_energy
    }
    
    with open(filename, "w") as f:
        json.dump(performance, f, indent=4)

# 配置
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",  # 用户可以在这里更换模型名称，例如 "huggingface/vivit"
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 100,  # 近似 Shapley Value 计算的采样次数
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/videos_val",
    "use_exact": True  # 设置为 True 以使用精确 Shapley Value 计算
}

# 初始化处理器
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# 读取视频列表和标签
video_files = []
true_labels = []
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_files.append(name)
        true_labels.append(int(label))

# 加载现有结果和已处理文件
existing_results, processed_files = load_existing_results("results.json")

# 筛选未处理文件
unprocessed_files = [f for f in video_files if f not in processed_files]
unprocessed_labels = [true_labels[video_files.index(f)] for f in unprocessed_files]

# 记录开始时间和能量
start_time = time.time()
initial_cpu_energy = get_cpu_energy()
initial_gpu_energy = get_gpu_energy()

# 获取数据和预测
video_data = process_videos(video_processor, shap_calculator, unprocessed_files, unprocessed_labels, use_exact=config["use_exact"], start_index=len(existing_results))

# 记录结束时间和能量
end_time = time.time()
final_cpu_energy = get_cpu_energy()
final_gpu_energy = get_gpu_energy()
time_consumed = end_time - start_time
cpu_energy_consumed = final_cpu_energy - initial_cpu_energy
gpu_energy_consumed = final_gpu_energy - initial_gpu_energy

# 合并现有结果与新结果
all_results = existing_results + video_data

# 打印并保存结果
save_results(all_results)

# 计算并输出指标
accuracy, precision, recall, f1 = compute_metrics(all_results)
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# 保存性能指标
save_performance_metrics(accuracy, precision, recall, f1, time_consumed, cpu_energy_consumed, gpu_energy_consumed, filename="performance.json")

# 打印详细结果
for video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred in video_data:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_label}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_label].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Error reading CPU energy: 'int' object has no attribute 'power'
# Error reading GPU energy: Command '['nvidia-smi', '--query-gpu=energy.draw', '--format=csv,noheader,nounits']' returned non-zero exit status 2.
# Processing videos:   0%|          | 0/19796 [00:00<?, ?video/s]
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/transformers/feature_extraction_utils.py:141: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   return torch.tensor(value)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 276
#     273 initial_gpu_energy = get_gpu_energy()
#     275 # 获取数据和预测
# --> 276 video_data = process_videos(video_processor, shap_calculator, unprocessed_files, unprocessed_labels, use_exact=config["use_exact"], start_index=len(existing_results))
#     278 # 记录结束时间和能量
#     279 end_time = time.time()
#
# Cell In[4], line 133, in process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact, start_index)
#     131 if use_exact:
#     132     sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
# --> 133     sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
#     134 else:
#     135     sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
#
# Cell In[4], line 90, in TemporalShap.exact_shapley_values(self, segment_outputs, label_index)
#      88 subset_prob = torch.zeros_like(segment_outputs[0][2])
#      89 if subset:
# ---> 90     subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
#      91 with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
#      92 marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
#
# KeyboardInterrupt:

# %% [markdown]
# 指定Class数据集的完整功能

# %%
import os
import av
import torch
import numpy as np
import torch.nn.functional as F
import random
import json
import time
import subprocess
import psutil
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import AutoImageProcessor, TimesformerForVideoClassification
from collections import defaultdict
from tqdm.notebook import tqdm
from itertools import combinations

class VideoProcessor:
    def __init__(self, model_name, image_processor_name, device='cuda'):
        self.model = self.load_model(model_name)
        self.image_processor = AutoImageProcessor.from_pretrained(image_processor_name)
        self.device = device
        self.model.to(device)

    def load_model(self, model_name):
        if "timesformer" in model_name.lower():
            return TimesformerForVideoClassification.from_pretrained(model_name)
        else:
            raise ValueError(f"Unsupported model name: {model_name}")

    def split_video_into_segments(self, container, n_segments=8, frames_per_segment=16):
        frame_list = [frame.to_image() for frame in container.decode(video=0)]
        total_frames = len(frame_list)
        segment_length = total_frames // n_segments
        segments = []
        for i in range(n_segments):
            start = i * segment_length
            end = min(start + segment_length, total_frames)
            segment_frames = frame_list[start:end] if end - start == segment_length else frame_list[start:] + [frame_list[-1]] * (segment_length - (end - start))
            segments.append(segment_frames[:frames_per_segment])
        return segments

    def predict_video_and_segments(self, container, true_label):
        video_segments = self.split_video_into_segments(container)
        segment_outputs = []
        with torch.no_grad():
            for segment in video_segments:
                inputs = self.image_processor(list(segment), return_tensors="pt")
                inputs = {k: v.to(self.device) for k, v in inputs.items()}
                try:
                    outputs = self.model(**inputs)
                    logits = outputs.logits
                    probabilities = F.softmax(logits, dim=-1)
                    pred_label = logits.argmax(-1).item()
                    pred_score = probabilities[0, pred_label].item()
                    segment_outputs.append((pred_label, pred_score, probabilities))
                except RuntimeError as e:
                    print(f"Error processing segment: {e}")
                    continue
        return segment_outputs

class TemporalShap:
    def __init__(self, num_samples=100):
        self.num_samples = num_samples

    def approximate_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        for _ in range(self.num_samples):
            random_subset = sorted(range(n), key=lambda _: random.random())
            subset_prob = torch.zeros_like(segment_outputs[0][2])
            for i, index in enumerate(random_subset):
                old_contribution = subset_prob[0, label_index].item()
                subset_prob += segment_outputs[index][2]
                subset_prob /= (i + 1)
                new_contribution = subset_prob[0, label_index].item()
                shapley_values[index] += new_contribution - old_contribution
        return [val / self.num_samples for val in shapley_values]

    def exact_shapley_values(self, segment_outputs, label_index):
        n = len(segment_outputs)
        shapley_values = [0] * n
        all_indices = list(range(n))
        for i in all_indices:
            marginal_contributions = []
            for subset_size in range(n):
                subsets = list(combinations([x for x in all_indices if x != i], subset_size))
                for subset in subsets:
                    subset_prob = torch.zeros_like(segment_outputs[0][2])
                    if subset:
                        subset_prob = torch.mean(torch.stack([segment_outputs[j][2] for j in subset]), dim=0)
                    with_i_prob = (subset_prob * len(subset) + segment_outputs[i][2]) / (len(subset) + 1)
                    marginal_contributions.append(with_i_prob[0, label_index].item() - subset_prob[0, label_index].item())
            shapley_values[i] = np.mean(marginal_contributions)
        return shapley_values

def get_gpu_energy():
    try:
        result = subprocess.check_output(['nvidia-smi', '--query-gpu=energy.draw', '--format=csv,noheader,nounits'])
        return float(result.strip().split()[0])
    except Exception as e:
        print(f"Error reading GPU energy: {e}")
        return 0.0

def get_cpu_energy():
    try:
        energy = 0.0
        for domain in psutil.sensors_battery():
            energy += domain.power * domain.energy
        return energy
    except Exception as e:
        print(f"Error reading CPU energy: {e}")
        return 0.0
    
import subprocess
import time

def get_gpu_power_draw():
    try:
        # This command retrieves the current power usage in watts.
        result = subprocess.check_output(['nvidia-smi', '--query-gpu=power.draw', '--format=csv,noheader,nounits'], text=True)
        return float(result.strip())
    except Exception as e:
        print(f"Error reading GPU power: {e}")
        return 0.0

def get_system_time():
    return time.time()  # Return the current system time in seconds

# Example usage in your processing function
start_time = get_system_time()
initial_gpu_power = get_gpu_power_draw()

# Execute your long-running process here
time.sleep(10)  # Simulating a delay

end_time = get_system_time()
final_gpu_power = get_gpu_power_draw()

time_consumed = end_time - start_time
average_gpu_power = (initial_gpu_power + final_gpu_power) / 2
energy_consumed = average_gpu_power * (time_consumed / 3600)  # Convert power usage in watts to kilowatt-hours if needed

def process_videos(video_processor, shap_calculator, sampled_files, true_labels, use_exact=False, start_index=0):
    predictions = []
    for idx, (video_file, true_label) in tqdm(enumerate(zip(sampled_files, true_labels)), desc="Processing videos", total=len(sampled_files), initial=start_index, unit="video"):
        if idx < start_index:
            continue
        file_path = os.path.join(config["video_directory"], video_file)
        container = av.open(file_path)
        try:
            segment_outputs = video_processor.predict_video_and_segments(container, true_label)
            if not segment_outputs:
                print(f"Skipping video {video_file} due to empty segment outputs.")
                continue
            video_probs = torch.mean(torch.stack([output[2] for output in segment_outputs]), dim=0)
            video_pred_label = video_probs.argmax().item()
            video_pred_score = video_probs[0, video_pred_label].item()
            video_true_score = video_probs[0, true_label].item()
            
            if use_exact:
                sv_true_label = shap_calculator.exact_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.exact_shapley_values(segment_outputs, video_pred_label)
            else:
                sv_true_label = shap_calculator.approximate_shapley_values(segment_outputs, true_label)
                sv_video_pred = shap_calculator.approximate_shapley_values(segment_outputs, video_pred_label)
            
            prediction = (video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred)
            predictions.append(prediction)
            save_partial_results(prediction, "results.json")
        except Exception as e:
            print(f"Error processing video {video_file}: {e}")
            continue
    return predictions

def save_partial_results(prediction, filename):
    video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred = prediction
    video_result = {
        "video_file": video_file,
        "video_pred_label": video_pred_label,
        "video_pred_score": video_pred_score,
        "video_true_score": video_true_score,
        "video_true_label": video_true_label,
        "segments": []
    }
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, video_true_label].item()
        video_result["segments"].append({
            "segment_index": i + 1,
            "segment_label": segment_label,
            "segment_score": segment_score,
            "segment_video_label_score": segment_video_label_score,
            "segment_true_label_score": segment_true_label_score,
            "sv_true_label": sv_true_label[i],
            "sv_video_pred": sv_video_pred[i]
        })
    
    if os.path.exists(filename):
        with open(filename, "r+") as f:
            results = json.load(f)
            results.append(video_result)
            f.seek(0)
            json.dump(results, f, indent=4)
    else:
        with open(filename, "w") as f:
            json.dump([video_result], f, indent=4)

def load_existing_results(filename):
    if os.path.exists(filename):
        with open(filename, "r") as f:
            results = json.load(f)
            processed_files = {result["video_file"] for result in results}
            return results, processed_files
    return [], set()

def save_results(predictions, filename="results.json"):
    results = []
    for video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred in predictions:
        video_result = {
            "video_file": video_file,
            "video_pred_label": video_pred_label,
            "video_pred_score": video_pred_score,
            "video_true_score": video_true_score,
            "video_true_label": video_true_label,
            "segments": []
        }
        for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
            segment_video_label_score = probabilities[0, video_pred_label].item()
            segment_true_label_score = probabilities[0, video_true_label].item()
            video_result["segments"].append({
                "segment_index": i + 1,
                "segment_label": segment_label,
                "segment_score": segment_score,
                "segment_video_label_score": segment_video_label_score,
                "segment_true_label_score": segment_true_label_score,
                "sv_true_label": sv_true_label[i],
                "sv_video_pred": sv_video_pred[i]
            })
        results.append(video_result)

    with open(filename, "w") as f:
        json.dump(results, f, indent=4)

def compute_metrics(predictions):
    true_labels = [pred[4] for pred in predictions]
    pred_labels = [pred[1] for pred in predictions]
    
    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')
    
    return accuracy, precision, recall, f1

def save_performance_metrics(accuracy, precision, recall, f1, time_consumed, cpu_energy, gpu_energy, filename="performance.json"):
    performance = {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "time_consumed": time_consumed,
        "cpu_energy": cpu_energy,
        "gpu_energy": gpu_energy
    }
    
    with open(filename, "w") as f:
        json.dump(performance, f, indent=4)

# Configuration
config = {
    "model_name": "facebook/timesformer-base-finetuned-k400",
    "image_processor_name": "MCG-NJU/videomae-base-finetuned-kinetics",
    "num_samples": 10,
    "num_classes": 4,  # For flexible dataset input
    "num_samples_per_class": 5,  # For flexible dataset input
    "video_list_path": "archive/kinetics400_val_list_videos.txt",
    "video_directory": "archive/zoom_blur",
    "use_exact": True
}

# Initialize processors
video_processor = VideoProcessor(config["model_name"], config["image_processor_name"])
shap_calculator = TemporalShap(num_samples=config["num_samples"])

# Load existing results
existing_results, processed_files = load_existing_results("results.json")

# Read video list and organize by categories if necessary
video_labels = defaultdict(list)
with open(config["video_list_path"], "r") as f:
    for line in f:
        name, label = line.strip().split()
        video_labels[int(label)].append(name)

# Prepare video samples for the configured number of classes and samples
sampled_files = []
true_labels = []
selected_classes = random.sample(list(video_labels.keys()), config["num_classes"])
for cls in selected_classes:
    sampled_files.extend(random.sample(video_labels[cls], config["num_samples_per_class"]))
    true_labels.extend([cls] * config["num_samples_per_class"])

# Filter unprocessed files
unprocessed_files = [f for f in sampled_files if f not in processed_files]
unprocessed_labels = [true_labels[sampled_files.index(f)] for f in unprocessed_files]

# Record start time and energy consumption
start_time = time.time()
initial_cpu_energy = get_cpu_energy()
initial_gpu_energy = get_gpu_energy()

# Process videos
video_data = process_videos(video_processor, shap_calculator, unprocessed_files, unprocessed_labels, use_exact=config["use_exact"], start_index=len(existing_results))

# Record end time and energy consumption
end_time = time.time()
final_cpu_energy = get_cpu_energy()
final_gpu_energy = get_gpu_energy()
time_consumed = end_time - start_time
cpu_energy_consumed = final_cpu_energy - initial_cpu_energy
gpu_energy_consumed = final_gpu_energy - initial_gpu_energy

# Combine existing results with new data
all_results = existing_results + video_data

# Save results
save_results(all_results)

# Compute and output metrics
accuracy, precision, recall, f1 = compute_metrics(all_results)
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Save performance metrics
save_performance_metrics(accuracy, precision, recall, f1, time_consumed, cpu_energy_consumed, gpu_energy_consumed, filename="performance.json")


# Print detailed results
for video_file, video_pred_label, video_pred_score, video_true_score, true_label, segment_outputs, sv_true_label, sv_video_pred in all_results:
    print(f"Video: {video_file}, Overall Predicted Label = {video_pred_label}, Overall Prediction Score = {video_pred_score:.4f}, True Label = {true_label}, True Label Score = {video_true_score:.4f}")
    for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
        segment_video_label_score = probabilities[0, video_pred_label].item()
        segment_true_label_score = probabilities[0, true_label].item()
        print(f"  Segment {i+1}: Predicted Label = {segment_label}, Prediction Score = {segment_score:.4f}, Segment Video Label Score = {segment_video_label_score:.4f}, Segment True Label Score = {segment_true_label_score:.4f}, SV True Label = {sv_true_label[i]:.4f}, SV Predicted Label = {sv_video_pred[i]:.4f}")
# Out:
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Error reading CPU energy: 'int' object has no attribute 'power'
# Error reading GPU energy: Command '['nvidia-smi', '--query-gpu=energy.draw', '--format=csv,noheader,nounits']' returned non-zero exit status 2.
# Processing videos: 100%|##########| 20/20 [00:00<?, ?video/s]
# Error reading CPU energy: 'int' object has no attribute 'power'
# Error reading GPU energy: Command '['nvidia-smi', '--query-gpu=energy.draw', '--format=csv,noheader,nounits']' returned non-zero exit status 2.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 327
#     324 all_results = existing_results + video_data
#     326 # Save results
# --> 327 save_results(all_results)
#     329 # Compute and output metrics
#     330 accuracy, precision, recall, f1 = compute_metrics(all_results)
#
# Cell In[2], line 218, in save_results(predictions, filename)
#     216 def save_results(predictions, filename="results.json"):
#     217     results = []
# --> 218     for video_file, video_pred_label, video_pred_score, video_true_score, video_true_label, segment_outputs, sv_true_label, sv_video_pred in predictions:
#     219         video_result = {
#     220             "video_file": video_file,
#     221             "video_pred_label": video_pred_label,
#    (...)
#     225             "segments": []
#     226         }
#     227         for i, (segment_label, segment_score, probabilities) in enumerate(segment_outputs):
#
# ValueError: not enough values to unpack (expected 8, got 6)

# %%
import os
import av
import torch
from transformers import ViTForImageClassification, ViTFeatureExtractor, ViTConfig
from PIL import Image
import numpy as np
from tqdm import tqdm
from lime import lime_image
from skimage.segmentation import mark_boundaries
import matplotlib.pyplot as plt
import random

# Configuration
config = {
    "model_config": "google/vit-base-patch16-224",
    "model_path": "finetuned_vit_model.pth",
    "feature_extractor_name": "google/vit-base-patch16-224",
    "video_directory": "archive/videos_val",
    "results_folder": "Results",
    "num_classes": 400,
    "num_videos_to_process": 10  # Number of videos to process
}

# Ensure the results directory exists
os.makedirs(config["results_folder"], exist_ok=True)

# Load the model
model_config = ViTConfig.from_pretrained(config["model_config"], num_labels=config["num_classes"])
model = ViTForImageClassification(model_config)
model.load_state_dict(torch.load(config["model_path"]), strict=False)  # Use strict=False to ignore non-matching keys
model.eval()

# Load the feature extractor
feature_extractor = ViTFeatureExtractor.from_pretrained(config["feature_extractor_name"])

# Function to process and explain a video file
def process_and_explain(video_path, model, feature_extractor):
    container = av.open(video_path)
    frame = next(container.decode(video=0)).to_image()
    inputs = feature_extractor(images=frame, return_tensors="pt")
    outputs = model(**inputs)
    preds = torch.nn.functional.softmax(outputs.logits, dim=-1)
    top_pred = preds.argmax().item()

    # Prepare frame for LIME
    def batch_predict(images):
        inputs = feature_extractor(images=[Image.fromarray(img.astype('uint8')) for img in images], return_tensors="pt")
        with torch.no_grad():
            outputs = model(**inputs)
            probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        return probs.detach().cpu().numpy()

    # Explain with LIME
    explainer = lime_image.LimeImageExplainer()
    explanation = explainer.explain_instance(np.array(frame), batch_predict, top_labels=5, hide_color=0, num_samples=1000)
    temp, mask = explanation.get_image_and_mask(top_pred, positive_only=False, num_features=10, hide_rest=False)
    img_boundary = mark_boundaries(np.array(frame) / 255.0, mask)

    # Plot and save the results
    plt.figure(figsize=(10, 10))
    plt.imshow(img_boundary)
    plt.axis('off')
    plt_path = os.path.join(config["results_folder"], f"{os.path.basename(video_path)}_explanation.png")
    plt.savefig(plt_path)
    plt.close()

    return top_pred, plt_path

# Select and process videos
all_video_files = os.listdir(config["video_directory"])
selected_video_files = random.sample(all_video_files, min(config["num_videos_to_process"], len(all_video_files)))

for video_file in tqdm(selected_video_files, desc="Processing videos"):
    video_path = os.path.join(config["video_directory"], video_file)
    prediction, explanation_path = process_and_explain(video_path, model, feature_extractor)
    print(f"Processed {video_file}: Top prediction index = {prediction}, Explanation saved to {explanation_path}")
# Out:
# /home/z/miniconda3/envs/mmxai/lib/python3.12/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# Processing videos:   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  10%|█         | 1/10 [01:25<12:50, 85.57s/it]
# Processed WwZv2UcULCo.mp4: Top prediction index = 229, Explanation saved to Results/WwZv2UcULCo.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  20%|██        | 2/10 [02:37<10:22, 77.81s/it]
# Processed GuDFD9qmXkY.mp4: Top prediction index = 209, Explanation saved to Results/GuDFD9qmXkY.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  30%|███       | 3/10 [03:50<08:48, 75.46s/it]
# Processed 5wzGMlYQzDU.mp4: Top prediction index = 280, Explanation saved to Results/5wzGMlYQzDU.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  40%|████      | 4/10 [05:00<07:18, 73.13s/it]
# Processed zlWSKUJl76M.mp4: Top prediction index = 98, Explanation saved to Results/zlWSKUJl76M.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  50%|█████     | 5/10 [06:14<06:08, 73.65s/it]
# Processed -5-dvLrzE78.mp4: Top prediction index = 167, Explanation saved to Results/-5-dvLrzE78.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  60%|██████    | 6/10 [07:27<04:54, 73.50s/it]
# Processed -nTtZiY1He0.mp4: Top prediction index = 214, Explanation saved to Results/-nTtZiY1He0.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  70%|███████   | 7/10 [08:41<03:40, 73.39s/it]
# Processed fT8BdRZNfTg.mp4: Top prediction index = 349, Explanation saved to Results/fT8BdRZNfTg.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  80%|████████  | 8/10 [09:50<02:24, 72.12s/it]
# Processed yorLJaaroLs.mp4: Top prediction index = 280, Explanation saved to Results/yorLJaaroLs.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos:  90%|█████████ | 9/10 [11:04<01:12, 72.62s/it]
# Processed ZLlPJuLCHi8.mp4: Top prediction index = 280, Explanation saved to Results/ZLlPJuLCHi8.mp4_explanation.png
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Processing videos: 100%|██████████| 10/10 [12:18<00:00, 73.80s/it]
# Processed gOxEEuOVXEw.mp4: Top prediction index = 46, Explanation saved to Results/gOxEEuOVXEw.mp4_explanation.png
